# %% [markdown]
# ## A notebook to query the HRA Knowledge Graph (KG)

# %%
# install packages
# %pip install requests pandas

# import external packages
import requests
import pandas as pd

# import built-in packages
import json
from pprint import pprint
from io import StringIO
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (2.32.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Example 1: Get an HRA Digital Object (DO) as a JSON file

# %% [markdown]
# In this example, we will retrieve an anatomical structures (AS), cell types (CT), plus biomarkers (B) table (ASCT+B, see [this paper](https://www.nature.com/articles/s41556-021-00788-6)) as a JSON file. As part of the HRA Digital Object (DO) processing pipeline, we perform normalization and enrichment. When we normalize, we convert every DO into a standard format that follows schemas defined in [LinkML](https://linkml.io/). The default file format for normalized data is [YAML](https://yaml.org/), which can readily be converted to JSON. This would almost be enough as is, but the current models were not fully designed for end users. It was created as a way to generate RDF graphs. So, there are some artifacts of this in the models themselves, which may make them hard to understand. However, with some clean-up, the HRA data is accessible and useful for end users with varying degrees of programming and analysis experience. LinkML can also generate a JSON-LD Context and a JSON Schema (see [https://json-schema.org/](https://json-schema.org/)), which we can then attach to the JSON files to make them validatable, easily convert them to RDF, and to provide autocomplete as well as documentation inline in code editors like VS Code, and to generate online documentation.

# %%
# Set the number of kvp printed from a pd df
n_kvp = 10

# Each HRA DO has a persistent URL (PURL), where the user is served HRA DO data after server-side content negotation

# This is the PURL for the ASCT+B table for the kidney

url = "https://purl.humanatlas.io/asct-b/kidney"


# set headers

headers = {

  "Accept" : "application/json"

}


# make request, parse response

response = requests.get(url, headers=headers)


# delete this once HRA DO JSONs are deployed

kidney_json = json.loads(response.text)

for key, value in list(kidney_json.items())[:n_kvp]:
  print(f"{key}: {value}")
# Out:
# $schema: https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.json
# @context: https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.context.jsonld
# @type: Container
# iri: https://purl.humanatlas.io/asct-b/kidney
# metadata: {'title': 'kidney (v1.5) graph data', 'description': 'The graph representation of the Anatomical Structures, Cell Types, plus Biomarkers (ASCT+B) table for Kidney dataset.', 'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'], 'creation_date': '2024-12-03', 'version': 'v1.5', 'license': 'https://creativecommons.org/licenses/by/4.0/', 'publisher': 'HuBMAP', 'see_also': 'https://lod.humanatlas.io/asct-b/kidney/v1.5/', 'derived_from': 'https://lod.humanatlas.io/asct-b/kidney/v1.5#raw-data'}
# data: {'anatomical_structures': [{'id': 'UBERON:0001062', 'ccf_pref_label': 'UBERON anatomical structure', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'parent_class': 'ccf:AnatomicalStructure'}, {'id': 'FMA:62955', 'ccf_pref_label': 'FMA anatomical structure', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'parent_class': 'ccf:AnatomicalStructure'}, {'id': 'FMA:29733', 'ccf_pref_label': 'General anatomical term', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'parent_class': 'ccf:AnatomicalStructure'}, {'id': 'UBERON:0013702', 'ccf_pref_label': 'body proper', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure'}, {'id': 'UBERON:0004538', 'ccf_pref_label': 'left kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0004539', 'ccf_pref_label': 'right kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0002113', 'ccf_pref_label': 'kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0013702']}, {'id': 'UBERON:0002015', 'ccf_pref_label': 'kidney capsule', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0001225', 'ccf_pref_label': 'cortex of kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0002189', 'ccf_pref_label': 'outer cortex of kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0001225']}, {'id': 'UBERON:0004188', 'ccf_pref_label': 'Glomerular Epithelium', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002189', 'UBERON:0005271', 'UBERON:0001284', 'UBERON:0001229']}, {'id': 'UBERON:0005751', 'ccf_pref_label': 'visceral epithelial layer', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0004188']}, {'id': 'UBERON:0005271', 'ccf_pref_label': 'juxtamedullary cortex', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0001225']}, {'id': 'UBERON:0009883', 'ccf_pref_label': 'medullary ray', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0001225']}, {'id': 'UBERON:0004203', 'ccf_pref_label': 'Collecting Duct (Cortex)', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0009883', 'UBERON:0001232']}, {'id': 'UBERON:0000362', 'ccf_pref_label': 'renal medulla', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0004202', 'ccf_pref_label': 'kidney outer medulla outer stripe', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0000362']}, {'id': 'UBERON:0001291', 'ccf_pref_label': 'Loop of Henle (Thick Limb/Medulla)', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0004202', 'UBERON:0001231']}, {'id': 'UBERON:0004201', 'ccf_pref_label': 'kidney outer medulla inner stripe', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0000362']}, {'id': 'UBERON:0001289', 'ccf_pref_label': 'Loop of Henle (Thin Limb)', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0004201', 'UBERON:0001 ...

# %%
# The resulting JSON file has these keys:
kidney_json.keys()
# Out:
# dict_keys(['$schema', '@context', '@type', 'iri', 'metadata', 'data'])

# %%
# Now we iterate over the rows in ASCT+B table
for row in kidney_json['data']['asctb_record'][:n_kvp]:
  print(row)
# Out:
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1', 'record_number': 1, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 1, 'order_number': 1, 'label': 'kidney (Table kidney, Record 1, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2', 'ccf_pref_label': 'kidney capsule', 'source_concept': 'UBERON:0002015', 'record_number': 1, 'order_number': 2, 'label': 'kidney capsule (Table kidney, Record 1, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1', 'ccf_pref_label': 'stromal cell', 'source_concept': 'CL:0000499', 'record_number': 1, 'order_number': 1, 'label': 'stromal cell (Table kidney, Record 1, Column CT/1)', 'type_of': ['CellTypeRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2', 'ccf_pref_label': 'capsule mesenchymal stromal cell', 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell', 'record_number': 1, 'order_number': 2, 'label': 'capsule mesenchymal stromal cell (Table kidney, Record 1, Column CT/2)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1', 'ccf_pref_label': 'Foxd1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:3802', 'record_number': 1, 'order_number': 1, 'label': 'Foxd1 (Table kidney, Record 1, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2', 'ccf_pref_label': 'VSX2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:1975', 'record_number': 1, 'order_number': 2, 'label': 'VSX2 (Table kidney, Record 1, Column BM/2)', 'type_of': ['BiomarkerRecord']}], 'references': ['https://doi.org/10.1371/journal.pone.0187118'], 'label': 'Table kidney, Record 1', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2', 'record_number': 2, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 2, 'order_number': 1, 'label': 'kidney (Table kidney, Record 2, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2', 'ccf_pref_label': 'cortex of kidney', 'source_concept': 'UBERON:0001225', 'record_number': 2, 'order_number': 2, 'label': 'cortex of kidney (Table kidney, Record 2, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3', 'ccf_pref_label': 'outer cortex of kidney', 'source_concept': 'UBERON:0002189', 'record_number': 2, 'order_number': 3, 'label': 'outer cortex of kidney (Table kidney, Record 2, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 2, 'order_number': 4, 'label': 'Glomerular Epithelium (Table kidney, Record 2, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 2, 'order_number': 5, 'label': 'visceral epithelial layer (Table kidney, Record 2, Column AS/5)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 2, 'order_number': 1, 'label': 'Podocyte (Table kidney, Record 2, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 2, 'order_number': 1, 'label': 'NPHS2 (Table kidney, Record 2, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 2, 'order_number': 2, 'label': 'PODXL (Table kidney, Record 2, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 2, 'order_number': 3, 'label': 'NPHS1 (Table kidney, Record 2, Column BM/3)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 2, 'order_number': 4, 'label': 'PTPRQ (Table kidney, Record 2, Column BM/4)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 2', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3', 'record_number': 3, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 3, 'order_number': 1, 'label': 'kidney (Table kidney, Record 3, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2', 'ccf_pref_label': 'cortex of kidney', 'source_concept': 'UBERON:0001225', 'record_number': 3, 'order_number': 2, 'label': 'cortex of kidney (Table kidney, Record 3, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3', 'ccf_pref_label': 'juxtamedullary cortex', 'source_concept': 'UBERON:0005271', 'record_number': 3, 'order_number': 3, 'label': 'juxtamedullary cortex (Table kidney, Record 3, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 3, 'order_number': 4, 'label': 'Glomerular Epithelium (Table kidney, Record 3, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 3, 'order_number': 5, 'label': 'visceral epithelial layer (Table kidney, Record 3, Column AS/5)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 3, 'order_number': 1, 'label': 'Podocyte (Table kidney, Record 3, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 3, 'order_number': 1, 'label': 'NPHS2 (Table kidney, Record 3, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 3, 'order_number': 2, 'label': 'PODXL (Table kidney, Record 3, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 3, 'order_number': 3, 'label': 'NPHS1 (Table kidney, Record 3, Column BM/3)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 3, 'order_number': 4, 'label': 'PTPRQ (Table kidney, Record 3, Column BM/4)', 'type_of': ['BiomarkerRecord']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM5', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:9171', 'record_number': 3, 'order_number': 5, 'label': 'PODXL (Table kidney, Record 3, Column BM/5)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 3', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4', 'record_number': 4, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 4, 'order_number': 1, 'label': 'kidney (Table kidney, Record 4, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS2', 'ccf_pref_label': 'cortex of kidney', 'source_concept': 'UBERON:0001225', 'record_number': 4, 'order_number': 2, 'label': 'cortex of kidney (Table kidney, Record 4, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS3', 'ccf_pref_label': 'medullary ray', 'source_concept': 'UBERON:0009883', 'record_number': 4, 'order_number': 3, 'label': 'medullary ray (Table kidney, Record 4, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS4', 'ccf_pref_label': 'Collecting Duct (Cortex)', 'source_concept': 'UBERON:0004203', 'record_number': 4, 'order_number': 4, 'label': 'Collecting Duct (Cortex) (Table kidney, Record 4, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-CT1', 'ccf_pref_label': 'Cortical Collecting Duct Principal Cell', 'source_concept': 'CL:1000714', 'record_number': 4, 'order_number': 1, 'label': 'Cortical Collecting Duct Principal Cell (Table kidney, Record 4, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM1', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:634', 'record_number': 4, 'order_number': 1, 'label': 'AQP2 (Table kidney, Record 4, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM2', 'ccf_pref_label': 'AQP3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:636', 'record_number': 4, 'order_number': 2, 'label': 'AQP3 (Table kidney, Record 4, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM3', 'ccf_pref_label': 'FXYD4', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4028', 'record_number': 4, 'order_number': 3, 'label': 'FXYD4 (Table kidney, Record 4, Column BM/3)', 'type_of': ['BiomarkerRecord']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM4', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:634', 'record_number': 4, 'order_number': 4, 'label': 'AQP2 (Table kidney, Record 4, Column BM/4)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 4', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5', 'record_number': 5, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 5, 'order_number': 1, 'label': 'kidney (Table kidney, Record 5, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 5, 'order_number': 2, 'label': 'renal medulla (Table kidney, Record 5, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS3', 'ccf_pref_label': 'kidney outer medulla outer stripe', 'source_concept': 'UBERON:0004202', 'record_number': 5, 'order_number': 3, 'label': 'kidney outer medulla outer stripe (Table kidney, Record 5, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS4', 'ccf_pref_label': 'Loop of Henle (Thick Limb/Medulla)', 'source_concept': 'UBERON:0001291', 'record_number': 5, 'order_number': 4, 'label': 'Loop of Henle (Thick Limb/Medulla) (Table kidney, Record 5, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-CT1', 'ccf_pref_label': 'Medullary Thick Ascending Limb Cell', 'source_concept': 'CL:1001108', 'record_number': 5, 'order_number': 1, 'label': 'Medullary Thick Ascending Limb Cell (Table kidney, Record 5, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM1', 'ccf_pref_label': 'SLC12A1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10910', 'record_number': 5, 'order_number': 1, 'label': 'SLC12A1 (Table kidney, Record 5, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM2', 'ccf_pref_label': 'UMOD', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:12559', 'record_number': 5, 'order_number': 2, 'label': 'UMOD (Table kidney, Record 5, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM3', 'ccf_pref_label': 'CASR', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:1514', 'record_number': 5, 'order_number': 3, 'label': 'CASR (Table kidney, Record 5, Column BM/3)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 5', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6', 'record_number': 6, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 6, 'order_number': 1, 'label': 'kidney (Table kidney, Record 6, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 6, 'order_number': 2, 'label': 'renal medulla (Table kidney, Record 6, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS3', 'ccf_pref_label': 'kidney outer medulla inner stripe', 'source_concept': 'UBERON:0004201', 'record_number': 6, 'order_number': 3, 'label': 'kidney outer medulla inner stripe (Table kidney, Record 6, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS4', 'ccf_pref_label': 'Loop of Henle (Thin Limb)', 'source_concept': 'UBERON:0001289', 'record_number': 6, 'order_number': 4, 'label': 'Loop of Henle (Thin Limb) (Table kidney, Record 6, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS5', 'ccf_pref_label': 'descending thin limb of loop of Henle 2', 'source_concept': 'UBERON:8600036', 'record_number': 6, 'order_number': 5, 'label': 'descending thin limb of loop of Henle 2 (Table kidney, Record 6, Column AS/5)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-CT1', 'ccf_pref_label': 'Descending Thin Limb Cell Type 2', 'source_concept': 'CL:4030013', 'record_number': 6, 'order_number': 1, 'label': 'Descending Thin Limb Cell Type 2 (Table kidney, Record 6, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM1', 'ccf_pref_label': 'CRYAB', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:2389', 'record_number': 6, 'order_number': 1, 'label': 'CRYAB (Table kidney, Record 6, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM2', 'ccf_pref_label': 'SLC39A8', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:20862', 'record_number': 6, 'order_number': 2, 'label': 'SLC39A8 (Table kidney, Record 6, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM3', 'ccf_pref_label': 'TACSTD2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11530', 'record_number': 6, 'order_number': 3, 'label': 'TACSTD2 (Table kidney, Record 6, Column BM/3)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM4', 'ccf_pref_label': 'AQP1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:633', 'record_number': 6, 'order_number': 4, 'label': 'AQP1 (Table kidney, Record 6, Column BM/4)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM5', 'ccf_pref_label': 'SLC9A3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11073', 'record_number': 6, 'order_number': 5, 'label': 'SLC9A3 (Table kidney, Record 6, Column BM/5)', 'type_of': ['BiomarkerRecord']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM6', 'ccf_pref_label': 'AQP1', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:633', 'record_number': 6, 'order_number': 6, 'label': 'AQP1 (Table kidney, Record 6, Column BM/6)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 6', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7', 'record_number': 7, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 7, 'order_number': 1, 'label': 'kidney (Table kidney, Record 7, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 7, 'order_number': 2, 'label': 'renal medulla (Table kidney, Record 7, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS3', 'ccf_pref_label': 'inner medulla of kidney', 'source_concept': 'UBERON:0001294', 'record_number': 7, 'order_number': 3, 'label': 'inner medulla of kidney (Table kidney, Record 7, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS4', 'ccf_pref_label': 'Descending Vasa Recta', 'source_concept': 'UBERON:0009202', 'record_number': 7, 'order_number': 4, 'label': 'Descending Vasa Recta (Table kidney, Record 7, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-CT1', 'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell', 'source_concept': 'CL:1001285', 'record_number': 7, 'order_number': 1, 'label': 'Descending Vasa Recta Endothelial Cell (Table kidney, Record 7, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM1', 'ccf_pref_label': 'SERPINE2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:8951', 'record_number': 7, 'order_number': 1, 'label': 'SERPINE2 (Table kidney, Record 7, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM2', 'ccf_pref_label': 'TM4SF1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11853', 'record_number': 7, 'order_number': 2, 'label': 'TM4SF1 (Table kidney, Record 7, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM3', 'ccf_pref_label': 'PALMD', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:15846', 'record_number': 7, 'order_number': 3, 'label': 'PALMD (Table kidney, Record 7, Column BM/3)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM4', 'ccf_pref_label': 'ADAMTS6', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:222', 'record_number': 7, 'order_number': 4, 'label': 'ADAMTS6 (Table kidney, Record 7, Column BM/4)', 'type_of': ['BiomarkerRecord']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM5', 'ccf_pref_label': 'UMOD', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:12559', 'record_number': 7, 'order_number': 5, 'label': 'UMOD (Table kidney, Record 7, Column BM/5)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 7', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8', 'record_number': 8, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 8, 'order_number': 1, 'label': 'kidney (Table kidney, Record 8, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 8, 'order_number': 2, 'label': 'renal medulla (Table kidney, Record 8, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS3', 'ccf_pref_label': 'inner medulla of kidney', 'source_concept': 'UBERON:0001294', 'record_number': 8, 'order_number': 3, 'label': 'inner medulla of kidney (Table kidney, Record 8, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS4', 'ccf_pref_label': 'renal papilla', 'source_concept': 'UBERON:0001228', 'record_number': 8, 'order_number': 4, 'label': 'renal papilla (Table kidney, Record 8, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS5', 'ccf_pref_label': 'papillary tip', 'source_concept': 'UBERON:0009095', 'record_number': 8, 'order_number': 5, 'label': 'papillary tip (Table kidney, Record 8, Column AS/5)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-CT1', 'ccf_pref_label': 'Inner Medullary Collecting Duct Cell', 'source_concept': 'CL:1000718', 'record_number': 8, 'order_number': 1, 'label': 'Inner Medullary Collecting Duct Cell (Table kidney, Record 8, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM1', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:634', 'record_number': 8, 'order_number': 1, 'label': 'AQP2 (Table kidney, Record 8, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM2', 'ccf_pref_label': 'SLC14A2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10919', 'record_number': 8, 'order_number': 2, 'label': 'SLC14A2 (Table kidney, Record 8, Column BM/2)', 'type_of': ['BiomarkerRecord']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM3', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:634', 'record_number': 8, 'order_number': 3, 'label': 'AQP2 (Table kidney, Record 8, Column BM/3)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 8', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9', 'record_number': 9, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 9, 'order_number': 1, 'label': 'kidney (Table kidney, Record 9, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS2', 'ccf_pref_label': 'renal cortex', 'source_concept': 'UBERON:0001225', 'record_number': 9, 'order_number': 2, 'label': 'renal cortex (Table kidney, Record 9, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS3', 'ccf_pref_label': 'renal column (column of Bertin)', 'source_concept': 'UBERON:0001284', 'record_number': 9, 'order_number': 3, 'label': 'renal column (column of Bertin) (Table kidney, Record 9, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 9, 'order_number': 4, 'label': 'Glomerular Epithelium (Table kidney, Record 9, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 9, 'order_number': 5, 'label': 'visceral epithelial layer (Table kidney, Record 9, Column AS/5)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 9, 'order_number': 1, 'label': 'Podocyte (Table kidney, Record 9, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 9, 'order_number': 1, 'label': 'NPHS2 (Table kidney, Record 9, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 9, 'order_number': 2, 'label': 'PODXL (Table kidney, Record 9, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 9, 'order_number': 3, 'label': 'NPHS1 (Table kidney, Record 9, Column BM/3)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 9, 'order_number': 4, 'label': 'PTPRQ (Table kidney, Record 9, Column BM/4)', 'type_of': ['BiomarkerRecord']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM5', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:9171', 'record_number': 9, 'order_number': 5, 'label': 'PODXL (Table kidney, Record 9, Column BM/5)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 9', 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10', 'record_number': 10, 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 10, 'order_number': 1, 'label': 'kidney (Table kidney, Record 10, Column AS/1)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 10, 'order_number': 2, 'label': 'renal medulla (Table kidney, Record 10, Column AS/2)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS3', 'ccf_pref_label': 'renal pyramid', 'source_concept': 'UBERON:0004200', 'record_number': 10, 'order_number': 3, 'label': 'renal pyramid (Table kidney, Record 10, Column AS/3)', 'type_of': ['AnatomicalStructureRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS4', 'ccf_pref_label': 'Descending Vasa Recta', 'source_concept': 'UBERON:0009202', 'record_number': 10, 'order_number': 4, 'label': 'Descending Vasa Recta (Table kidney, Record 10, Column AS/4)', 'type_of': ['AnatomicalStructureRecord']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-CT1', 'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell', 'source_concept': 'CL:1001285', 'record_number': 10, 'order_number': 1, 'label': 'Descending Vasa Recta Endothelial Cell (Table kidney, Record 10, Column CT/1)', 'type_of': ['CellTypeRecord']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM1', 'ccf_pref_label': 'SERPINE2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:8951', 'record_number': 10, 'order_number': 1, 'label': 'SERPINE2 (Table kidney, Record 10, Column BM/1)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM2', 'ccf_pref_label': 'TM4SF1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11853', 'record_number': 10, 'order_number': 2, 'label': 'TM4SF1 (Table kidney, Record 10, Column BM/2)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM3', 'ccf_pref_label': 'PALMD', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:15846', 'record_number': 10, 'order_number': 3, 'label': 'PALMD (Table kidney, Record 10, Column BM/3)', 'type_of': ['BiomarkerRecord']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM4', 'ccf_pref_label': 'ADAMTS6', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:222', 'record_number': 10, 'order_number': 4, 'label': 'ADAMTS6 (Table kidney, Record 10, Column BM/4)', 'type_of': ['BiomarkerRecord']}], 'label': 'Table kidney, Record 10', 'type_of': ['AsctbRecord']}

# %% [markdown]
# ## Example 2: Run a SPARQL query via `grlc` with `requests`

# %% [markdown]
# `grlc` retrieves SPARQL queries in [https://github.com/hubmapconsortium/ccf-grlc](https://github.com/hubmapconsortium/ccf-grlc), then allows the user to run these queries like RESTful API endpoints. In this example, we retrieve all the AS, CT, and Bs in the ASCT+B table in the lymph node ([https://purl.humanatlas.io/asct-b/lymph-node](https://purl.humanatlas.io/asct-b/lymph-node)). Our desired format is CSV. The query is documented [here](https://apps.humanatlas.io/api/grlc/hra.html#get-/asctb-in-table).

# %%
# set desired file format
format = "csv" 

# set url
grlc_url = f"https://grlc.io/api-git/hubmapconsortium/ccf-grlc/subdir/hra/asctb-in-table.{format}?asctb=https%3A%2F%2Fpurl.humanatlas.io%2Fasct-b%2Flymph-node"

# set header
headers = {
  "Accept": "text/csv"
}

# make request
response = requests.get(grlc_url)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df.head()
# Out:
#                     as_label                              ct_label bm_label  \
# 0  Afferent lymphatic vessel                    Smooth Muscle Cell    ACTA2
# 1  Afferent lymphatic vessel  Endothelial Cell of Lymphatic Vessel   CLEC4M
# 2  Afferent lymphatic vessel  Endothelial Cell of Lymphatic Vessel  TNFRSF9
# 3  Afferent lymphatic vessel  Endothelial Cell of Lymphatic Vessel    Lyve1
# 4  Afferent lymphatic vessel  Endothelial Cell of Lymphatic Vessel     CAV1
#
#                                               as  \
# 0  http://purl.obolibrary.org/obo/UBERON_0010396
# 1  http://purl.obolibrary.org/obo/UBERON_0010396
# 2  http://purl.obolibrary.org/obo/UBERON_0010396
# 3  http://purl.obolibrary.org/obo/UBERON_0010396
# 4  http://purl.obolibrary.org/obo/UBERON_0010396
#
#                                           ct  \
# 0  http://purl.obolibrary.org/obo/CL_0019017
# 1  http://purl.obolibrary.org/obo/CL_0002138
# 2  http://purl.obolibrary.org/obo/CL_0002138
# 3  http://purl.obolibrary.org/obo/CL_0002138
# 4  http://purl.obolibrary.org/obo/CL_0002138
#
#                                   bm   bmType
# 0    http://identifiers.org/hgnc/130     gene
# 1  http://identifiers.org/hgnc/13523     gene
# 2  http://identifiers.org/hgnc/11924  protein
# 3  http://identifiers.org/hgnc/14687  protein
# 4   http://identifiers.org/hgnc/1527     gene

# %% [markdown]
# ## Example 3: Run your own SPARQL query with `requests`

# %% [markdown]
# (do not use hra-api client), ask for text/csv, parse with csv module

# %%
# In this example, we write our own SPARQL query inline. Alternatively, you could load a query saved in an RQ file.
query = "SELECT * WHERE { ?sub ?pred ?obj . } LIMIT 10" #this is a simple query for all subject, predicate, object triples in the queried graph

# define endpoint
url = "https://lod.humanatlas.io/sparql"

# define parameters
params = {
    "query": query,
}

# set header
headers = {
  "Accept": "text/csv"
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df.head()
# Out:
#                                                  sub  \
# 0  http://protege.stanford.edu/plugins/owl/proteg...
# 1         http://purl.obolibrary.org/obo/BFO_0000002
# 2         http://purl.obolibrary.org/obo/BFO_0000002
# 3         http://purl.obolibrary.org/obo/BFO_0000002
# 4         http://purl.obolibrary.org/obo/BFO_0000002
#
#                                               pred  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1       http://purl.obolibrary.org/obo/IAO_0000115
# 2       http://purl.obolibrary.org/obo/IAO_0000116
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4       http://www.w3.org/2000/01/rdf-schema#label
#
#                                                  obj
# 0   http://www.w3.org/2002/07/owl#AnnotationProperty
# 1  An entity that exists in full at any time in w...
# 2  BFO 2 Reference: Continuant entities are entit...
# 3                http://www.w3.org/2002/07/owl#Class
# 4                                         continuant

# %% [markdown]
# ## Demonstrate how to use the HRA KG either declaratively (via SPARQL) or imperatively (via JSON)

# %% [markdown]
# Juxtapose querying JSON with Python vs SPARQL (faster, cleaner, no for or foreach loops)
#
# - For Python, use kidney.json
#
# - For SPARQL, use code example from "Cells to expect in my anatomical region of interest":
# ```
# #+ summary: All cells that make up the kidney cortex
#
#
# PREFIX ccf: <http://purl.org/ccf/>
# PREFIX kidney_cortex: <http://purl.obolibrary.org/obo/UBERON_0001225>
#
#
# SELECT DISTINCT ?cell_label ?cell_ontology_id
# FROM <https://purl.humanatlas.io/asct-b/kidney>
# WHERE {
#   kidney_cortex: ^ccf:ccf_part_of* ?kidney_cortex_parts .
#   ?cell_ontology_id ccf:ccf_located_in ?kidney_cortex_parts .
#   ?cell_ontology_id ccf:ccf_pref_label ?cell_label .
# }
#
# ```

# %% [markdown]
# In this section, we juxtapose two ways of using data from the HRA KG to retrieve all the cells that make up the kidney cortex:
# 1. imperatively via opening a data product (JSON) in Python
# 2. declaratively via a SPARQL query
#
# While both options have advantages, we will show that the SPARQL query needs fewer lines of code and adds the ability to easily query more than one graph.

# %% [markdown]
# ### Declaratively (via SPARQL)

# %%
query = """
PREFIX ccf: <http://purl.org/ccf/>
PREFIX kidney_cortex: <http://purl.obolibrary.org/obo/UBERON_0001225>


SELECT DISTINCT ?cell_label ?cell_ontology_id
FROM <https://purl.humanatlas.io/asct-b/kidney>
WHERE {
  kidney_cortex: ^ccf:ccf_part_of* ?kidney_cortex_parts .
  # ?cell_ontology_id ccf:ccf_located_in ?kidney_cortex_parts .
  # ?cell_ontology_id ccf:ccf_pref_label ?cell_label .
}
"""

# define endpoint
url = "https://lod.humanatlas.io/sparql"

# define parameters
params = {
    "query": query,
}

# set header
headers = {
  "Accept": "text/csv"
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df.head()
# Out:
#                                           cell_label  \
# 0                                           Podocyte
# 1                           Parietal Epithelial Cell
# 2            Cortical Collecting Duct Principal Cell
# 3  Cortical Collecting Duct Intercalated Cell Type A
#
#                             cell_ontology_id
# 0  http://purl.obolibrary.org/obo/CL_0000653
# 1  http://purl.obolibrary.org/obo/CL_1000452
# 2  http://purl.obolibrary.org/obo/CL_1000714
# 3  http://purl.obolibrary.org/obo/CL_1000715

# %% [markdown]
# ### Imperatively (via JSON)

# %%
# To achieve this in Python, we first need to get the JSON representation of the ASCT+B table for the kidney, then we need to iterate through all rows with the UBERON ID for the kidney cortex, and finally, we need to collect all cell types in a DataFrame.
# get ASCT+B table (note that this is the same procedure as Example 1)
for key, value in list(kidney_json.items())[:n_kvp]:
  print(f"{key}: {value}")
# Out:
# $schema: https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.json
# @context: https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.context.jsonld
# @type: Container
# iri: https://purl.humanatlas.io/asct-b/kidney
# metadata: {'title': 'kidney (v1.5) graph data', 'description': 'The graph representation of the Anatomical Structures, Cell Types, plus Biomarkers (ASCT+B) table for Kidney dataset.', 'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'], 'creation_date': '2024-12-03', 'version': 'v1.5', 'license': 'https://creativecommons.org/licenses/by/4.0/', 'publisher': 'HuBMAP', 'see_also': 'https://lod.humanatlas.io/asct-b/kidney/v1.5/', 'derived_from': 'https://lod.humanatlas.io/asct-b/kidney/v1.5#raw-data'}
# data: {'anatomical_structures': [{'id': 'UBERON:0001062', 'ccf_pref_label': 'UBERON anatomical structure', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'parent_class': 'ccf:AnatomicalStructure'}, {'id': 'FMA:62955', 'ccf_pref_label': 'FMA anatomical structure', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'parent_class': 'ccf:AnatomicalStructure'}, {'id': 'FMA:29733', 'ccf_pref_label': 'General anatomical term', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'parent_class': 'ccf:AnatomicalStructure'}, {'id': 'UBERON:0013702', 'ccf_pref_label': 'body proper', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure'}, {'id': 'UBERON:0004538', 'ccf_pref_label': 'left kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0004539', 'ccf_pref_label': 'right kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0002113', 'ccf_pref_label': 'kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0013702']}, {'id': 'UBERON:0002015', 'ccf_pref_label': 'kidney capsule', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0001225', 'ccf_pref_label': 'cortex of kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0002189', 'ccf_pref_label': 'outer cortex of kidney', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0001225']}, {'id': 'UBERON:0004188', 'ccf_pref_label': 'Glomerular Epithelium', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002189', 'UBERON:0005271', 'UBERON:0001284', 'UBERON:0001229']}, {'id': 'UBERON:0005751', 'ccf_pref_label': 'visceral epithelial layer', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0004188']}, {'id': 'UBERON:0005271', 'ccf_pref_label': 'juxtamedullary cortex', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0001225']}, {'id': 'UBERON:0009883', 'ccf_pref_label': 'medullary ray', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0001225']}, {'id': 'UBERON:0004203', 'ccf_pref_label': 'Collecting Duct (Cortex)', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0009883', 'UBERON:0001232']}, {'id': 'UBERON:0000362', 'ccf_pref_label': 'renal medulla', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0002113']}, {'id': 'UBERON:0004202', 'ccf_pref_label': 'kidney outer medulla outer stripe', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0000362']}, {'id': 'UBERON:0001291', 'ccf_pref_label': 'Loop of Henle (Thick Limb/Medulla)', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0004202', 'UBERON:0001231']}, {'id': 'UBERON:0004201', 'ccf_pref_label': 'kidney outer medulla inner stripe', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0000362']}, {'id': 'UBERON:0001289', 'ccf_pref_label': 'Loop of Henle (Thin Limb)', 'ccf_asctb_type': 'AS', 'ccf_is_provisional': False, 'conforms_to': 'AnatomicalStructure', 'ccf_part_of': ['UBERON:0004201', 'UBERON:0001 ...

# %%
# iterate over rows in ASCT+B table 
for row in kidney_json['data']['asctb_record'][:n_kvp]:
  pprint(row)
# Out:
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                 'label': 'kidney (Table kidney, Record 1, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney capsule',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                 'label': 'kidney capsule (Table kidney, Record '
#                                          '1, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002015',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                      'label': 'stromal cell (Table kidney, Record 1, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 1,
#                      'source_concept': 'CL:0000499',
#                      'type_of': ['CellTypeRecord']},
#                     {'ccf_pref_label': 'capsule mesenchymal stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                      'label': 'capsule mesenchymal stromal cell (Table kidney, '
#                               'Record 1, Column CT/2)',
#                      'order_number': 2,
#                      'record_number': 1,
#                      'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'Foxd1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                        'label': 'Foxd1 (Table kidney, Record 1, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:3802',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'VSX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                        'label': 'VSX2 (Table kidney, Record 1, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:1975',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#  'label': 'Table kidney, Record 1',
#  'record_number': 1,
#  'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                 'label': 'kidney (Table kidney, Record 2, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 2, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'outer cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                 'label': 'outer cortex of kidney (Table '
#                                          'kidney, Record 2, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002189',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 2, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 2, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                      'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 2,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 2, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                        'label': 'PODXL (Table kidney, Record 2, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 2, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 2, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#  'label': 'Table kidney, Record 2',
#  'record_number': 2,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1',
#                                 'label': 'kidney (Table kidney, Record 3, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 3, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'juxtamedullary cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3',
#                                 'label': 'juxtamedullary cortex (Table kidney, '
#                                          'Record 3, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005271',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 3, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 3, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-CT1',
#                      'label': 'Podocyte (Table kidney, Record 3, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 3,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 3, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM2',
#                        'label': 'PODXL (Table kidney, Record 3, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 3, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 3, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3',
#  'label': 'Table kidney, Record 3',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM5',
#                           'label': 'PODXL (Table kidney, Record 3, Column '
#                                    'BM/5)',
#                           'order_number': 5,
#                           'record_number': 3,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 3,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS1',
#                                 'label': 'kidney (Table kidney, Record 4, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 4, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'medullary ray',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS3',
#                                 'label': 'medullary ray (Table kidney, Record '
#                                          '4, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0009883',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Collecting Duct (Cortex)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS4',
#                                 'label': 'Collecting Duct (Cortex) (Table '
#                                          'kidney, Record 4, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0004203',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Cortical Collecting Duct Principal '
#                                        'Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-CT1',
#                      'label': 'Cortical Collecting Duct Principal Cell (Table '
#                               'kidney, Record 4, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 4,
#                      'source_concept': 'CL:1000714',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM1',
#                        'label': 'AQP2 (Table kidney, Record 4, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM2',
#                        'label': 'AQP3 (Table kidney, Record 4, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:636',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FXYD4',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM3',
#                        'label': 'FXYD4 (Table kidney, Record 4, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:4028',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4',
#  'label': 'Table kidney, Record 4',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM4',
#                           'label': 'AQP2 (Table kidney, Record 4, Column BM/4)',
#                           'order_number': 4,
#                           'record_number': 4,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 4,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS1',
#                                 'label': 'kidney (Table kidney, Record 5, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '5, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney outer medulla outer '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS3',
#                                 'label': 'kidney outer medulla outer stripe '
#                                          '(Table kidney, Record 5, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0004202',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Loop of Henle (Thick '
#                                                   'Limb/Medulla)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS4',
#                                 'label': 'Loop of Henle (Thick Limb/Medulla) '
#                                          '(Table kidney, Record 5, Column '
#                                          'AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0001291',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Medullary Thick Ascending Limb Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-CT1',
#                      'label': 'Medullary Thick Ascending Limb Cell (Table '
#                               'kidney, Record 5, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 5,
#                      'source_concept': 'CL:1001108',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC12A1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM1',
#                        'label': 'SLC12A1 (Table kidney, Record 5, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:10910',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'UMOD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM2',
#                        'label': 'UMOD (Table kidney, Record 5, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:12559',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CASR',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM3',
#                        'label': 'CASR (Table kidney, Record 5, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:1514',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5',
#  'label': 'Table kidney, Record 5',
#  'record_number': 5,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS1',
#                                 'label': 'kidney (Table kidney, Record 6, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '6, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney outer medulla inner '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS3',
#                                 'label': 'kidney outer medulla inner stripe '
#                                          '(Table kidney, Record 6, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0004201',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Loop of Henle (Thin Limb)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS4',
#                                 'label': 'Loop of Henle (Thin Limb) (Table '
#                                          'kidney, Record 6, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0001289',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'descending thin limb of '
#                                                   'loop of Henle 2',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS5',
#                                 'label': 'descending thin limb of loop of '
#                                          'Henle 2 (Table kidney, Record 6, '
#                                          'Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:8600036',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Thin Limb Cell Type 2',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-CT1',
#                      'label': 'Descending Thin Limb Cell Type 2 (Table kidney, '
#                               'Record 6, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 6,
#                      'source_concept': 'CL:4030013',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CRYAB',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM1',
#                        'label': 'CRYAB (Table kidney, Record 6, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:2389',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC39A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM2',
#                        'label': 'SLC39A8 (Table kidney, Record 6, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:20862',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM3',
#                        'label': 'TACSTD2 (Table kidney, Record 6, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM4',
#                        'label': 'AQP1 (Table kidney, Record 6, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:633',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC9A3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM5',
#                        'label': 'SLC9A3 (Table kidney, Record 6, Column BM/5)',
#                        'order_number': 5,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11073',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6',
#  'label': 'Table kidney, Record 6',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP1',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM6',
#                           'label': 'AQP1 (Table kidney, Record 6, Column BM/6)',
#                           'order_number': 6,
#                           'record_number': 6,
#                           'source_concept': 'HGNC:633',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 6,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS1',
#                                 'label': 'kidney (Table kidney, Record 7, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '7, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS3',
#                                 'label': 'inner medulla of kidney (Table '
#                                          'kidney, Record 7, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS4',
#                                 'label': 'Descending Vasa Recta (Table kidney, '
#                                          'Record 7, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-CT1',
#                      'label': 'Descending Vasa Recta Endothelial Cell (Table '
#                               'kidney, Record 7, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 7,
#                      'source_concept': 'CL:1001285',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SERPINE2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM1',
#                        'label': 'SERPINE2 (Table kidney, Record 7, Column '
#                                 'BM/1)',
#                        'order_number': 1,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:8951',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TM4SF1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM2',
#                        'label': 'TM4SF1 (Table kidney, Record 7, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:11853',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PALMD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM3',
#                        'label': 'PALMD (Table kidney, Record 7, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:15846',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'ADAMTS6',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM4',
#                        'label': 'ADAMTS6 (Table kidney, Record 7, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:222',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7',
#  'label': 'Table kidney, Record 7',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'UMOD',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM5',
#                           'label': 'UMOD (Table kidney, Record 7, Column BM/5)',
#                           'order_number': 5,
#                           'record_number': 7,
#                           'source_concept': 'HGNC:12559',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 7,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS1',
#                                 'label': 'kidney (Table kidney, Record 8, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '8, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS3',
#                                 'label': 'inner medulla of kidney (Table '
#                                          'kidney, Record 8, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS4',
#                                 'label': 'renal papilla (Table kidney, Record '
#                                          '8, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'papillary tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS5',
#                                 'label': 'papillary tip (Table kidney, Record '
#                                          '8, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Inner Medullary Collecting Duct Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-CT1',
#                      'label': 'Inner Medullary Collecting Duct Cell (Table '
#                               'kidney, Record 8, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 8,
#                      'source_concept': 'CL:1000718',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM1',
#                        'label': 'AQP2 (Table kidney, Record 8, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC14A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM2',
#                        'label': 'SLC14A2 (Table kidney, Record 8, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:10919',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8',
#  'label': 'Table kidney, Record 8',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM3',
#                           'label': 'AQP2 (Table kidney, Record 8, Column BM/3)',
#                           'order_number': 3,
#                           'record_number': 8,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 8,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS1',
#                                 'label': 'kidney (Table kidney, Record 9, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS2',
#                                 'label': 'renal cortex (Table kidney, Record '
#                                          '9, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal column (column of '
#                                                   'Bertin)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS3',
#                                 'label': 'renal column (column of Bertin) '
#                                          '(Table kidney, Record 9, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001284',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 9, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 9, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-CT1',
#                      'label': 'Podocyte (Table kidney, Record 9, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 9,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 9, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM2',
#                        'label': 'PODXL (Table kidney, Record 9, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 9, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 9, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9',
#  'label': 'Table kidney, Record 9',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM5',
#                           'label': 'PODXL (Table kidney, Record 9, Column '
#                                    'BM/5)',
#                           'order_number': 5,
#                           'record_number': 9,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 9,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS1',
#                                 'label': 'kidney (Table kidney, Record 10, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '10, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal pyramid',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS3',
#                                 'label': 'renal pyramid (Table kidney, Record '
#                                          '10, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0004200',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS4',
#                                 'label': 'Descending Vasa Recta (Table kidney, '
#                                          'Record 10, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-CT1',
#                      'label': 'Descending Vasa Recta Endothelial Cell (Table '
#                               'kidney, Record 10, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 10,
#                      'source_concept': 'CL:1001285',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SERPINE2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM1',
#                        'label': 'SERPINE2 (Table kidney, Record 10, Column '
#                                 'BM/1)',
#                        'order_number': 1,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:8951',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TM4SF1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM2',
#                        'label': 'TM4SF1 (Table kidney, Record 10, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:11853',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PALMD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM3',
#                        'label': 'PALMD (Table kidney, Record 10, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:15846',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'ADAMTS6',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM4',
#                        'label': 'ADAMTS6 (Table kidney, Record 10, Column '
#                                 'BM/4)',
#                        'order_number': 4,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:222',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10',
#  'label': 'Table kidney, Record 10',
#  'record_number': 10,
#  'type_of': ['AsctbRecord']}

# %%
# get all rows with kidney cortex
cortex_id = "UBERON:0001225"

# %%
# find all AS IDs with a connection to the cortex
def find_connected_ids(kidney_data, cortex_id, collected_ids=None):
  """_summary_

  Args:
      kidney_data (json): table as JSON
      cortex_id (str): AS ID
      collected_ids (set(), optional): A set of IDs. Defaults to None.

  Returns:
       collected_ids (set()): A set of IDs. Defaults to None.
  """
  if collected_ids is None:
      collected_ids = set()

  new_ids = set()

  # Loop through each anatomical structure to find connections to cortex_id
  for structure in kidney_data['data']['anatomical_structures']:
      try:
          # If the cortex_id is in the 'ccf_part_of' list, add the structure's ID
          if cortex_id in structure['ccf_part_of'] and structure['id'] not in collected_ids:
              new_ids.add(structure['id'])
      except KeyError:
          # Skip if 'ccf_part_of' key doesn't exist
          pass

  # If no new IDs are found, return the collected set
  if not new_ids:
      return collected_ids

  # Add newly found IDs to collected_ids
  collected_ids.update(new_ids)

  # Recursively find connections for each new ID found
  for new_id in new_ids:
      find_connected_ids(kidney_data, new_id, collected_ids)

  return collected_ids


# Example usage
ids_with_connection_to_cortex = find_connected_ids(kidney_json, cortex_id)
pprint(ids_with_connection_to_cortex)
# Out:
# {'UBERON:0001284',
#  'UBERON:0002189',
#  'UBERON:0004188',
#  'UBERON:0004203',
#  'UBERON:0005271',
#  'UBERON:0005750',
#  'UBERON:0005751',
#  'UBERON:0009883'}

# %%
# check connections to cortex
def check_relationships(id: str):
  """Checks if the provided IRI is connected to the cortex
  Args:
      id (str): an IRI (UBERON or FMA)
  Returns:
      check (bool): checks whether there is a connection
  """

  check = False
  for entry in kidney_json['data']['anatomical_structures']:
    if entry['id'] == id:
      try:
        if cortex_id in entry['ccf_part_of']:
          check = True
      except:
        pass

  return check

# %%
# initialize dict for result
result = {
  "cell_label": [],
  "cell_ontology_id": []
}

# initialize list for all asctb_records with cortex
relevant_records = []

for record in kidney_json['data']['asctb_record']:
  for row in record['anatomical_structure_list']:
    if (cortex_id in row['source_concept'] or cortex_id in row['type_of'] or check_relationships(row['source_concept']) or row['source_concept'] in ids_with_connection_to_cortex):
      relevant_records.append(record['cell_type_list'])
    
# use list comprehension to simply the list of cell types
list_flattened = [record for sublist in relevant_records for record in sublist]
pprint(list_flattened[:3])
# Out:
# [{'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CellTypeRecord']},
#  {'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CellTypeRecord']},
#  {'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CellTypeRecord']}]

# %%
# prefix for OBO PURL
prefix = "http://purl.obolibrary.org/obo/"

# capture result in dict
for cell_type in list_flattened:
  result['cell_label'].append(cell_type['ccf_pref_label'])
  result['cell_ontology_id'].append(prefix+cell_type['source_concept'])
  
# convert to dataframe
df = pd.DataFrame(result).drop_duplicates(subset="cell_ontology_id")
df
# Out:
#                                            cell_label  \
# 0                                            Podocyte
# 8             Cortical Collecting Duct Principal Cell
# 15                           Parietal Epithelial Cell
# 20  Cortical Collecting Duct Intercalated Cell Type A
#
#                              cell_ontology_id
# 0   http://purl.obolibrary.org/obo/CL:0000653
# 8   http://purl.obolibrary.org/obo/CL:1000714
# 15  http://purl.obolibrary.org/obo/CL:1000452
# 20  http://purl.obolibrary.org/obo/CL:1000715
