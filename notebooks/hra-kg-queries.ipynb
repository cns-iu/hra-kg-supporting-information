# %% [markdown]
# ## A notebook to query the HRA Knowledge Graph (KG)

# %%
# install packages
# %pip install requests pandas

# import external packages
import requests
import pandas as pd

# import built-in packages
import json
from pprint import pprint
from io import StringIO
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (2.32.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ## Example 1: Get an HRA Digital Object (DO) as a JSON file

# %% [markdown]
# In this example, we will retrieve an anatomical structures (AS), cell types (CT), plus biomarkers (B) table (ASCT+B, see [this paper](https://www.nature.com/articles/s41556-021-00788-6)) as a JSON file. As part of the HRA Digital Object (DO) processing pipeline, we perform normalization and enrichment. When we normalize, we convert every DO into a standard format that follows schemas defined in [LinkML](https://linkml.io/). The default file format for normalized data is [YAML](https://yaml.org/), which can readily be converted to JSON. This would almost be enough as is, but the current models were not fully designed for end users. It was created as a way to generate RDF graphs. So, there are some artifacts of this in the models themselves, which may make them hard to understand. However, with some clean-up, the HRA data is accessible and useful for end users with varying degrees of programming and analysis experience. LinkML can also generate a JSON-LD Context and a JSON Schema (see [https://json-schema.org/](https://json-schema.org/)), which we can then attach to the JSON files to make them validatable, easily convert them to RDF, and to provide autocomplete as well as documentation inline in code editors like VS Code, and to generate online documentation.

# %%
# Each HRA DO has a persistent URL (PURL), where the user is served HRA DO data after server-side content negotation
# This is the PURL for the ASCT+B table for the kidney
url = "https://purl.humanatlas.io/asct-b/kidney"

# set headers
headers = {
  "Accept" : "application/json"
}

# make request, parse response
response = requests.get(url, headers=headers)

# delete this once HRA DO JSONs are deployed
kidney_json = json.loads(response.text)
pprint(kidney_json)
# Out:
# {'$schema': 'https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.json',
#  '@context': 'https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.context.jsonld',
#  '@type': 'Container',
#  'data': {'anatomical_structures': [{'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'UBERON anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001062',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'FMA anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:62955',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'General anatomical '
#                                                        'term',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:29733',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'body proper',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0013702'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'left kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004538'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'right kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004539'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0013702'],
#                                      'ccf_pref_label': 'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002113'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'kidney capsule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002015'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001225'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'outer cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002189'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002189',
#                                                      'UBERON:0005271',
#                                                      'UBERON:0001284',
#                                                      'UBERON:0001229'],
#                                      'ccf_pref_label': 'Glomerular Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004188'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'visceral epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005751'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'juxtamedullary cortex',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005271'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'medullary ray',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009883'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0009883',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct '
#                                                        '(Cortex)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004203'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal medulla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000362'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'outer stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004202',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thick '
#                                                        'Limb/Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001291'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'inner stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004201'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004201',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001289'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600036'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'inner medulla of '
#                                                        'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0004200',
#                                                      'UBERON:0004726'],
#                                      'ccf_pref_label': 'Descending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'renal papilla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001228'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001228'],
#                                      'ccf_pref_label': 'papillary tip',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009095'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'renal column (column '
#                                                        'of Bertin)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001284'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'renal pyramid',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004200'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'nephron',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001285'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Renal Corpuscle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001229'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'parietal epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005750'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229'],
#                                      'ccf_pref_label': 'renal glomerulus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000074'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000074'],
#                                      'ccf_pref_label': 'Glomerulus Vasculature',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004190'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004190'],
#                                      'ccf_pref_label': 'glomerular capillary '
#                                                        'endothelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'Interstitium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005215'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005215'],
#                                      'ccf_pref_label': 'Proximal Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002319'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002319'],
#                                      'ccf_pref_label': 'glomerular mesangium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002320'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001231'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'proximal tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004134'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004196'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004197'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal straight '
#                                                        'tubule segment 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001290'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005096'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005099'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600037'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004193'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001291'],
#                                      'ccf_pref_label': 'Macula Densa',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002335'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Distal Convolution',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001292'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Connecting Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005097'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal collecting '
#                                                        'system',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004100'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004100',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001232'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Outer '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004204'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Inner '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004205'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'Vessels',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0006544'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Blood Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003517'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517',
#                                                      'UBERON:0009202',
#                                                      'UBERON:0009091'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001986'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0034884'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Afferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004639'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Efferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004640'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003527'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003527'],
#                                      'ccf_pref_label': 'Peritubular Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005272'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005272'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0012441'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004726'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004726'],
#                                      'ccf_pref_label': 'Ascending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009091'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Lymphatic '
#                                                        'Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel',
#                                      'label': 'Kidney Lymphatic Vessel',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002042'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Apparatus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002303'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0009095'],
#                                      'ccf_pref_label': 'Papillary Tip '
#                                                        'Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                      'label': 'Papillary Tip Epithelium',
#                                      'parent_class': 'ccf:AnatomicalStructure'}],
#           'asctb_record': [{'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                                            'label': 'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 1, '
#                                                                     'Column '
#                                                                     'AS/1)',
#                                                            'order_number': 1,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'kidney '
#                                                                              'capsule',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                                            'label': 'kidney '
#                                                                     'capsule '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 1, '
#                                                                     'Column '
#                                                                     'AS/2)',
#                                                            'order_number': 2,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002015',
#                                                            'type_of': ['AnatomicalStructureRecord']}],
#                             'cell_type_list': [{'ccf_pref_label': 'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                                                 'label': 'stromal cell (Table '
#                                                          'kidney, Record 1, '
#                                                          'Column CT/1)',
#                                                 'order_number': 1,
#                                                 'record_number': 1,
#                                                 'source_concept': 'CL:0000499',
#                                                 'type_of': ['CellTypeRecord']},
#                                                {'ccf_pref_label': 'capsule '
#                                                                   'mesenchymal '
#                                                                   'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                                                 'label': 'capsule mesenchymal '
#                                                          'stromal cell (Table '
#                                                          'kidney, Record 1, '
#                                                          'Column CT/2)',
#                                                 'order_number': 2,
#                                                 'record_number': 1,
#                                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                                                 'type_of': ['CellTypeRecord']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'Foxd1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                                                   'label': 'Foxd1 (Table '
#                                                            'kidney, Record 1, '
#                                                            'Column BM/1)',
#                                                   'order_number': 1,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:3802',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'VSX2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                                                   'label': 'VSX2 (Table '
#                                                            'kidney, Record 1, '
#                                                            'Column BM/2)',
#                                                   'order_number': 2,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:1975',
#                                                   'type_of': ['BiomarkerRecord']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#                             'label': 'Table kidney, Record 1',
#                             'record_number': 1,
#                             'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                                            'label': 'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/1)',
#                                                            'order_number': 1,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                                            'label': 'cortex of '
#                                                                     'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/2)',
#                                                            'order_number': 2,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0001225',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'outer '
#                                                                              'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                                            'label': 'outer '
#                                                                     'cortex of '
#                                                                     'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/3)',
#                                                            'order_number': 3,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002189',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'Glomerular '
#                                                                              'Epithelium',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                                            'label': 'Glomerular '
#                                                                     'Epithelium '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/4)',
#                                                            'order_number': 4,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0004188',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'visceral '
#                                                                              'epithelial '
#                                                                              'layer',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                                            'label': 'visceral '
#                                                                     'epithelial '
#                                                                     'layer '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/5)',
#                                                            'order_number': 5,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0005751',
#                                                            'type_of': ['AnatomicalStructureRecord']}],
#                             'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                                                 'label': 'Podocyte (Table '
#                                                          'kidney, Record 2, '
#                                                          'Column CT/1)',
#                                                 'order_number': 1,
#                                                 'record_number': 2,
#                                                 'source_concept': 'CL:0000653',
#                                                 'type_of': ['CellTypeRecord']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                                                   'label': 'NPHS2 (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/1)',
#                                                   'order_number': 1,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:13394',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PODXL',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                                                   'label': 'PODXL (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/2)',
#                                                   'order_number': 2,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9171',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                                                   'label': 'NPHS1 (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/3)',
#                                                   'order_number': 3,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:7908',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PTPRQ',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                                                   'label': 'PTPRQ (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/4)',
#                                                   'order_number': 4,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9679',
#                                                   'type_of': ['BiomarkerRecord']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#                             'label': 'Table kidney, Record 2',
#                             'record_number': 2,
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
# ...
#                           'id': 'CL:0000814'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (general)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:613',
#                                                                          'HGNC:1636',
#                                                                          'HGNC:1638',
#                                                                          'HGNC:3609',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0001056'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (classical)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6152',
#                                                                          'HGNC:3765',
#                                                                          'HGNC:26705'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1084/jem.20030323',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000990'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (plasmatoid)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6012',
#                                                                          'HGNC:3765'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2']}],
#                           'id': 'CL:0001058'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:1241',
#                                                                          'HGNC:4947',
#                                                                          'HGNC:6152'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000576'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'mononuclear phagocyte',
#                           'conforms_to': 'CellType',
#                           'id': 'CL:0000113'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000113'],
#                           'ccf_is_provisional': True,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte Derived Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:7376',
#                                                                          'HGNC:6152',
#                                                                          'HGNC:4942',
#                                                                          'HGNC:4948',
#                                                                          'HGNC:2435',
#                                                                          'HGNC:1628',
#                                                                          'HGNC:12339']}],
#                           'id': 'https://purl.org/ccf/ASCTB-TEMP_monocyte-derived-cell',
#                           'label': 'Monocyte Derived Cell',
#                           'parent_class': 'ccf:CellType'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:16892',
#                                                                          'HGNC:1673',
#                                                                          'HGNC:1675',
#                                                                          'HGNC:11935',
#                                                                          'HGNC:1677'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000084'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Cytotoxic T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:4708',
#                                                                          'HGNC:10630',
#                                                                          'HGNC:10632'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000910'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'regulatory T cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6106']}],
#                           'id': 'CL:0000815'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'B cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:5713',
#                                                                          'HGNC:1698',
#                                                                          'HGNC:7315',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000236'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Plasma cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:30125',
#                                                                          'HGNC:18508',
#                                                                          'HGNC:5713',
#                                                                          'HGNC:5716'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000786'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Neutrophil',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:10499',
#                                                                          'HGNC:10498',
#                                                                          'HGNC:3620',
#                                                                          'HGNC:2439'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1016/j.exphem.2016.10.008',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000775'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Mast cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6342',
#                                                                          'HGNC:2298',
#                                                                          'HGNC:7316'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000097'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0001228',
#                                              'UBERON:0009095',
#                                              'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium'],
#                           'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6442',
#                                                                          'HGNC:15979',
#                                                                          'HGNC:4554',
#                                                                          'HGNC:11530']}],
#                           'id': 'CL:1000597'}]},
#  'iri': 'https://purl.humanatlas.io/asct-b/kidney',
#  'metadata': {'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'],
#               'creation_date': '2024-11-22',
#               'derived_from': 'https://lod.humanatlas.io/asct-b/kidney/v1.5#raw-data',
#               'description': 'The graph representation of the Anatomical '
#                              'Structures, Cell Types, plus Biomarkers (ASCT+B) '
#                              'table for Kidney dataset.',
#               'license': 'https://creativecommons.org/licenses/by/4.0/',
#               'publisher': 'HuBMAP',
#               'see_also': 'https://lod.humanatlas.io/asct-b/kidney/v1.5/',
#               'title': 'kidney (v1.5) graph data',
#               'version': 'v1.5'}}

# %%
# The resulting JSON file has these keys:
kidney_json.keys()
# Out:
# dict_keys(['$schema', '@context', '@type', 'iri', 'metadata', 'data'])

# %%
# Now we iterate over all the rows in ASCT+B table
for row in kidney_json['data']['asctb_record']:
  pprint(row)
# Out:
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                 'label': 'kidney (Table kidney, Record 1, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney capsule',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                 'label': 'kidney capsule (Table kidney, Record '
#                                          '1, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002015',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                      'label': 'stromal cell (Table kidney, Record 1, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 1,
#                      'source_concept': 'CL:0000499',
#                      'type_of': ['CellTypeRecord']},
#                     {'ccf_pref_label': 'capsule mesenchymal stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                      'label': 'capsule mesenchymal stromal cell (Table kidney, '
#                               'Record 1, Column CT/2)',
#                      'order_number': 2,
#                      'record_number': 1,
#                      'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'Foxd1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                        'label': 'Foxd1 (Table kidney, Record 1, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:3802',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'VSX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                        'label': 'VSX2 (Table kidney, Record 1, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:1975',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#  'label': 'Table kidney, Record 1',
#  'record_number': 1,
#  'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                 'label': 'kidney (Table kidney, Record 2, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 2, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'outer cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                 'label': 'outer cortex of kidney (Table '
#                                          'kidney, Record 2, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002189',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 2, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 2, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                      'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 2,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 2, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                        'label': 'PODXL (Table kidney, Record 2, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 2, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 2, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#  'label': 'Table kidney, Record 2',
#  'record_number': 2,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1',
#                                 'label': 'kidney (Table kidney, Record 3, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 3, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'juxtamedullary cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3',
#                                 'label': 'juxtamedullary cortex (Table kidney, '
#                                          'Record 3, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005271',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 3, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 3, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-CT1',
#                      'label': 'Podocyte (Table kidney, Record 3, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 3,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 3, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM2',
#                        'label': 'PODXL (Table kidney, Record 3, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 3, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 3, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3',
#  'label': 'Table kidney, Record 3',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM5',
#                           'label': 'PODXL (Table kidney, Record 3, Column '
#                                    'BM/5)',
#                           'order_number': 5,
#                           'record_number': 3,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 3,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS1',
#                                 'label': 'kidney (Table kidney, Record 4, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 4, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'medullary ray',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS3',
#                                 'label': 'medullary ray (Table kidney, Record '
#                                          '4, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0009883',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Collecting Duct (Cortex)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS4',
#                                 'label': 'Collecting Duct (Cortex) (Table '
#                                          'kidney, Record 4, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0004203',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Cortical Collecting Duct Principal '
#                                        'Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-CT1',
#                      'label': 'Cortical Collecting Duct Principal Cell (Table '
#                               'kidney, Record 4, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 4,
#                      'source_concept': 'CL:1000714',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM1',
#                        'label': 'AQP2 (Table kidney, Record 4, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM2',
#                        'label': 'AQP3 (Table kidney, Record 4, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:636',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FXYD4',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM3',
#                        'label': 'FXYD4 (Table kidney, Record 4, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:4028',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4',
#  'label': 'Table kidney, Record 4',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM4',
#                           'label': 'AQP2 (Table kidney, Record 4, Column BM/4)',
#                           'order_number': 4,
#                           'record_number': 4,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 4,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS1',
#                                 'label': 'kidney (Table kidney, Record 5, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '5, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney outer medulla outer '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS3',
#                                 'label': 'kidney outer medulla outer stripe '
#                                          '(Table kidney, Record 5, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0004202',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Loop of Henle (Thick '
#                                                   'Limb/Medulla)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS4',
#                                 'label': 'Loop of Henle (Thick Limb/Medulla) '
#                                          '(Table kidney, Record 5, Column '
#                                          'AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0001291',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Medullary Thick Ascending Limb Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-CT1',
#                      'label': 'Medullary Thick Ascending Limb Cell (Table '
#                               'kidney, Record 5, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 5,
#                      'source_concept': 'CL:1001108',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC12A1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM1',
#                        'label': 'SLC12A1 (Table kidney, Record 5, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:10910',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'UMOD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM2',
#                        'label': 'UMOD (Table kidney, Record 5, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:12559',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CASR',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM3',
#                        'label': 'CASR (Table kidney, Record 5, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:1514',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5',
#  'label': 'Table kidney, Record 5',
#  'record_number': 5,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS1',
#                                 'label': 'kidney (Table kidney, Record 6, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '6, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney outer medulla inner '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS3',
#                                 'label': 'kidney outer medulla inner stripe '
#                                          '(Table kidney, Record 6, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0004201',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Loop of Henle (Thin Limb)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS4',
#                                 'label': 'Loop of Henle (Thin Limb) (Table '
#                                          'kidney, Record 6, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0001289',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'descending thin limb of '
#                                                   'loop of Henle 2',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS5',
#                                 'label': 'descending thin limb of loop of '
#                                          'Henle 2 (Table kidney, Record 6, '
#                                          'Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:8600036',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Thin Limb Cell Type 2',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-CT1',
#                      'label': 'Descending Thin Limb Cell Type 2 (Table kidney, '
#                               'Record 6, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 6,
#                      'source_concept': 'CL:4030013',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CRYAB',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM1',
#                        'label': 'CRYAB (Table kidney, Record 6, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:2389',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC39A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM2',
#                        'label': 'SLC39A8 (Table kidney, Record 6, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:20862',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM3',
#                        'label': 'TACSTD2 (Table kidney, Record 6, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM4',
#                        'label': 'AQP1 (Table kidney, Record 6, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:633',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC9A3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM5',
#                        'label': 'SLC9A3 (Table kidney, Record 6, Column BM/5)',
#                        'order_number': 5,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11073',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6',
#  'label': 'Table kidney, Record 6',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP1',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM6',
#                           'label': 'AQP1 (Table kidney, Record 6, Column BM/6)',
#                           'order_number': 6,
#                           'record_number': 6,
#                           'source_concept': 'HGNC:633',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 6,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS1',
#                                 'label': 'kidney (Table kidney, Record 7, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '7, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS3',
#                                 'label': 'inner medulla of kidney (Table '
#                                          'kidney, Record 7, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS4',
#                                 'label': 'Descending Vasa Recta (Table kidney, '
#                                          'Record 7, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-CT1',
#                      'label': 'Descending Vasa Recta Endothelial Cell (Table '
#                               'kidney, Record 7, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 7,
#                      'source_concept': 'CL:1001285',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SERPINE2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM1',
#                        'label': 'SERPINE2 (Table kidney, Record 7, Column '
#                                 'BM/1)',
#                        'order_number': 1,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:8951',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TM4SF1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM2',
#                        'label': 'TM4SF1 (Table kidney, Record 7, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:11853',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PALMD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM3',
#                        'label': 'PALMD (Table kidney, Record 7, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:15846',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'ADAMTS6',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM4',
#                        'label': 'ADAMTS6 (Table kidney, Record 7, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:222',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7',
#  'label': 'Table kidney, Record 7',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'UMOD',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM5',
#                           'label': 'UMOD (Table kidney, Record 7, Column BM/5)',
#                           'order_number': 5,
#                           'record_number': 7,
#                           'source_concept': 'HGNC:12559',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 7,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS1',
#                                 'label': 'kidney (Table kidney, Record 8, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '8, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS3',
#                                 'label': 'inner medulla of kidney (Table '
#                                          'kidney, Record 8, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS4',
#                                 'label': 'renal papilla (Table kidney, Record '
#                                          '8, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'papillary tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS5',
#                                 'label': 'papillary tip (Table kidney, Record '
#                                          '8, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Inner Medullary Collecting Duct Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-CT1',
#                      'label': 'Inner Medullary Collecting Duct Cell (Table '
#                               'kidney, Record 8, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 8,
#                      'source_concept': 'CL:1000718',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM1',
#                        'label': 'AQP2 (Table kidney, Record 8, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC14A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM2',
#                        'label': 'SLC14A2 (Table kidney, Record 8, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:10919',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8',
#  'label': 'Table kidney, Record 8',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM3',
#                           'label': 'AQP2 (Table kidney, Record 8, Column BM/3)',
#                           'order_number': 3,
#                           'record_number': 8,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 8,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS1',
#                                 'label': 'kidney (Table kidney, Record 9, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS2',
#                                 'label': 'renal cortex (Table kidney, Record '
#                                          '9, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal column (column of '
#                                                   'Bertin)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS3',
#                                 'label': 'renal column (column of Bertin) '
#                                          '(Table kidney, Record 9, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001284',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 9, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 9, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-CT1',
#                      'label': 'Podocyte (Table kidney, Record 9, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 9,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 9, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM2',
#                        'label': 'PODXL (Table kidney, Record 9, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 9, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 9, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9',
#  'label': 'Table kidney, Record 9',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM5',
#                           'label': 'PODXL (Table kidney, Record 9, Column '
#                                    'BM/5)',
#                           'order_number': 5,
#                           'record_number': 9,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 9,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS1',
#                                 'label': 'kidney (Table kidney, Record 10, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '10, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal pyramid',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS3',
#                                 'label': 'renal pyramid (Table kidney, Record '
#                                          '10, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0004200',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS4',
#                                 'label': 'Descending Vasa Recta (Table kidney, '
#                                          'Record 10, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-CT1',
# ...
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 75,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-AS2',
#                                 'label': 'Interstitium (Table kidney, Record '
#                                          '75, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 75,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Plasma cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-CT1',
#                      'label': 'Plasma cell (Table kidney, Record 75, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 75,
#                      'source_concept': 'CL:0000786',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'MZB1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM1',
#                        'label': 'MZB1 (Table kidney, Record 75, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:30125',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FCRL5',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM2',
#                        'label': 'FCRL5 (Table kidney, Record 75, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:18508',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'JCHAIN',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM3',
#                        'label': 'JCHAIN (Table kidney, Record 75, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:5713',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'IGKC',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM4',
#                        'label': 'IGKC (Table kidney, Record 75, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:5716',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75',
#  'label': 'Table kidney, Record 75',
#  'record_number': 75,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS1',
#                                 'label': 'kidney (Table kidney, Record 76, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 76,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS2',
#                                 'label': 'Interstitium (Table kidney, Record '
#                                          '76, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 76,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Neutrophil',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-CT1',
#                      'label': 'Neutrophil (Table kidney, Record 76, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 76,
#                      'source_concept': 'CL:0000775',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'S100A9',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM1',
#                        'label': 'S100A9 (Table kidney, Record 76, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:10499',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'S100A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM2',
#                        'label': 'S100A8 (Table kidney, Record 76, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:10498',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FCGR3B',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM3',
#                        'label': 'FCGR3B (Table kidney, Record 76, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:3620',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CSF3R',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM4',
#                        'label': 'CSF3R (Table kidney, Record 76, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:2439',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76',
#  'label': 'Table kidney, Record 76',
#  'record_number': 76,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1016/j.exphem.2016.10.008',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS1',
#                                 'label': 'kidney (Table kidney, Record 77, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 77,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS2',
#                                 'label': 'Interstitium (Table kidney, Record '
#                                          '77, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 77,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Mast cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-CT1',
#                      'label': 'Mast cell (Table kidney, Record 77, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 77,
#                      'source_concept': 'CL:0000097',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'KIT',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM1',
#                        'label': 'KIT (Table kidney, Record 77, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:6342',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CPA3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM2',
#                        'label': 'CPA3 (Table kidney, Record 77, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:2298',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'MS4A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM3',
#                        'label': 'MS4A2 (Table kidney, Record 77, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:7316',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77',
#  'label': 'Table kidney, Record 77',
#  'record_number': 77,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS1',
#                                 'label': 'kidney (Table kidney, Record 78, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS2',
#                                 'label': 'Papilla (Table kidney, Record 78, '
#                                          'Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Papillary Tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS3',
#                                 'label': 'Papillary Tip (Table kidney, Record '
#                                          '78, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Papillary Tip Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS4',
#                                 'label': 'Papillary Tip Epithelium (Table '
#                                          'kidney, Record 78, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 78,
#                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-CT1',
#                      'label': 'Papillary Tip Epithelial Cell (Table kidney, '
#                               'Record 78, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 78,
#                      'source_concept': 'CL:1000597',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'KRT5',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM1',
#                        'label': 'KRT5 (Table kidney, Record 78, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:6442',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TP63',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM2',
#                        'label': 'TP63 (Table kidney, Record 78, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:15979',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'GPX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM3',
#                        'label': 'GPX2 (Table kidney, Record 78, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:4554',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM4',
#                        'label': 'TACSTD2 (Table kidney, Record 78, Column '
#                                 'BM/4)',
#                        'order_number': 4,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'GPX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM5',
#                        'label': 'GPX2 (Table kidney, Record 78, Column BM/5)',
#                        'order_number': 5,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:4554',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78',
#  'label': 'Table kidney, Record 78',
#  'record_number': 78,
#  'type_of': ['AsctbRecord']}

# %% [markdown]
# ## Example 2: Run a SPARQL query via `grlc` with `requests`

# %% [markdown]
# `grlc` retrieves SPARQL queries in [https://github.com/hubmapconsortium/ccf-grlc](https://github.com/hubmapconsortium/ccf-grlc), then allows the user to run these queries like RESTful API endpoints. In this example, we retrieve all the AS, CT, and Bs in the ASCT+B table in the lymph node ([https://purl.humanatlas.io/asct-b/lymph-node](https://purl.humanatlas.io/asct-b/lymph-node)). Our desired format is CSV. The query is documented [here](https://apps.humanatlas.io/api/grlc/hra.html#get-/asctb-in-table).

# %%
# set desired file format
format = "csv" 

# set url
grlc_url = f"https://grlc.io/api-git/hubmapconsortium/ccf-grlc/subdir/hra/asctb-in-table.{format}?asctb=https%3A%2F%2Fpurl.humanatlas.io%2Fasct-b%2Flymph-node"

# set header
headers = {
  "Accept": "text/csv"
}

# make request
response = requests.get(grlc_url)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df
# Out:
#                        as_label  \
# 0     Afferent lymphatic vessel
# 1     Afferent lymphatic vessel
# 2     Afferent lymphatic vessel
# 3     Afferent lymphatic vessel
# 4     Afferent lymphatic vessel
# ...                         ...
# 2325                 lymph node
# 2326                 lymph node
# 2327                 lymph node
# 2328                 lymph node
# 2329                 lymph node
#
#                                                ct_label   bm_label  \
# 0                  Endothelial Cell of Lymphatic Vessel    TNFRSF9
# 1                                    Smooth Muscle Cell      ACTA2
# 2                  Endothelial Cell of Lymphatic Vessel      Lyve1
# 3                  Endothelial Cell of Lymphatic Vessel       CAV1
# 4                  Endothelial Cell of Lymphatic Vessel     CLEC4M
# ...                                                 ...        ...
# 2325  Lymphatic Endothelial Cell-Subcapsular Sinus F...       NT5E
# 2326  Lymphatic Endothelial Cell-Subcapsular Sinus F...  Claudin11
# 2327                      Blood Vessel Endothelial Cell      CD123
# 2328  Lymphatic Endothelial Cell-Subcapsular Sinus F...      MFAP4
# 2329  Lymphatic Endothelial Cell-Subcapsular Sinus F...       CD45
#
#                                                  as  \
# 0     http://purl.obolibrary.org/obo/UBERON_0010396
# 1     http://purl.obolibrary.org/obo/UBERON_0010396
# 2     http://purl.obolibrary.org/obo/UBERON_0010396
# 3     http://purl.obolibrary.org/obo/UBERON_0010396
# 4     http://purl.obolibrary.org/obo/UBERON_0010396
# ...                                             ...
# 2325  http://purl.obolibrary.org/obo/UBERON_0000029
# 2326  http://purl.obolibrary.org/obo/UBERON_0000029
# 2327  http://purl.obolibrary.org/obo/UBERON_0000029
# 2328  http://purl.obolibrary.org/obo/UBERON_0000029
# 2329  http://purl.obolibrary.org/obo/UBERON_0000029
#
#                                              ct  \
# 0     http://purl.obolibrary.org/obo/CL_0002138
# 1     http://purl.obolibrary.org/obo/CL_0019017
# 2     http://purl.obolibrary.org/obo/CL_0002138
# 3     http://purl.obolibrary.org/obo/CL_0002138
# 4     http://purl.obolibrary.org/obo/CL_0002138
# ...                                         ...
# 2325  http://purl.obolibrary.org/obo/CL_0009108
# 2326  http://purl.obolibrary.org/obo/CL_0009108
# 2327  http://purl.obolibrary.org/obo/CL_0000071
# 2328  http://purl.obolibrary.org/obo/CL_0009108
# 2329  http://purl.obolibrary.org/obo/CL_0009108
#
#                                      bm   bmType
# 0     http://identifiers.org/hgnc/11924  protein
# 1       http://identifiers.org/hgnc/130     gene
# 2     http://identifiers.org/hgnc/14687  protein
# 3      http://identifiers.org/hgnc/1527     gene
# 4     http://identifiers.org/hgnc/13523     gene
# ...                                 ...      ...
# 2325   http://identifiers.org/hgnc/8021     gene
# 2326   http://identifiers.org/hgnc/8514  protein
# 2327   http://identifiers.org/hgnc/6012  protein
# 2328   http://identifiers.org/hgnc/7035  protein
# 2329   http://identifiers.org/hgnc/9666  protein
#
# [2330 rows x 7 columns]

# %% [markdown]
# ## Example 3: Run your own SPARQL query with `requests`

# %% [markdown]
# (do not use hra-api client), ask for text/csv, parse with csv module

# %%
# In this example, we write our own SPARQL query inline. Alternatively, you could load a query saved in an RQ file.
query = "SELECT * WHERE { ?sub ?pred ?obj . } LIMIT 10" #this is a simple query for all subject, predicate, object triples in the queried graph

# define endpoint
url = "https://lod.humanatlas.io/sparql"

# define parameters
params = {
    "query": query,
}

# set header
headers = {
  "Accept": "text/csv"
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df
# Out:
#                                                  sub  \
# 0  http://protege.stanford.edu/plugins/owl/proteg...
# 1         http://purl.obolibrary.org/obo/BFO_0000002
# 2         http://purl.obolibrary.org/obo/BFO_0000002
# 3         http://purl.obolibrary.org/obo/BFO_0000002
# 4         http://purl.obolibrary.org/obo/BFO_0000002
# 5         http://purl.obolibrary.org/obo/BFO_0000002
# 6         http://purl.obolibrary.org/obo/BFO_0000002
# 7         http://purl.obolibrary.org/obo/BFO_0000002
# 8         http://purl.obolibrary.org/obo/BFO_0000002
# 9         http://purl.obolibrary.org/obo/BFO_0000002
#
#                                               pred  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1       http://purl.obolibrary.org/obo/IAO_0000115
# 2       http://purl.obolibrary.org/obo/IAO_0000116
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4       http://www.w3.org/2000/01/rdf-schema#label
# 5  http://www.w3.org/2000/01/rdf-schema#subClassOf
# 6  http://www.w3.org/2000/01/rdf-schema#subClassOf
# 7       http://www.w3.org/2002/07/owl#disjointWith
# 8       http://www.w3.org/2002/07/owl#disjointWith
# 9       http://www.w3.org/2002/07/owl#disjointWith
#
#                                                  obj
# 0   http://www.w3.org/2002/07/owl#AnnotationProperty
# 1  An entity that exists in full at any time in w...
# 2  BFO 2 Reference: Continuant entities are entit...
# 3                http://www.w3.org/2002/07/owl#Class
# 4                                         continuant
# 5         http://purl.obolibrary.org/obo/BFO_0000001
# 6                                            _:t4732
# 7         http://purl.obolibrary.org/obo/BFO_0000003
# 8                                            _:t4733
# 9                                           _:t20743

# %% [markdown]
# ## Demonstrate how to use the HRA KG either declaratively (via SPARQL) or imperatively (via JSON)

# %% [markdown]
# Juxtapose querying JSON with Python vs SPARQL (faster, cleaner, no for or foreach loops)
#
# - For Python, use kidney.json
#
# - For SPARQL, use code example from "Cells to expect in my anatomical region of interest":
# ```
# #+ summary: All cells that make up the kidney cortex
#
#
# PREFIX ccf: <http://purl.org/ccf/>
# PREFIX kidney_cortex: <http://purl.obolibrary.org/obo/UBERON_0001225>
#
#
# SELECT DISTINCT ?cell_label ?cell_ontology_id
# FROM <https://purl.humanatlas.io/asct-b/kidney>
# WHERE {
#   kidney_cortex: ^ccf:ccf_part_of* ?kidney_cortex_parts .
#   ?cell_ontology_id ccf:ccf_located_in ?kidney_cortex_parts .
#   ?cell_ontology_id ccf:ccf_pref_label ?cell_label .
# }
#
# ```

# %% [markdown]
# In this section, we juxtapose two ways of using data from the HRA KG to retrieve all the cells that make up the kidney cortex:
# 1. imperatively via opening a data product (JSON) in Python
# 2. declaratively via a SPARQL query
#
# While both options have advantages, we will show that the SPARQL query needs fewer lines of code and adds the ability to easily query more than one graph.

# %% [markdown]
# ### Declaratively (via SPARQL)

# %%
query = """
PREFIX ccf: <http://purl.org/ccf/>
PREFIX kidney_cortex: <http://purl.obolibrary.org/obo/UBERON_0001225>


SELECT DISTINCT ?cell_label ?cell_ontology_id
FROM <https://purl.humanatlas.io/asct-b/kidney>
WHERE {
  kidney_cortex: ^ccf:ccf_part_of* ?kidney_cortex_parts .
  # ?cell_ontology_id ccf:ccf_located_in ?kidney_cortex_parts .
  # ?cell_ontology_id ccf:ccf_pref_label ?cell_label .
}
"""

# define endpoint
url = "https://lod.humanatlas.io/sparql"

# define parameters
params = {
    "query": query,
}

# set header
headers = {
  "Accept": "text/csv"
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df
# Out:
#                                           cell_label  \
# 0                                           Podocyte
# 1                           Parietal Epithelial Cell
# 2            Cortical Collecting Duct Principal Cell
# 3  Cortical Collecting Duct Intercalated Cell Type A
#
#                             cell_ontology_id
# 0  http://purl.obolibrary.org/obo/CL_0000653
# 1  http://purl.obolibrary.org/obo/CL_1000452
# 2  http://purl.obolibrary.org/obo/CL_1000714
# 3  http://purl.obolibrary.org/obo/CL_1000715

# %% [markdown]
# ### Imperatively (via JSON)

# %%
# To achieve this in Python, we first need to get the JSON representation of the ASCT+B table for the kidney, then we need to iterate through all rows with the UBERON ID for the kidney cortex, and finally, we need to collect all cell types in a DataFrame.
# get ASCT+B table (note that this is the same procedure as Example 1)
pprint(kidney_json)
# Out:
# {'$schema': 'https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.json',
#  '@context': 'https://cdn.humanatlas.io/digital-objects/schema/asct-b/latest/assets/schema.context.jsonld',
#  '@type': 'Container',
#  'data': {'anatomical_structures': [{'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'UBERON anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001062',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'FMA anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:62955',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'General anatomical '
#                                                        'term',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:29733',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'body proper',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0013702'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'left kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004538'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'right kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004539'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0013702'],
#                                      'ccf_pref_label': 'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002113'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'kidney capsule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002015'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001225'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'outer cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002189'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002189',
#                                                      'UBERON:0005271',
#                                                      'UBERON:0001284',
#                                                      'UBERON:0001229'],
#                                      'ccf_pref_label': 'Glomerular Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004188'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'visceral epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005751'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'juxtamedullary cortex',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005271'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'medullary ray',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009883'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0009883',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct '
#                                                        '(Cortex)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004203'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal medulla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000362'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'outer stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004202',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thick '
#                                                        'Limb/Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001291'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'inner stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004201'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004201',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001289'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600036'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'inner medulla of '
#                                                        'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0004200',
#                                                      'UBERON:0004726'],
#                                      'ccf_pref_label': 'Descending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'renal papilla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001228'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001228'],
#                                      'ccf_pref_label': 'papillary tip',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009095'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'renal column (column '
#                                                        'of Bertin)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001284'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'renal pyramid',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004200'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'nephron',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001285'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Renal Corpuscle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001229'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'parietal epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005750'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229'],
#                                      'ccf_pref_label': 'renal glomerulus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000074'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000074'],
#                                      'ccf_pref_label': 'Glomerulus Vasculature',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004190'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004190'],
#                                      'ccf_pref_label': 'glomerular capillary '
#                                                        'endothelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'Interstitium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005215'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005215'],
#                                      'ccf_pref_label': 'Proximal Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002319'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002319'],
#                                      'ccf_pref_label': 'glomerular mesangium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002320'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001231'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'proximal tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004134'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004196'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004197'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal straight '
#                                                        'tubule segment 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001290'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005096'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005099'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600037'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004193'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001291'],
#                                      'ccf_pref_label': 'Macula Densa',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002335'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Distal Convolution',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001292'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Connecting Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005097'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal collecting '
#                                                        'system',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004100'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004100',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001232'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Outer '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004204'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Inner '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004205'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'Vessels',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0006544'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Blood Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003517'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517',
#                                                      'UBERON:0009202',
#                                                      'UBERON:0009091'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001986'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0034884'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Afferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004639'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Efferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004640'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003527'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003527'],
#                                      'ccf_pref_label': 'Peritubular Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005272'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005272'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0012441'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004726'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004726'],
#                                      'ccf_pref_label': 'Ascending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009091'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Lymphatic '
#                                                        'Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel',
#                                      'label': 'Kidney Lymphatic Vessel',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002042'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Apparatus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002303'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0009095'],
#                                      'ccf_pref_label': 'Papillary Tip '
#                                                        'Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                      'label': 'Papillary Tip Epithelium',
#                                      'parent_class': 'ccf:AnatomicalStructure'}],
#           'asctb_record': [{'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                                            'label': 'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 1, '
#                                                                     'Column '
#                                                                     'AS/1)',
#                                                            'order_number': 1,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'kidney '
#                                                                              'capsule',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                                            'label': 'kidney '
#                                                                     'capsule '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 1, '
#                                                                     'Column '
#                                                                     'AS/2)',
#                                                            'order_number': 2,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002015',
#                                                            'type_of': ['AnatomicalStructureRecord']}],
#                             'cell_type_list': [{'ccf_pref_label': 'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                                                 'label': 'stromal cell (Table '
#                                                          'kidney, Record 1, '
#                                                          'Column CT/1)',
#                                                 'order_number': 1,
#                                                 'record_number': 1,
#                                                 'source_concept': 'CL:0000499',
#                                                 'type_of': ['CellTypeRecord']},
#                                                {'ccf_pref_label': 'capsule '
#                                                                   'mesenchymal '
#                                                                   'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                                                 'label': 'capsule mesenchymal '
#                                                          'stromal cell (Table '
#                                                          'kidney, Record 1, '
#                                                          'Column CT/2)',
#                                                 'order_number': 2,
#                                                 'record_number': 1,
#                                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                                                 'type_of': ['CellTypeRecord']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'Foxd1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                                                   'label': 'Foxd1 (Table '
#                                                            'kidney, Record 1, '
#                                                            'Column BM/1)',
#                                                   'order_number': 1,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:3802',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'VSX2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                                                   'label': 'VSX2 (Table '
#                                                            'kidney, Record 1, '
#                                                            'Column BM/2)',
#                                                   'order_number': 2,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:1975',
#                                                   'type_of': ['BiomarkerRecord']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#                             'label': 'Table kidney, Record 1',
#                             'record_number': 1,
#                             'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                                            'label': 'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/1)',
#                                                            'order_number': 1,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                                            'label': 'cortex of '
#                                                                     'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/2)',
#                                                            'order_number': 2,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0001225',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'outer '
#                                                                              'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                                            'label': 'outer '
#                                                                     'cortex of '
#                                                                     'kidney '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/3)',
#                                                            'order_number': 3,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002189',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'Glomerular '
#                                                                              'Epithelium',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                                            'label': 'Glomerular '
#                                                                     'Epithelium '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/4)',
#                                                            'order_number': 4,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0004188',
#                                                            'type_of': ['AnatomicalStructureRecord']},
#                                                           {'ccf_pref_label': 'visceral '
#                                                                              'epithelial '
#                                                                              'layer',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                                            'label': 'visceral '
#                                                                     'epithelial '
#                                                                     'layer '
#                                                                     '(Table '
#                                                                     'kidney, '
#                                                                     'Record 2, '
#                                                                     'Column '
#                                                                     'AS/5)',
#                                                            'order_number': 5,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0005751',
#                                                            'type_of': ['AnatomicalStructureRecord']}],
#                             'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                                                 'label': 'Podocyte (Table '
#                                                          'kidney, Record 2, '
#                                                          'Column CT/1)',
#                                                 'order_number': 1,
#                                                 'record_number': 2,
#                                                 'source_concept': 'CL:0000653',
#                                                 'type_of': ['CellTypeRecord']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                                                   'label': 'NPHS2 (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/1)',
#                                                   'order_number': 1,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:13394',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PODXL',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                                                   'label': 'PODXL (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/2)',
#                                                   'order_number': 2,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9171',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                                                   'label': 'NPHS1 (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/3)',
#                                                   'order_number': 3,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:7908',
#                                                   'type_of': ['BiomarkerRecord']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PTPRQ',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                                                   'label': 'PTPRQ (Table '
#                                                            'kidney, Record 2, '
#                                                            'Column BM/4)',
#                                                   'order_number': 4,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9679',
#                                                   'type_of': ['BiomarkerRecord']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#                             'label': 'Table kidney, Record 2',
#                             'record_number': 2,
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
# ...
#                           'id': 'CL:0000814'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (general)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:613',
#                                                                          'HGNC:1636',
#                                                                          'HGNC:1638',
#                                                                          'HGNC:3609',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0001056'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (classical)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6152',
#                                                                          'HGNC:3765',
#                                                                          'HGNC:26705'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1084/jem.20030323',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000990'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (plasmatoid)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6012',
#                                                                          'HGNC:3765'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2']}],
#                           'id': 'CL:0001058'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:1241',
#                                                                          'HGNC:4947',
#                                                                          'HGNC:6152'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000576'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'mononuclear phagocyte',
#                           'conforms_to': 'CellType',
#                           'id': 'CL:0000113'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000113'],
#                           'ccf_is_provisional': True,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte Derived Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:7376',
#                                                                          'HGNC:6152',
#                                                                          'HGNC:4942',
#                                                                          'HGNC:4948',
#                                                                          'HGNC:2435',
#                                                                          'HGNC:1628',
#                                                                          'HGNC:12339']}],
#                           'id': 'https://purl.org/ccf/ASCTB-TEMP_monocyte-derived-cell',
#                           'label': 'Monocyte Derived Cell',
#                           'parent_class': 'ccf:CellType'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:16892',
#                                                                          'HGNC:1673',
#                                                                          'HGNC:1675',
#                                                                          'HGNC:11935',
#                                                                          'HGNC:1677'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000084'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Cytotoxic T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:4708',
#                                                                          'HGNC:10630',
#                                                                          'HGNC:10632'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000910'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'regulatory T cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6106']}],
#                           'id': 'CL:0000815'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'B cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:5713',
#                                                                          'HGNC:1698',
#                                                                          'HGNC:7315',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000236'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Plasma cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:30125',
#                                                                          'HGNC:18508',
#                                                                          'HGNC:5713',
#                                                                          'HGNC:5716'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000786'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Neutrophil',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:10499',
#                                                                          'HGNC:10498',
#                                                                          'HGNC:3620',
#                                                                          'HGNC:2439'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1016/j.exphem.2016.10.008',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000775'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Mast cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6342',
#                                                                          'HGNC:2298',
#                                                                          'HGNC:7316'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000097'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0001228',
#                                              'UBERON:0009095',
#                                              'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium'],
#                           'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6442',
#                                                                          'HGNC:15979',
#                                                                          'HGNC:4554',
#                                                                          'HGNC:11530']}],
#                           'id': 'CL:1000597'}]},
#  'iri': 'https://purl.humanatlas.io/asct-b/kidney',
#  'metadata': {'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'],
#               'creation_date': '2024-11-22',
#               'derived_from': 'https://lod.humanatlas.io/asct-b/kidney/v1.5#raw-data',
#               'description': 'The graph representation of the Anatomical '
#                              'Structures, Cell Types, plus Biomarkers (ASCT+B) '
#                              'table for Kidney dataset.',
#               'license': 'https://creativecommons.org/licenses/by/4.0/',
#               'publisher': 'HuBMAP',
#               'see_also': 'https://lod.humanatlas.io/asct-b/kidney/v1.5/',
#               'title': 'kidney (v1.5) graph data',
#               'version': 'v1.5'}}

# %%
# iterate over rows in ASCT+B table 
for row in kidney_json['data']['asctb_record']:
  pprint(row)
# Out:
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                 'label': 'kidney (Table kidney, Record 1, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney capsule',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                 'label': 'kidney capsule (Table kidney, Record '
#                                          '1, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002015',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                      'label': 'stromal cell (Table kidney, Record 1, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 1,
#                      'source_concept': 'CL:0000499',
#                      'type_of': ['CellTypeRecord']},
#                     {'ccf_pref_label': 'capsule mesenchymal stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                      'label': 'capsule mesenchymal stromal cell (Table kidney, '
#                               'Record 1, Column CT/2)',
#                      'order_number': 2,
#                      'record_number': 1,
#                      'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'Foxd1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                        'label': 'Foxd1 (Table kidney, Record 1, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:3802',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'VSX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                        'label': 'VSX2 (Table kidney, Record 1, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:1975',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#  'label': 'Table kidney, Record 1',
#  'record_number': 1,
#  'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                 'label': 'kidney (Table kidney, Record 2, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 2, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'outer cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                 'label': 'outer cortex of kidney (Table '
#                                          'kidney, Record 2, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002189',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 2, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 2, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                      'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 2,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 2, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                        'label': 'PODXL (Table kidney, Record 2, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 2, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 2, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#  'label': 'Table kidney, Record 2',
#  'record_number': 2,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1',
#                                 'label': 'kidney (Table kidney, Record 3, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 3, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'juxtamedullary cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3',
#                                 'label': 'juxtamedullary cortex (Table kidney, '
#                                          'Record 3, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005271',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 3, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 3, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-CT1',
#                      'label': 'Podocyte (Table kidney, Record 3, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 3,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 3, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM2',
#                        'label': 'PODXL (Table kidney, Record 3, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 3, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 3, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3',
#  'label': 'Table kidney, Record 3',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM5',
#                           'label': 'PODXL (Table kidney, Record 3, Column '
#                                    'BM/5)',
#                           'order_number': 5,
#                           'record_number': 3,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 3,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS1',
#                                 'label': 'kidney (Table kidney, Record 4, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS2',
#                                 'label': 'cortex of kidney (Table kidney, '
#                                          'Record 4, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'medullary ray',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS3',
#                                 'label': 'medullary ray (Table kidney, Record '
#                                          '4, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0009883',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Collecting Duct (Cortex)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS4',
#                                 'label': 'Collecting Duct (Cortex) (Table '
#                                          'kidney, Record 4, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0004203',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Cortical Collecting Duct Principal '
#                                        'Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-CT1',
#                      'label': 'Cortical Collecting Duct Principal Cell (Table '
#                               'kidney, Record 4, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 4,
#                      'source_concept': 'CL:1000714',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM1',
#                        'label': 'AQP2 (Table kidney, Record 4, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM2',
#                        'label': 'AQP3 (Table kidney, Record 4, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:636',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FXYD4',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM3',
#                        'label': 'FXYD4 (Table kidney, Record 4, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:4028',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4',
#  'label': 'Table kidney, Record 4',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM4',
#                           'label': 'AQP2 (Table kidney, Record 4, Column BM/4)',
#                           'order_number': 4,
#                           'record_number': 4,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 4,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS1',
#                                 'label': 'kidney (Table kidney, Record 5, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '5, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney outer medulla outer '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS3',
#                                 'label': 'kidney outer medulla outer stripe '
#                                          '(Table kidney, Record 5, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0004202',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Loop of Henle (Thick '
#                                                   'Limb/Medulla)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS4',
#                                 'label': 'Loop of Henle (Thick Limb/Medulla) '
#                                          '(Table kidney, Record 5, Column '
#                                          'AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0001291',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Medullary Thick Ascending Limb Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-CT1',
#                      'label': 'Medullary Thick Ascending Limb Cell (Table '
#                               'kidney, Record 5, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 5,
#                      'source_concept': 'CL:1001108',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC12A1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM1',
#                        'label': 'SLC12A1 (Table kidney, Record 5, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:10910',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'UMOD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM2',
#                        'label': 'UMOD (Table kidney, Record 5, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:12559',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CASR',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM3',
#                        'label': 'CASR (Table kidney, Record 5, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:1514',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5',
#  'label': 'Table kidney, Record 5',
#  'record_number': 5,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS1',
#                                 'label': 'kidney (Table kidney, Record 6, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '6, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'kidney outer medulla inner '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS3',
#                                 'label': 'kidney outer medulla inner stripe '
#                                          '(Table kidney, Record 6, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0004201',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Loop of Henle (Thin Limb)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS4',
#                                 'label': 'Loop of Henle (Thin Limb) (Table '
#                                          'kidney, Record 6, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0001289',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'descending thin limb of '
#                                                   'loop of Henle 2',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS5',
#                                 'label': 'descending thin limb of loop of '
#                                          'Henle 2 (Table kidney, Record 6, '
#                                          'Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:8600036',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Thin Limb Cell Type 2',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-CT1',
#                      'label': 'Descending Thin Limb Cell Type 2 (Table kidney, '
#                               'Record 6, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 6,
#                      'source_concept': 'CL:4030013',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CRYAB',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM1',
#                        'label': 'CRYAB (Table kidney, Record 6, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:2389',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC39A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM2',
#                        'label': 'SLC39A8 (Table kidney, Record 6, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:20862',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM3',
#                        'label': 'TACSTD2 (Table kidney, Record 6, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM4',
#                        'label': 'AQP1 (Table kidney, Record 6, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:633',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC9A3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM5',
#                        'label': 'SLC9A3 (Table kidney, Record 6, Column BM/5)',
#                        'order_number': 5,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11073',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6',
#  'label': 'Table kidney, Record 6',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP1',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM6',
#                           'label': 'AQP1 (Table kidney, Record 6, Column BM/6)',
#                           'order_number': 6,
#                           'record_number': 6,
#                           'source_concept': 'HGNC:633',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 6,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS1',
#                                 'label': 'kidney (Table kidney, Record 7, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '7, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS3',
#                                 'label': 'inner medulla of kidney (Table '
#                                          'kidney, Record 7, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS4',
#                                 'label': 'Descending Vasa Recta (Table kidney, '
#                                          'Record 7, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-CT1',
#                      'label': 'Descending Vasa Recta Endothelial Cell (Table '
#                               'kidney, Record 7, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 7,
#                      'source_concept': 'CL:1001285',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SERPINE2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM1',
#                        'label': 'SERPINE2 (Table kidney, Record 7, Column '
#                                 'BM/1)',
#                        'order_number': 1,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:8951',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TM4SF1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM2',
#                        'label': 'TM4SF1 (Table kidney, Record 7, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:11853',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PALMD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM3',
#                        'label': 'PALMD (Table kidney, Record 7, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:15846',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'ADAMTS6',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM4',
#                        'label': 'ADAMTS6 (Table kidney, Record 7, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:222',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7',
#  'label': 'Table kidney, Record 7',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'UMOD',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM5',
#                           'label': 'UMOD (Table kidney, Record 7, Column BM/5)',
#                           'order_number': 5,
#                           'record_number': 7,
#                           'source_concept': 'HGNC:12559',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 7,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS1',
#                                 'label': 'kidney (Table kidney, Record 8, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '8, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS3',
#                                 'label': 'inner medulla of kidney (Table '
#                                          'kidney, Record 8, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS4',
#                                 'label': 'renal papilla (Table kidney, Record '
#                                          '8, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'papillary tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS5',
#                                 'label': 'papillary tip (Table kidney, Record '
#                                          '8, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Inner Medullary Collecting Duct Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-CT1',
#                      'label': 'Inner Medullary Collecting Duct Cell (Table '
#                               'kidney, Record 8, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 8,
#                      'source_concept': 'CL:1000718',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM1',
#                        'label': 'AQP2 (Table kidney, Record 8, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC14A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM2',
#                        'label': 'SLC14A2 (Table kidney, Record 8, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:10919',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8',
#  'label': 'Table kidney, Record 8',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM3',
#                           'label': 'AQP2 (Table kidney, Record 8, Column BM/3)',
#                           'order_number': 3,
#                           'record_number': 8,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 8,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS1',
#                                 'label': 'kidney (Table kidney, Record 9, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS2',
#                                 'label': 'renal cortex (Table kidney, Record '
#                                          '9, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal column (column of '
#                                                   'Bertin)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS3',
#                                 'label': 'renal column (column of Bertin) '
#                                          '(Table kidney, Record 9, Column '
#                                          'AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001284',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS4',
#                                 'label': 'Glomerular Epithelium (Table kidney, '
#                                          'Record 9, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS5',
#                                 'label': 'visceral epithelial layer (Table '
#                                          'kidney, Record 9, Column AS/5)',
#                                 'order_number': 5,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-CT1',
#                      'label': 'Podocyte (Table kidney, Record 9, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 9,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM1',
#                        'label': 'NPHS2 (Table kidney, Record 9, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM2',
#                        'label': 'PODXL (Table kidney, Record 9, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM3',
#                        'label': 'NPHS1 (Table kidney, Record 9, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM4',
#                        'label': 'PTPRQ (Table kidney, Record 9, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9',
#  'label': 'Table kidney, Record 9',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM5',
#                           'label': 'PODXL (Table kidney, Record 9, Column '
#                                    'BM/5)',
#                           'order_number': 5,
#                           'record_number': 9,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['BiomarkerRecord']}],
#  'record_number': 9,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS1',
#                                 'label': 'kidney (Table kidney, Record 10, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS2',
#                                 'label': 'renal medulla (Table kidney, Record '
#                                          '10, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'renal pyramid',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS3',
#                                 'label': 'renal pyramid (Table kidney, Record '
#                                          '10, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0004200',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS4',
#                                 'label': 'Descending Vasa Recta (Table kidney, '
#                                          'Record 10, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-CT1',
# ...
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 75,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-AS2',
#                                 'label': 'Interstitium (Table kidney, Record '
#                                          '75, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 75,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Plasma cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-CT1',
#                      'label': 'Plasma cell (Table kidney, Record 75, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 75,
#                      'source_concept': 'CL:0000786',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'MZB1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM1',
#                        'label': 'MZB1 (Table kidney, Record 75, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:30125',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FCRL5',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM2',
#                        'label': 'FCRL5 (Table kidney, Record 75, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:18508',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'JCHAIN',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM3',
#                        'label': 'JCHAIN (Table kidney, Record 75, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:5713',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'IGKC',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM4',
#                        'label': 'IGKC (Table kidney, Record 75, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:5716',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75',
#  'label': 'Table kidney, Record 75',
#  'record_number': 75,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS1',
#                                 'label': 'kidney (Table kidney, Record 76, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 76,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS2',
#                                 'label': 'Interstitium (Table kidney, Record '
#                                          '76, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 76,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Neutrophil',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-CT1',
#                      'label': 'Neutrophil (Table kidney, Record 76, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 76,
#                      'source_concept': 'CL:0000775',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'S100A9',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM1',
#                        'label': 'S100A9 (Table kidney, Record 76, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:10499',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'S100A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM2',
#                        'label': 'S100A8 (Table kidney, Record 76, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:10498',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FCGR3B',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM3',
#                        'label': 'FCGR3B (Table kidney, Record 76, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:3620',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CSF3R',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM4',
#                        'label': 'CSF3R (Table kidney, Record 76, Column BM/4)',
#                        'order_number': 4,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:2439',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76',
#  'label': 'Table kidney, Record 76',
#  'record_number': 76,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1016/j.exphem.2016.10.008',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS1',
#                                 'label': 'kidney (Table kidney, Record 77, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 77,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS2',
#                                 'label': 'Interstitium (Table kidney, Record '
#                                          '77, Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 77,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Mast cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-CT1',
#                      'label': 'Mast cell (Table kidney, Record 77, Column '
#                               'CT/1)',
#                      'order_number': 1,
#                      'record_number': 77,
#                      'source_concept': 'CL:0000097',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'KIT',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM1',
#                        'label': 'KIT (Table kidney, Record 77, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:6342',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CPA3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM2',
#                        'label': 'CPA3 (Table kidney, Record 77, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:2298',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'MS4A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM3',
#                        'label': 'MS4A2 (Table kidney, Record 77, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:7316',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77',
#  'label': 'Table kidney, Record 77',
#  'record_number': 77,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS1',
#                                 'label': 'kidney (Table kidney, Record 78, '
#                                          'Column AS/1)',
#                                 'order_number': 1,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS2',
#                                 'label': 'Papilla (Table kidney, Record 78, '
#                                          'Column AS/2)',
#                                 'order_number': 2,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Papillary Tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS3',
#                                 'label': 'Papillary Tip (Table kidney, Record '
#                                          '78, Column AS/3)',
#                                 'order_number': 3,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['AnatomicalStructureRecord']},
#                                {'ccf_pref_label': 'Papillary Tip Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS4',
#                                 'label': 'Papillary Tip Epithelium (Table '
#                                          'kidney, Record 78, Column AS/4)',
#                                 'order_number': 4,
#                                 'record_number': 78,
#                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                 'type_of': ['AnatomicalStructureRecord']}],
#  'cell_type_list': [{'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-CT1',
#                      'label': 'Papillary Tip Epithelial Cell (Table kidney, '
#                               'Record 78, Column CT/1)',
#                      'order_number': 1,
#                      'record_number': 78,
#                      'source_concept': 'CL:1000597',
#                      'type_of': ['CellTypeRecord']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'KRT5',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM1',
#                        'label': 'KRT5 (Table kidney, Record 78, Column BM/1)',
#                        'order_number': 1,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:6442',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TP63',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM2',
#                        'label': 'TP63 (Table kidney, Record 78, Column BM/2)',
#                        'order_number': 2,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:15979',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'GPX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM3',
#                        'label': 'GPX2 (Table kidney, Record 78, Column BM/3)',
#                        'order_number': 3,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:4554',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM4',
#                        'label': 'TACSTD2 (Table kidney, Record 78, Column '
#                                 'BM/4)',
#                        'order_number': 4,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['BiomarkerRecord']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'GPX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM5',
#                        'label': 'GPX2 (Table kidney, Record 78, Column BM/5)',
#                        'order_number': 5,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:4554',
#                        'type_of': ['BiomarkerRecord']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78',
#  'label': 'Table kidney, Record 78',
#  'record_number': 78,
#  'type_of': ['AsctbRecord']}

# %%
# get all rows with kidney cortex
cortex_id = "UBERON:0001225"

# %%
# find all AS IDs with a connection to the cortex
def find_connected_ids(kidney_data, cortex_id, collected_ids=None):
  """_summary_

  Args:
      kidney_data (json): table as JSON
      cortex_id (str): AS ID
      collected_ids (set(), optional): A set of IDs. Defaults to None.

  Returns:
       collected_ids (set()): A set of IDs. Defaults to None.
  """
  if collected_ids is None:
      collected_ids = set()

  new_ids = set()

  # Loop through each anatomical structure to find connections to cortex_id
  for structure in kidney_data['data']['anatomical_structures']:
      try:
          # If the cortex_id is in the 'ccf_part_of' list, add the structure's ID
          if cortex_id in structure['ccf_part_of'] and structure['id'] not in collected_ids:
              new_ids.add(structure['id'])
      except KeyError:
          # Skip if 'ccf_part_of' key doesn't exist
          pass

  # If no new IDs are found, return the collected set
  if not new_ids:
      return collected_ids

  # Add newly found IDs to collected_ids
  collected_ids.update(new_ids)

  # Recursively find connections for each new ID found
  for new_id in new_ids:
      find_connected_ids(kidney_data, new_id, collected_ids)

  return collected_ids


# Example usage
ids_with_connection_to_cortex = find_connected_ids(kidney_json, cortex_id)
pprint(ids_with_connection_to_cortex)
# Out:
# {'UBERON:0001284',
#  'UBERON:0002189',
#  'UBERON:0004188',
#  'UBERON:0004203',
#  'UBERON:0005271',
#  'UBERON:0005750',
#  'UBERON:0005751',
#  'UBERON:0009883'}

# %%
# check connections to cortex
def check_relationships(id: str):
  """Checks if the provided IRI is connected to the cortex
  Args:
      id (str): an IRI (UBERON or FMA)
  Returns:
      check (bool): checks whether there is a connection
  """

  check = False
  for entry in kidney_json['data']['anatomical_structures']:
    if entry['id'] == id:
      try:
        if cortex_id in entry['ccf_part_of']:
          check = True
      except:
        pass

  return check

# %%
# initialize dict for result
result = {
  "cell_label": [],
  "cell_ontology_id": []
}

# initialize list for all asctb_records with cortex
relevant_records = []

for record in kidney_json['data']['asctb_record']:
  for row in record['anatomical_structure_list']:
    if (cortex_id in row['source_concept'] or cortex_id in row['type_of'] or check_relationships(row['source_concept']) or row['source_concept'] in ids_with_connection_to_cortex):
      relevant_records.append(record['cell_type_list'])
    
# use list comprehension to simply the list of cell types
list_flattened = [record for sublist in relevant_records for record in sublist]
pprint(list_flattened[:3])
# Out:
# [{'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CellTypeRecord']},
#  {'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CellTypeRecord']},
#  {'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (Table kidney, Record 2, Column CT/1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CellTypeRecord']}]

# %%
# prefix for OBO PURL
prefix = "http://purl.obolibrary.org/obo/"

# capture result in dict
for cell_type in list_flattened:
  result['cell_label'].append(cell_type['ccf_pref_label'])
  result['cell_ontology_id'].append(prefix+cell_type['source_concept'])
  
# convert to dataframe
df = pd.DataFrame(result).drop_duplicates(subset="cell_ontology_id")
df
# Out:
#                                            cell_label  \
# 0                                            Podocyte
# 8             Cortical Collecting Duct Principal Cell
# 15                           Parietal Epithelial Cell
# 20  Cortical Collecting Duct Intercalated Cell Type A
#
#                              cell_ontology_id
# 0   http://purl.obolibrary.org/obo/CL:0000653
# 8   http://purl.obolibrary.org/obo/CL:1000714
# 15  http://purl.obolibrary.org/obo/CL:1000452
# 20  http://purl.obolibrary.org/obo/CL:1000715
