# %% [markdown]
# ## A notebook to query the HRA Knowledge Graph (KG)

# %%
# install packages
# %pip install requests pandas

# import packages
import requests
import pandas as pd

import json
from pprint import pprint
from io import StringIO
# Out:
# Requirement already satisfied: requests in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\abueckle\documents\github\hra-glb-preprocessor\hra-kg-supporting-information\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Example 1: Get a HRA Digital Object (DO) as a JSON file

# %% [markdown]
# In this example, we will retrieve an anatomical structures, cell types, plus biomarkers (ASCT+B) table (see [paper](https://www.nature.com/articles/s41556-021-00788-6)) as a JSON file. As part of the HRA Digital Object processing pipeline, we perform normalization and enrichment. When we normalize, we convert every Digital Object into a standard format that follows schemas defined by [LinkML](https://linkml.io/). The default file format for normalized data is [YAML](https://yaml.org/), which can readily be converted to JSON. This would almost be enough as is, but the current models were not fully designed for end users to use. It was created as a way to generate RDF graphs. So, there are some artifacts of this in the models themselves, which may make them hard to understand. However, with some clean-up, the HRA data will be accessible and useful for end users with varying degrees of programming and analysis experience. LinkML can also generate a JSON-LD Context and a JSON Schema (see [https://json-schema.org/](https://json-schema.org/)), which we can then attach to the JSON files to make them validatable, readily convert them to RDF, and to provide autocomplete as well as documentation inline in code editors like VS Code, and to generate online documentation.

# %%
# Each HRA DO has a permanent URL (PURL), where the user is served HRA DO data after server-side content negotation
# will be same as https://cdn.humanatlas.io/digital-objects/asct-b/kidney/v1.5/graph.json BUT MORE programmer-friendly!!!
# This is the PURL for the ASCT+B table for the kidney
url = "https://purl.humanatlas.io/asct-b/kidney"

# set headers
headers = {
  "Accept" : "application/json"
}

# make request, parse response (COMPLETE WHEN HRA DO JSONs are FULLY DEPLOYED)
response = requests.get(url, headers=headers).text
# pprint(response)

# delete this once HRA DO JSONs are deployed
with open('data/kidney.json') as f:
    kidney_json = json.load(f)

pprint(kidney_json)
# Out:
# {'@type': 'Container',
#  'data': {'anatomical_structures': [{'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'UBERON anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001062',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'FMA anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:62955',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'General anatomical '
#                                                        'term',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:29733',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'body proper',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0013702'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'left kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004538'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'right kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004539'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0013702'],
#                                      'ccf_pref_label': 'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002113'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'kidney capsule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002015'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001225'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'outer cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002189'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002189',
#                                                      'UBERON:0005271',
#                                                      'UBERON:0001284',
#                                                      'UBERON:0001229'],
#                                      'ccf_pref_label': 'Glomerular Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004188'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'visceral epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005751'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'juxtamedullary cortex',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005271'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'medullary ray',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009883'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0009883',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct '
#                                                        '(Cortex)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004203'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal medulla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000362'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'outer stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004202',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thick '
#                                                        'Limb/Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001291'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'inner stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004201'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004201',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001289'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600036'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'inner medulla of '
#                                                        'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0004200',
#                                                      'UBERON:0004726'],
#                                      'ccf_pref_label': 'Descending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'renal papilla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001228'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001228'],
#                                      'ccf_pref_label': 'papillary tip',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009095'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'renal column (column '
#                                                        'of Bertin)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001284'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'renal pyramid',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004200'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'nephron',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001285'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Renal Corpuscle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001229'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'parietal epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005750'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229'],
#                                      'ccf_pref_label': 'renal glomerulus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000074'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000074'],
#                                      'ccf_pref_label': 'Glomerulus Vasculature',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004190'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004190'],
#                                      'ccf_pref_label': 'glomerular capillary '
#                                                        'endothelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'Interstitium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005215'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005215'],
#                                      'ccf_pref_label': 'Proximal Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002319'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002319'],
#                                      'ccf_pref_label': 'glomerular mesangium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002320'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001231'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'proximal tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004134'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004196'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004197'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal straight '
#                                                        'tubule segment 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001290'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005096'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005099'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600037'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004193'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001291'],
#                                      'ccf_pref_label': 'Macula Densa',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002335'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Distal Convolution',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001292'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Connecting Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005097'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal collecting '
#                                                        'system',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004100'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004100',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001232'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Outer '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004204'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Inner '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004205'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'Vessels',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0006544'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Blood Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003517'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517',
#                                                      'UBERON:0009202',
#                                                      'UBERON:0009091'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001986'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0034884'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Afferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004639'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Efferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004640'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003527'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003527'],
#                                      'ccf_pref_label': 'Peritubular Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005272'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005272'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0012441'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004726'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004726'],
#                                      'ccf_pref_label': 'Ascending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009091'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Lymphatic '
#                                                        'Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002042'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Apparatus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002303'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0009095'],
#                                      'ccf_pref_label': 'Papillary Tip '
#                                                        'Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                      'parent_class': 'ccf:AnatomicalStructure'}],
#           'asctb_record': [{'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                                            'label': 'kidney '
#                                                                     '(kidney-R1-AS1)',
#                                                            'order_number': 1,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['UBERON:0002113']},
#                                                           {'ccf_pref_label': 'kidney '
#                                                                              'capsule',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                                            'label': 'kidney '
#                                                                     'capsule '
#                                                                     '(kidney-R1-AS2)',
#                                                            'order_number': 2,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002015',
#                                                            'type_of': ['UBERON:0002015']}],
#                             'cell_type_list': [{'ccf_pref_label': 'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                                                 'label': 'stromal cell '
#                                                          '(kidney-R1-CT1)',
#                                                 'order_number': 1,
#                                                 'record_number': 1,
#                                                 'source_concept': 'CL:0000499',
#                                                 'type_of': ['CL:0000499']},
#                                                {'ccf_pref_label': 'capsule '
#                                                                   'mesenchymal '
#                                                                   'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                                                 'label': 'capsule mesenchymal '
#                                                          'stromal cell '
#                                                          '(kidney-R1-CT2)',
#                                                 'order_number': 2,
#                                                 'record_number': 1,
#                                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                                                 'type_of': ['https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'Foxd1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                                                   'label': 'Foxd1 '
#                                                            '(kidney-R1-BM1)',
#                                                   'order_number': 1,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:3802',
#                                                   'type_of': ['HGNC:3802']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'VSX2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                                                   'label': 'VSX2 '
#                                                            '(kidney-R1-BM2)',
#                                                   'order_number': 2,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:1975',
#                                                   'type_of': ['HGNC:1975']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#                             'label': 'Record 1',
#                             'record_number': 1,
#                             'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                                            'label': 'kidney '
#                                                                     '(kidney-R2-AS1)',
#                                                            'order_number': 1,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['UBERON:0002113']},
#                                                           {'ccf_pref_label': 'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                                            'label': 'cortex of '
#                                                                     'kidney '
#                                                                     '(kidney-R2-AS2)',
#                                                            'order_number': 2,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0001225',
#                                                            'type_of': ['UBERON:0001225']},
#                                                           {'ccf_pref_label': 'outer '
#                                                                              'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                                            'label': 'outer '
#                                                                     'cortex of '
#                                                                     'kidney '
#                                                                     '(kidney-R2-AS3)',
#                                                            'order_number': 3,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002189',
#                                                            'type_of': ['UBERON:0002189']},
#                                                           {'ccf_pref_label': 'Glomerular '
#                                                                              'Epithelium',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                                            'label': 'Glomerular '
#                                                                     'Epithelium '
#                                                                     '(kidney-R2-AS4)',
#                                                            'order_number': 4,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0004188',
#                                                            'type_of': ['UBERON:0004188']},
#                                                           {'ccf_pref_label': 'visceral '
#                                                                              'epithelial '
#                                                                              'layer',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                                            'label': 'visceral '
#                                                                     'epithelial '
#                                                                     'layer '
#                                                                     '(kidney-R2-AS5)',
#                                                            'order_number': 5,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0005751',
#                                                            'type_of': ['UBERON:0005751']}],
#                             'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                                                 'label': 'Podocyte '
#                                                          '(kidney-R2-CT1)',
#                                                 'order_number': 1,
#                                                 'record_number': 2,
#                                                 'source_concept': 'CL:0000653',
#                                                 'type_of': ['CL:0000653']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                                                   'label': 'NPHS2 '
#                                                            '(kidney-R2-BM1)',
#                                                   'order_number': 1,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:13394',
#                                                   'type_of': ['HGNC:13394']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PODXL',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                                                   'label': 'PODXL '
#                                                            '(kidney-R2-BM2)',
#                                                   'order_number': 2,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9171',
#                                                   'type_of': ['HGNC:9171']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                                                   'label': 'NPHS1 '
#                                                            '(kidney-R2-BM3)',
#                                                   'order_number': 3,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:7908',
#                                                   'type_of': ['HGNC:7908']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PTPRQ',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                                                   'label': 'PTPRQ '
#                                                            '(kidney-R2-BM4)',
#                                                   'order_number': 4,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9679',
#                                                   'type_of': ['HGNC:9679']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#                             'label': 'Record 2',
#                             'record_number': 2,
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1',
#                                                            'label': 'kidney '
#                                                                     '(kidney-R3-AS1)',
#                                                            'order_number': 1,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['UBERON:0002113']},
#                                                           {'ccf_pref_label': 'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2',
#                                                            'label': 'cortex of '
#                                                                     'kidney '
#                                                                     '(kidney-R3-AS2)',
#                                                            'order_number': 2,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0001225',
#                                                            'type_of': ['UBERON:0001225']},
#                                                           {'ccf_pref_label': 'juxtamedullary '
#                                                                              'cortex',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3',
#                                                            'label': 'juxtamedullary '
#                                                                     'cortex '
#                                                                     '(kidney-R3-AS3)',
#                                                            'order_number': 3,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0005271',
#                                                            'type_of': ['UBERON:0005271']},
#                                                           {'ccf_pref_label': 'Glomerular '
#                                                                              'Epithelium',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4',
#                                                            'label': 'Glomerular '
#                                                                     'Epithelium '
#                                                                     '(kidney-R3-AS4)',
#                                                            'order_number': 4,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0004188',
#                                                            'type_of': ['UBERON:0004188']},
# ...
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000814'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (general)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:613',
#                                                                          'HGNC:1636',
#                                                                          'HGNC:1638',
#                                                                          'HGNC:3609',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0001056'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (classical)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6152',
#                                                                          'HGNC:3765',
#                                                                          'HGNC:26705'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1084/jem.20030323',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000990'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (plasmatoid)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6012',
#                                                                          'HGNC:3765'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2']}],
#                           'id': 'CL:0001058'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:1241',
#                                                                          'HGNC:4947',
#                                                                          'HGNC:6152'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000576'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'mononuclear phagocyte',
#                           'conforms_to': 'CellType',
#                           'id': 'CL:0000113'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000113'],
#                           'ccf_is_provisional': True,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte Derived Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:7376',
#                                                                          'HGNC:6152',
#                                                                          'HGNC:4942',
#                                                                          'HGNC:4948',
#                                                                          'HGNC:2435',
#                                                                          'HGNC:1628',
#                                                                          'HGNC:12339']}],
#                           'id': 'https://purl.org/ccf/ASCTB-TEMP_monocyte-derived-cell',
#                           'parent_class': 'ccf:CellType'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:16892',
#                                                                          'HGNC:1673',
#                                                                          'HGNC:1675',
#                                                                          'HGNC:11935',
#                                                                          'HGNC:1677'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000084'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Cytotoxic T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:4708',
#                                                                          'HGNC:10630',
#                                                                          'HGNC:10632'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000910'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'regulatory T cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6106']}],
#                           'id': 'CL:0000815'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'B cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:5713',
#                                                                          'HGNC:1698',
#                                                                          'HGNC:7315',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000236'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Plasma cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:30125',
#                                                                          'HGNC:18508',
#                                                                          'HGNC:5713',
#                                                                          'HGNC:5716'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000786'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Neutrophil',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:10499',
#                                                                          'HGNC:10498',
#                                                                          'HGNC:3620',
#                                                                          'HGNC:2439'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1016/j.exphem.2016.10.008',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000775'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Mast cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6342',
#                                                                          'HGNC:2298',
#                                                                          'HGNC:7316'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000097'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0001228',
#                                              'UBERON:0009095',
#                                              'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium'],
#                           'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6442',
#                                                                          'HGNC:15979',
#                                                                          'HGNC:4554',
#                                                                          'HGNC:11530']}],
#                           'id': 'CL:1000597'}]},
#  'iri': 'https://purl.humanatlas.io/asct-b/kidney',
#  'metadata': {'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'],
#               'creation_date': '2024-09-24',
#               'derived_from': 'https://lod.humanatlas.io/asct-b/kidney/v1.5#raw-data',
#               'description': 'The graph representation of the Anatomical '
#                              'Structures, Cell Types, plus Biomarkers (ASCT+B) '
#                              'table for Kidney dataset.',
#               'license': 'https://creativecommons.org/licenses/by/4.0/',
#               'publisher': 'HuBMAP',
#               'see_also': 'https://lod.humanatlas.io/asct-b/kidney/v1.5/',
#               'title': 'kidney (v1.5) graph data',
#               'version': 'v1.5'}}

# %%
# The resulting JSON file has four keys:
kidney_json.keys()
# Out:
# dict_keys(['iri', 'metadata', 'data', '@type'])

# %%
# iterate over rows in ASCT+B table
for row in kidney_json['data']['asctb_record']:
  print(row)
# Out:
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1', 'record_number': 1, 'label': 'Record 1', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 1, 'order_number': 1, 'label': 'kidney (kidney-R1-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2', 'ccf_pref_label': 'kidney capsule', 'source_concept': 'UBERON:0002015', 'record_number': 1, 'order_number': 2, 'label': 'kidney capsule (kidney-R1-AS2)', 'type_of': ['UBERON:0002015']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1', 'ccf_pref_label': 'stromal cell', 'source_concept': 'CL:0000499', 'record_number': 1, 'order_number': 1, 'label': 'stromal cell (kidney-R1-CT1)', 'type_of': ['CL:0000499']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2', 'ccf_pref_label': 'capsule mesenchymal stromal cell', 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell', 'record_number': 1, 'order_number': 2, 'label': 'capsule mesenchymal stromal cell (kidney-R1-CT2)', 'type_of': ['https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1', 'ccf_pref_label': 'Foxd1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:3802', 'record_number': 1, 'order_number': 1, 'label': 'Foxd1 (kidney-R1-BM1)', 'type_of': ['HGNC:3802']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2', 'ccf_pref_label': 'VSX2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:1975', 'record_number': 1, 'order_number': 2, 'label': 'VSX2 (kidney-R1-BM2)', 'type_of': ['HGNC:1975']}], 'references': ['https://doi.org/10.1371/journal.pone.0187118'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2', 'record_number': 2, 'label': 'Record 2', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 2, 'order_number': 1, 'label': 'kidney (kidney-R2-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2', 'ccf_pref_label': 'cortex of kidney', 'source_concept': 'UBERON:0001225', 'record_number': 2, 'order_number': 2, 'label': 'cortex of kidney (kidney-R2-AS2)', 'type_of': ['UBERON:0001225']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3', 'ccf_pref_label': 'outer cortex of kidney', 'source_concept': 'UBERON:0002189', 'record_number': 2, 'order_number': 3, 'label': 'outer cortex of kidney (kidney-R2-AS3)', 'type_of': ['UBERON:0002189']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 2, 'order_number': 4, 'label': 'Glomerular Epithelium (kidney-R2-AS4)', 'type_of': ['UBERON:0004188']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 2, 'order_number': 5, 'label': 'visceral epithelial layer (kidney-R2-AS5)', 'type_of': ['UBERON:0005751']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 2, 'order_number': 1, 'label': 'Podocyte (kidney-R2-CT1)', 'type_of': ['CL:0000653']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 2, 'order_number': 1, 'label': 'NPHS2 (kidney-R2-BM1)', 'type_of': ['HGNC:13394']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 2, 'order_number': 2, 'label': 'PODXL (kidney-R2-BM2)', 'type_of': ['HGNC:9171']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 2, 'order_number': 3, 'label': 'NPHS1 (kidney-R2-BM3)', 'type_of': ['HGNC:7908']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 2, 'order_number': 4, 'label': 'PTPRQ (kidney-R2-BM4)', 'type_of': ['HGNC:9679']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3', 'record_number': 3, 'label': 'Record 3', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 3, 'order_number': 1, 'label': 'kidney (kidney-R3-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2', 'ccf_pref_label': 'cortex of kidney', 'source_concept': 'UBERON:0001225', 'record_number': 3, 'order_number': 2, 'label': 'cortex of kidney (kidney-R3-AS2)', 'type_of': ['UBERON:0001225']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3', 'ccf_pref_label': 'juxtamedullary cortex', 'source_concept': 'UBERON:0005271', 'record_number': 3, 'order_number': 3, 'label': 'juxtamedullary cortex (kidney-R3-AS3)', 'type_of': ['UBERON:0005271']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 3, 'order_number': 4, 'label': 'Glomerular Epithelium (kidney-R3-AS4)', 'type_of': ['UBERON:0004188']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 3, 'order_number': 5, 'label': 'visceral epithelial layer (kidney-R3-AS5)', 'type_of': ['UBERON:0005751']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 3, 'order_number': 1, 'label': 'Podocyte (kidney-R3-CT1)', 'type_of': ['CL:0000653']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 3, 'order_number': 1, 'label': 'NPHS2 (kidney-R3-BM1)', 'type_of': ['HGNC:13394']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 3, 'order_number': 2, 'label': 'PODXL (kidney-R3-BM2)', 'type_of': ['HGNC:9171']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 3, 'order_number': 3, 'label': 'NPHS1 (kidney-R3-BM3)', 'type_of': ['HGNC:7908']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 3, 'order_number': 4, 'label': 'PTPRQ (kidney-R3-BM4)', 'type_of': ['HGNC:9679']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM5', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:9171', 'record_number': 3, 'order_number': 5, 'label': 'PODXL (kidney-R3-BM5)', 'type_of': ['HGNC:9171']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4', 'record_number': 4, 'label': 'Record 4', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 4, 'order_number': 1, 'label': 'kidney (kidney-R4-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS2', 'ccf_pref_label': 'cortex of kidney', 'source_concept': 'UBERON:0001225', 'record_number': 4, 'order_number': 2, 'label': 'cortex of kidney (kidney-R4-AS2)', 'type_of': ['UBERON:0001225']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS3', 'ccf_pref_label': 'medullary ray', 'source_concept': 'UBERON:0009883', 'record_number': 4, 'order_number': 3, 'label': 'medullary ray (kidney-R4-AS3)', 'type_of': ['UBERON:0009883']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS4', 'ccf_pref_label': 'Collecting Duct (Cortex)', 'source_concept': 'UBERON:0004203', 'record_number': 4, 'order_number': 4, 'label': 'Collecting Duct (Cortex) (kidney-R4-AS4)', 'type_of': ['UBERON:0004203']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-CT1', 'ccf_pref_label': 'Cortical Collecting Duct Principal Cell', 'source_concept': 'CL:1000714', 'record_number': 4, 'order_number': 1, 'label': 'Cortical Collecting Duct Principal Cell (kidney-R4-CT1)', 'type_of': ['CL:1000714']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM1', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:634', 'record_number': 4, 'order_number': 1, 'label': 'AQP2 (kidney-R4-BM1)', 'type_of': ['HGNC:634']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM2', 'ccf_pref_label': 'AQP3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:636', 'record_number': 4, 'order_number': 2, 'label': 'AQP3 (kidney-R4-BM2)', 'type_of': ['HGNC:636']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM3', 'ccf_pref_label': 'FXYD4', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4028', 'record_number': 4, 'order_number': 3, 'label': 'FXYD4 (kidney-R4-BM3)', 'type_of': ['HGNC:4028']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM4', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:634', 'record_number': 4, 'order_number': 4, 'label': 'AQP2 (kidney-R4-BM4)', 'type_of': ['HGNC:634']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5', 'record_number': 5, 'label': 'Record 5', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 5, 'order_number': 1, 'label': 'kidney (kidney-R5-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 5, 'order_number': 2, 'label': 'renal medulla (kidney-R5-AS2)', 'type_of': ['UBERON:0000362']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS3', 'ccf_pref_label': 'kidney outer medulla outer stripe', 'source_concept': 'UBERON:0004202', 'record_number': 5, 'order_number': 3, 'label': 'kidney outer medulla outer stripe (kidney-R5-AS3)', 'type_of': ['UBERON:0004202']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS4', 'ccf_pref_label': 'Loop of Henle (Thick Limb/Medulla)', 'source_concept': 'UBERON:0001291', 'record_number': 5, 'order_number': 4, 'label': 'Loop of Henle (Thick Limb/Medulla) (kidney-R5-AS4)', 'type_of': ['UBERON:0001291']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-CT1', 'ccf_pref_label': 'Medullary Thick Ascending Limb Cell', 'source_concept': 'CL:1001108', 'record_number': 5, 'order_number': 1, 'label': 'Medullary Thick Ascending Limb Cell (kidney-R5-CT1)', 'type_of': ['CL:1001108']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM1', 'ccf_pref_label': 'SLC12A1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10910', 'record_number': 5, 'order_number': 1, 'label': 'SLC12A1 (kidney-R5-BM1)', 'type_of': ['HGNC:10910']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM2', 'ccf_pref_label': 'UMOD', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:12559', 'record_number': 5, 'order_number': 2, 'label': 'UMOD (kidney-R5-BM2)', 'type_of': ['HGNC:12559']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM3', 'ccf_pref_label': 'CASR', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:1514', 'record_number': 5, 'order_number': 3, 'label': 'CASR (kidney-R5-BM3)', 'type_of': ['HGNC:1514']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6', 'record_number': 6, 'label': 'Record 6', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 6, 'order_number': 1, 'label': 'kidney (kidney-R6-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 6, 'order_number': 2, 'label': 'renal medulla (kidney-R6-AS2)', 'type_of': ['UBERON:0000362']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS3', 'ccf_pref_label': 'kidney outer medulla inner stripe', 'source_concept': 'UBERON:0004201', 'record_number': 6, 'order_number': 3, 'label': 'kidney outer medulla inner stripe (kidney-R6-AS3)', 'type_of': ['UBERON:0004201']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS4', 'ccf_pref_label': 'Loop of Henle (Thin Limb)', 'source_concept': 'UBERON:0001289', 'record_number': 6, 'order_number': 4, 'label': 'Loop of Henle (Thin Limb) (kidney-R6-AS4)', 'type_of': ['UBERON:0001289']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS5', 'ccf_pref_label': 'descending thin limb of loop of Henle 2', 'source_concept': 'UBERON:8600036', 'record_number': 6, 'order_number': 5, 'label': 'descending thin limb of loop of Henle 2 (kidney-R6-AS5)', 'type_of': ['UBERON:8600036']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-CT1', 'ccf_pref_label': 'Descending Thin Limb Cell Type 2', 'source_concept': 'CL:4030013', 'record_number': 6, 'order_number': 1, 'label': 'Descending Thin Limb Cell Type 2 (kidney-R6-CT1)', 'type_of': ['CL:4030013']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM1', 'ccf_pref_label': 'CRYAB', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:2389', 'record_number': 6, 'order_number': 1, 'label': 'CRYAB (kidney-R6-BM1)', 'type_of': ['HGNC:2389']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM2', 'ccf_pref_label': 'SLC39A8', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:20862', 'record_number': 6, 'order_number': 2, 'label': 'SLC39A8 (kidney-R6-BM2)', 'type_of': ['HGNC:20862']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM3', 'ccf_pref_label': 'TACSTD2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11530', 'record_number': 6, 'order_number': 3, 'label': 'TACSTD2 (kidney-R6-BM3)', 'type_of': ['HGNC:11530']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM4', 'ccf_pref_label': 'AQP1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:633', 'record_number': 6, 'order_number': 4, 'label': 'AQP1 (kidney-R6-BM4)', 'type_of': ['HGNC:633']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM5', 'ccf_pref_label': 'SLC9A3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11073', 'record_number': 6, 'order_number': 5, 'label': 'SLC9A3 (kidney-R6-BM5)', 'type_of': ['HGNC:11073']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM6', 'ccf_pref_label': 'AQP1', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:633', 'record_number': 6, 'order_number': 6, 'label': 'AQP1 (kidney-R6-BM6)', 'type_of': ['HGNC:633']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7', 'record_number': 7, 'label': 'Record 7', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 7, 'order_number': 1, 'label': 'kidney (kidney-R7-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 7, 'order_number': 2, 'label': 'renal medulla (kidney-R7-AS2)', 'type_of': ['UBERON:0000362']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS3', 'ccf_pref_label': 'inner medulla of kidney', 'source_concept': 'UBERON:0001294', 'record_number': 7, 'order_number': 3, 'label': 'inner medulla of kidney (kidney-R7-AS3)', 'type_of': ['UBERON:0001294']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS4', 'ccf_pref_label': 'Descending Vasa Recta', 'source_concept': 'UBERON:0009202', 'record_number': 7, 'order_number': 4, 'label': 'Descending Vasa Recta (kidney-R7-AS4)', 'type_of': ['UBERON:0009202']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-CT1', 'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell', 'source_concept': 'CL:1001285', 'record_number': 7, 'order_number': 1, 'label': 'Descending Vasa Recta Endothelial Cell (kidney-R7-CT1)', 'type_of': ['CL:1001285']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM1', 'ccf_pref_label': 'SERPINE2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:8951', 'record_number': 7, 'order_number': 1, 'label': 'SERPINE2 (kidney-R7-BM1)', 'type_of': ['HGNC:8951']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM2', 'ccf_pref_label': 'TM4SF1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11853', 'record_number': 7, 'order_number': 2, 'label': 'TM4SF1 (kidney-R7-BM2)', 'type_of': ['HGNC:11853']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM3', 'ccf_pref_label': 'PALMD', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:15846', 'record_number': 7, 'order_number': 3, 'label': 'PALMD (kidney-R7-BM3)', 'type_of': ['HGNC:15846']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM4', 'ccf_pref_label': 'ADAMTS6', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:222', 'record_number': 7, 'order_number': 4, 'label': 'ADAMTS6 (kidney-R7-BM4)', 'type_of': ['HGNC:222']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM5', 'ccf_pref_label': 'UMOD', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:12559', 'record_number': 7, 'order_number': 5, 'label': 'UMOD (kidney-R7-BM5)', 'type_of': ['HGNC:12559']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8', 'record_number': 8, 'label': 'Record 8', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 8, 'order_number': 1, 'label': 'kidney (kidney-R8-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 8, 'order_number': 2, 'label': 'renal medulla (kidney-R8-AS2)', 'type_of': ['UBERON:0000362']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS3', 'ccf_pref_label': 'inner medulla of kidney', 'source_concept': 'UBERON:0001294', 'record_number': 8, 'order_number': 3, 'label': 'inner medulla of kidney (kidney-R8-AS3)', 'type_of': ['UBERON:0001294']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS4', 'ccf_pref_label': 'renal papilla', 'source_concept': 'UBERON:0001228', 'record_number': 8, 'order_number': 4, 'label': 'renal papilla (kidney-R8-AS4)', 'type_of': ['UBERON:0001228']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS5', 'ccf_pref_label': 'papillary tip', 'source_concept': 'UBERON:0009095', 'record_number': 8, 'order_number': 5, 'label': 'papillary tip (kidney-R8-AS5)', 'type_of': ['UBERON:0009095']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-CT1', 'ccf_pref_label': 'Inner Medullary Collecting Duct Cell', 'source_concept': 'CL:1000718', 'record_number': 8, 'order_number': 1, 'label': 'Inner Medullary Collecting Duct Cell (kidney-R8-CT1)', 'type_of': ['CL:1000718']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM1', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:634', 'record_number': 8, 'order_number': 1, 'label': 'AQP2 (kidney-R8-BM1)', 'type_of': ['HGNC:634']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM2', 'ccf_pref_label': 'SLC14A2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10919', 'record_number': 8, 'order_number': 2, 'label': 'SLC14A2 (kidney-R8-BM2)', 'type_of': ['HGNC:10919']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM3', 'ccf_pref_label': 'AQP2', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:634', 'record_number': 8, 'order_number': 3, 'label': 'AQP2 (kidney-R8-BM3)', 'type_of': ['HGNC:634']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9', 'record_number': 9, 'label': 'Record 9', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 9, 'order_number': 1, 'label': 'kidney (kidney-R9-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS2', 'ccf_pref_label': 'renal cortex', 'source_concept': 'UBERON:0001225', 'record_number': 9, 'order_number': 2, 'label': 'renal cortex (kidney-R9-AS2)', 'type_of': ['UBERON:0001225']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS3', 'ccf_pref_label': 'renal column (column of Bertin)', 'source_concept': 'UBERON:0001284', 'record_number': 9, 'order_number': 3, 'label': 'renal column (column of Bertin) (kidney-R9-AS3)', 'type_of': ['UBERON:0001284']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 9, 'order_number': 4, 'label': 'Glomerular Epithelium (kidney-R9-AS4)', 'type_of': ['UBERON:0004188']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 9, 'order_number': 5, 'label': 'visceral epithelial layer (kidney-R9-AS5)', 'type_of': ['UBERON:0005751']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 9, 'order_number': 1, 'label': 'Podocyte (kidney-R9-CT1)', 'type_of': ['CL:0000653']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 9, 'order_number': 1, 'label': 'NPHS2 (kidney-R9-BM1)', 'type_of': ['HGNC:13394']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 9, 'order_number': 2, 'label': 'PODXL (kidney-R9-BM2)', 'type_of': ['HGNC:9171']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 9, 'order_number': 3, 'label': 'NPHS1 (kidney-R9-BM3)', 'type_of': ['HGNC:7908']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 9, 'order_number': 4, 'label': 'PTPRQ (kidney-R9-BM4)', 'type_of': ['HGNC:9679']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM5', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:9171', 'record_number': 9, 'order_number': 5, 'label': 'PODXL (kidney-R9-BM5)', 'type_of': ['HGNC:9171']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10', 'record_number': 10, 'label': 'Record 10', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 10, 'order_number': 1, 'label': 'kidney (kidney-R10-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS2', 'ccf_pref_label': 'renal medulla', 'source_concept': 'UBERON:0000362', 'record_number': 10, 'order_number': 2, 'label': 'renal medulla (kidney-R10-AS2)', 'type_of': ['UBERON:0000362']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS3', 'ccf_pref_label': 'renal pyramid', 'source_concept': 'UBERON:0004200', 'record_number': 10, 'order_number': 3, 'label': 'renal pyramid (kidney-R10-AS3)', 'type_of': ['UBERON:0004200']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS4', 'ccf_pref_label': 'Descending Vasa Recta', 'source_concept': 'UBERON:0009202', 'record_number': 10, 'order_number': 4, 'label': 'Descending Vasa Recta (kidney-R10-AS4)', 'type_of': ['UBERON:0009202']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-CT1', 'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell', 'source_concept': 'CL:1001285', 'record_number': 10, 'order_number': 1, 'label': 'Descending Vasa Recta Endothelial Cell (kidney-R10-CT1)', 'type_of': ['CL:1001285']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM1', 'ccf_pref_label': 'SERPINE2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:8951', 'record_number': 10, 'order_number': 1, 'label': 'SERPINE2 (kidney-R10-BM1)', 'type_of': ['HGNC:8951']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM2', 'ccf_pref_label': 'TM4SF1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11853', 'record_number': 10, 'order_number': 2, 'label': 'TM4SF1 (kidney-R10-BM2)', 'type_of': ['HGNC:11853']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM3', 'ccf_pref_label': 'PALMD', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:15846', 'record_number': 10, 'order_number': 3, 'label': 'PALMD (kidney-R10-BM3)', 'type_of': ['HGNC:15846']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM4', 'ccf_pref_label': 'ADAMTS6', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:222', 'record_number': 10, 'order_number': 4, 'label': 'ADAMTS6 (kidney-R10-BM4)', 'type_of': ['HGNC:222']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11', 'record_number': 11, 'label': 'Record 11', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 11, 'order_number': 1, 'label': 'kidney (kidney-R11-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS2', 'ccf_pref_label': 'nephron', 'source_concept': 'UBERON:0001285', 'record_number': 11, 'order_number': 2, 'label': 'nephron (kidney-R11-AS2)', 'type_of': ['UBERON:0001285']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS3', 'ccf_pref_label': 'Renal Corpuscle', 'source_concept': 'UBERON:0001229', 'record_number': 11, 'order_number': 3, 'label': 'Renal Corpuscle (kidney-R11-AS3)', 'type_of': ['UBERON:0001229']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 11, 'order_number': 4, 'label': 'Glomerular Epithelium (kidney-R11-AS4)', 'type_of': ['UBERON:0004188']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS5', 'ccf_pref_label': 'parietal epithelial layer', 'source_concept': 'UBERON:0005750', 'record_number': 11, 'order_number': 5, 'label': 'parietal epithelial layer (kidney-R11-AS5)', 'type_of': ['UBERON:0005750']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-CT1', 'ccf_pref_label': 'Parietal Epithelial Cell', 'source_concept': 'CL:1000452', 'record_number': 11, 'order_number': 1, 'label': 'Parietal Epithelial Cell (kidney-R11-CT1)', 'type_of': ['CL:1000452']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-BM1', 'ccf_pref_label': 'VCAM1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:12663', 'record_number': 11, 'order_number': 1, 'label': 'VCAM1 (kidney-R11-BM1)', 'type_of': ['HGNC:12663']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-BM2', 'ccf_pref_label': 'CFH', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4883', 'record_number': 11, 'order_number': 2, 'label': 'CFH (kidney-R11-BM2)', 'type_of': ['HGNC:4883']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-BM3', 'ccf_pref_label': 'CRB2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:18688', 'record_number': 11, 'order_number': 3, 'label': 'CRB2 (kidney-R11-BM3)', 'type_of': ['HGNC:18688']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-BM4', 'ccf_pref_label': 'ALDH1A2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:15472', 'record_number': 11, 'order_number': 4, 'label': 'ALDH1A2 (kidney-R11-BM4)', 'type_of': ['HGNC:15472']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-BM5', 'ccf_pref_label': 'VIM', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:12692', 'record_number': 11, 'order_number': 5, 'label': 'VIM (kidney-R11-BM5)', 'type_of': ['HGNC:12692']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1038/s41467-019-10861-2'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12', 'record_number': 12, 'label': 'Record 12', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 12, 'order_number': 1, 'label': 'kidney (kidney-R12-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-AS2', 'ccf_pref_label': 'nephron', 'source_concept': 'UBERON:0001285', 'record_number': 12, 'order_number': 2, 'label': 'nephron (kidney-R12-AS2)', 'type_of': ['UBERON:0001285']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-AS3', 'ccf_pref_label': 'Renal Corpuscle', 'source_concept': 'UBERON:0001229', 'record_number': 12, 'order_number': 3, 'label': 'Renal Corpuscle (kidney-R12-AS3)', 'type_of': ['UBERON:0001229']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-AS4', 'ccf_pref_label': 'Glomerular Epithelium', 'source_concept': 'UBERON:0004188', 'record_number': 12, 'order_number': 4, 'label': 'Glomerular Epithelium (kidney-R12-AS4)', 'type_of': ['UBERON:0004188']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-AS5', 'ccf_pref_label': 'visceral epithelial layer', 'source_concept': 'UBERON:0005751', 'record_number': 12, 'order_number': 5, 'label': 'visceral epithelial layer (kidney-R12-AS5)', 'type_of': ['UBERON:0005751']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-CT1', 'ccf_pref_label': 'Podocyte', 'source_concept': 'CL:0000653', 'record_number': 12, 'order_number': 1, 'label': 'Podocyte (kidney-R12-CT1)', 'type_of': ['CL:0000653']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM1', 'ccf_pref_label': 'NPHS2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13394', 'record_number': 12, 'order_number': 1, 'label': 'NPHS2 (kidney-R12-BM1)', 'type_of': ['HGNC:13394']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM2', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9171', 'record_number': 12, 'order_number': 2, 'label': 'PODXL (kidney-R12-BM2)', 'type_of': ['HGNC:9171']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM3', 'ccf_pref_label': 'NPHS1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7908', 'record_number': 12, 'order_number': 3, 'label': 'NPHS1 (kidney-R12-BM3)', 'type_of': ['HGNC:7908']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM4', 'ccf_pref_label': 'PTPRQ', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9679', 'record_number': 12, 'order_number': 4, 'label': 'PTPRQ (kidney-R12-BM4)', 'type_of': ['HGNC:9679']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM5', 'ccf_pref_label': 'NTNG1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:23319', 'record_number': 12, 'order_number': 5, 'label': 'NTNG1 (kidney-R12-BM5)', 'type_of': ['HGNC:23319']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM6', 'ccf_pref_label': 'CLIC5', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:13517', 'record_number': 12, 'order_number': 6, 'label': 'CLIC5 (kidney-R12-BM6)', 'type_of': ['HGNC:13517']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R12-BM7', 'ccf_pref_label': 'PODXL', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:9171', 'record_number': 12, 'order_number': 7, 'label': 'PODXL (kidney-R12-BM7)', 'type_of': ['HGNC:9171']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1073/pnas.2005477117'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13', 'record_number': 13, 'label': 'Record 13', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 13, 'order_number': 1, 'label': 'kidney (kidney-R13-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-AS2', 'ccf_pref_label': 'nephron', 'source_concept': 'UBERON:0001285', 'record_number': 13, 'order_number': 2, 'label': 'nephron (kidney-R13-AS2)', 'type_of': ['UBERON:0001285']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-AS3', 'ccf_pref_label': 'Renal Corpuscle', 'source_concept': 'UBERON:0001229', 'record_number': 13, 'order_number': 3, 'label': 'Renal Corpuscle (kidney-R13-AS3)', 'type_of': ['UBERON:0001229']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-AS4', 'ccf_pref_label': 'renal glomerulus', 'source_concept': 'UBERON:0000074', 'record_number': 13, 'order_number': 4, 'label': 'renal glomerulus (kidney-R13-AS4)', 'type_of': ['UBERON:0000074']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-AS5', 'ccf_pref_label': 'Glomerulus Vasculature', 'source_concept': 'UBERON:0004190', 'record_number': 13, 'order_number': 5, 'label': 'Glomerulus Vasculature (kidney-R13-AS5)', 'type_of': ['UBERON:0004190']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-AS6', 'ccf_pref_label': 'glomerular capillary endothelium', 'source_concept': 'UBERON:0004294', 'record_number': 13, 'order_number': 6, 'label': 'glomerular capillary endothelium (kidney-R13-AS6)', 'type_of': ['UBERON:0004294']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-CT1', 'ccf_pref_label': 'Glomerular Capillary Endothelial Cell', 'source_concept': 'CL:1001005', 'record_number': 13, 'order_number': 1, 'label': 'Glomerular Capillary Endothelial Cell (kidney-R13-CT1)', 'type_of': ['CL:1001005']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM1', 'ccf_pref_label': 'EHD3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:3244', 'record_number': 13, 'order_number': 1, 'label': 'EHD3 (kidney-R13-BM1)', 'type_of': ['HGNC:3244']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM2', 'ccf_pref_label': 'EMCN', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:16041', 'record_number': 13, 'order_number': 2, 'label': 'EMCN (kidney-R13-BM2)', 'type_of': ['HGNC:16041']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM3', 'ccf_pref_label': 'HECW2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:29853', 'record_number': 13, 'order_number': 3, 'label': 'HECW2 (kidney-R13-BM3)', 'type_of': ['HGNC:29853']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM4', 'ccf_pref_label': 'FLT1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:3763', 'record_number': 13, 'order_number': 4, 'label': 'FLT1 (kidney-R13-BM4)', 'type_of': ['HGNC:3763']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM5', 'ccf_pref_label': 'AQP1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:633', 'record_number': 13, 'order_number': 5, 'label': 'AQP1 (kidney-R13-BM5)', 'type_of': ['HGNC:633']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM6', 'ccf_pref_label': 'PLAT', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:9051', 'record_number': 13, 'order_number': 6, 'label': 'PLAT (kidney-R13-BM6)', 'type_of': ['HGNC:9051']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R13-BM7', 'ccf_pref_label': 'AQP1', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:633', 'record_number': 13, 'order_number': 7, 'label': 'AQP1 (kidney-R13-BM7)', 'type_of': ['HGNC:633']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41586-020-2941-1', 'h ...
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14', 'record_number': 14, 'label': 'Record 14', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 14, 'order_number': 1, 'label': 'kidney (kidney-R14-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-AS2', 'ccf_pref_label': 'nephron', 'source_concept': 'UBERON:0001285', 'record_number': 14, 'order_number': 2, 'label': 'nephron (kidney-R14-AS2)', 'type_of': ['UBERON:0001285']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-AS3', 'ccf_pref_label': 'Renal Corpuscle', 'source_concept': 'UBERON:0001229', 'record_number': 14, 'order_number': 3, 'label': 'Renal Corpuscle (kidney-R14-AS3)', 'type_of': ['UBERON:0001229']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-AS4', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 14, 'order_number': 4, 'label': 'Interstitium (kidney-R14-AS4)', 'type_of': ['UBERON:0005215']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-AS5', 'ccf_pref_label': 'Proximal Tubule', 'source_concept': 'UBERON:0002319', 'record_number': 14, 'order_number': 5, 'label': 'Proximal Tubule (kidney-R14-AS5)', 'type_of': ['UBERON:0002319']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-AS6', 'ccf_pref_label': 'glomerular mesangium', 'source_concept': 'UBERON:0002320', 'record_number': 14, 'order_number': 6, 'label': 'glomerular mesangium (kidney-R14-AS6)', 'type_of': ['UBERON:0002320']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-CT1', 'ccf_pref_label': 'Mesangial Cell', 'source_concept': 'CL:1000742', 'record_number': 14, 'order_number': 1, 'label': 'Mesangial Cell (kidney-R14-CT1)', 'type_of': ['CL:1000742']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-BM1', 'ccf_pref_label': 'POSTN', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:16953', 'record_number': 14, 'order_number': 1, 'label': 'POSTN (kidney-R14-BM1)', 'type_of': ['HGNC:16953']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-BM2', 'ccf_pref_label': 'PIEZO2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:26270', 'record_number': 14, 'order_number': 2, 'label': 'PIEZO2 (kidney-R14-BM2)', 'type_of': ['HGNC:26270']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-BM3', 'ccf_pref_label': 'ROBO1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10249', 'record_number': 14, 'order_number': 3, 'label': 'ROBO1 (kidney-R14-BM3)', 'type_of': ['HGNC:10249']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-BM4', 'ccf_pref_label': 'ITGA8', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:6144', 'record_number': 14, 'order_number': 4, 'label': 'ITGA8 (kidney-R14-BM4)', 'type_of': ['HGNC:6144']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-BM5', 'ccf_pref_label': 'PDGFRB', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:8804', 'record_number': 14, 'order_number': 5, 'label': 'PDGFRB (kidney-R14-BM5)', 'type_of': ['HGNC:8804']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R14-BM6', 'ccf_pref_label': 'SYNPO2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:17732', 'record_number': 14, 'order_number': 6, 'label': 'SYNPO2 (kidney-R14-BM6)', 'type_of': ['HGNC:17732']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1073/pnas.2005477117', 'https://doi.org/10.1681/ASN.2020010071'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15', 'record_number': 15, 'label': 'Record 15', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 15, 'order_number': 1, 'label': 'kidney (kidney-R15-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-AS2', 'ccf_pref_label': 'nephron', 'source_concept': 'UBERON:0001285', 'record_number': 15, 'order_number': 2, 'label': 'nephron (kidney-R15-AS2)', 'type_of': ['UBERON:0001285']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-AS3', 'ccf_pref_label': 'Tubules', 'source_concept': 'UBERON:0001231', 'record_number': 15, 'order_number': 3, 'label': 'Tubules (kidney-R15-AS3)', 'type_of': ['UBERON:0001231']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-AS4', 'ccf_pref_label': 'proximal tubule', 'source_concept': 'UBERON:0004134', 'record_number': 15, 'order_number': 4, 'label': 'proximal tubule (kidney-R15-AS4)', 'type_of': ['UBERON:0004134']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-CT1', 'ccf_pref_label': 'Proximal Tubule Epithelial Cell', 'source_concept': 'CL:0002306', 'record_number': 15, 'order_number': 1, 'label': 'Proximal Tubule Epithelial Cell (kidney-R15-CT1)', 'type_of': ['CL:0002306']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-BM1', 'ccf_pref_label': 'CUBN', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:2548', 'record_number': 15, 'order_number': 1, 'label': 'CUBN (kidney-R15-BM1)', 'type_of': ['HGNC:2548']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-BM2', 'ccf_pref_label': 'LRP2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:6694', 'record_number': 15, 'order_number': 2, 'label': 'LRP2 (kidney-R15-BM2)', 'type_of': ['HGNC:6694']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-BM3', 'ccf_pref_label': 'SLC13A1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10916', 'record_number': 15, 'order_number': 3, 'label': 'SLC13A1 (kidney-R15-BM3)', 'type_of': ['HGNC:10916']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-BM4', 'ccf_pref_label': 'ALDOB', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:417', 'record_number': 15, 'order_number': 4, 'label': 'ALDOB (kidney-R15-BM4)', 'type_of': ['HGNC:417']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-BM5', 'ccf_pref_label': 'GATM', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4175', 'record_number': 15, 'order_number': 5, 'label': 'GATM (kidney-R15-BM5)', 'type_of': ['HGNC:4175']}], 'protein_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R15-BM6', 'ccf_pref_label': 'LRP2', 'ccf_biomarker_type': 'protein', 'source_concept': 'HGNC:6694', 'record_number': 15, 'order_number': 6, 'label': 'LRP2 (kidney-R15-BM6)', 'type_of': ['HGNC:6694']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1073/pnas.2005477117', 'https://doi.org/10.1681/ASN.2020010071'], 'type_of': ['AsctbRecord']}
# ...
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72', 'record_number': 72, 'label': 'Record 72', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 72, 'order_number': 1, 'label': 'kidney (kidney-R72-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72-AS2', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 72, 'order_number': 2, 'label': 'Interstitium (kidney-R72-AS2)', 'type_of': ['UBERON:0005215']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72-CT1', 'ccf_pref_label': 'Cytotoxic T Cell', 'source_concept': 'CL:0000910', 'record_number': 72, 'order_number': 1, 'label': 'Cytotoxic T Cell (kidney-R72-CT1)', 'type_of': ['CL:0000910']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72-BM1', 'ccf_pref_label': 'GZMA', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4708', 'record_number': 72, 'order_number': 1, 'label': 'GZMA (kidney-R72-BM1)', 'type_of': ['HGNC:4708']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72-BM2', 'ccf_pref_label': 'CCL4', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10630', 'record_number': 72, 'order_number': 2, 'label': 'CCL4 (kidney-R72-BM2)', 'type_of': ['HGNC:10630']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R72-BM3', 'ccf_pref_label': 'CCL5', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10632', 'record_number': 72, 'order_number': 3, 'label': 'CCL5 (kidney-R72-BM3)', 'type_of': ['HGNC:10632']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1172/jci.insight.133267'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R73', 'record_number': 73, 'label': 'Record 73', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R73-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 73, 'order_number': 1, 'label': 'kidney (kidney-R73-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R73-AS2', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 73, 'order_number': 2, 'label': 'Interstitium (kidney-R73-AS2)', 'type_of': ['UBERON:0005215']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R73-CT1', 'ccf_pref_label': 'regulatory T cell', 'source_concept': 'CL:0000815', 'record_number': 73, 'order_number': 1, 'label': 'regulatory T cell (kidney-R73-CT1)', 'type_of': ['CL:0000815']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R73-BM1', 'ccf_pref_label': 'FOXP3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:6106', 'record_number': 73, 'order_number': 1, 'label': 'FOXP3 (kidney-R73-BM1)', 'type_of': ['HGNC:6106']}], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74', 'record_number': 74, 'label': 'Record 74', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 74, 'order_number': 1, 'label': 'kidney (kidney-R74-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-AS2', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 74, 'order_number': 2, 'label': 'Interstitium (kidney-R74-AS2)', 'type_of': ['UBERON:0005215']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-CT1', 'ccf_pref_label': 'B cell', 'source_concept': 'CL:0000236', 'record_number': 74, 'order_number': 1, 'label': 'B cell (kidney-R74-CT1)', 'type_of': ['CL:0000236']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-BM1', 'ccf_pref_label': 'JCHAIN', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:5713', 'record_number': 74, 'order_number': 1, 'label': 'JCHAIN (kidney-R74-BM1)', 'type_of': ['HGNC:5713']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-BM2', 'ccf_pref_label': 'CD79A', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:1698', 'record_number': 74, 'order_number': 2, 'label': 'CD79A (kidney-R74-BM2)', 'type_of': ['HGNC:1698']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-BM3', 'ccf_pref_label': 'MS4A1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7315', 'record_number': 74, 'order_number': 3, 'label': 'MS4A1 (kidney-R74-BM3)', 'type_of': ['HGNC:7315']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-BM4', 'ccf_pref_label': 'HLA-DRA', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4947', 'record_number': 74, 'order_number': 4, 'label': 'HLA-DRA (kidney-R74-BM4)', 'type_of': ['HGNC:4947']}], 'references': ['https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1126/science.aat5031'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75', 'record_number': 75, 'label': 'Record 75', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 75, 'order_number': 1, 'label': 'kidney (kidney-R75-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-AS2', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 75, 'order_number': 2, 'label': 'Interstitium (kidney-R75-AS2)', 'type_of': ['UBERON:0005215']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-CT1', 'ccf_pref_label': 'Plasma cell', 'source_concept': 'CL:0000786', 'record_number': 75, 'order_number': 1, 'label': 'Plasma cell (kidney-R75-CT1)', 'type_of': ['CL:0000786']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM1', 'ccf_pref_label': 'MZB1', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:30125', 'record_number': 75, 'order_number': 1, 'label': 'MZB1 (kidney-R75-BM1)', 'type_of': ['HGNC:30125']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM2', 'ccf_pref_label': 'FCRL5', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:18508', 'record_number': 75, 'order_number': 2, 'label': 'FCRL5 (kidney-R75-BM2)', 'type_of': ['HGNC:18508']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM3', 'ccf_pref_label': 'JCHAIN', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:5713', 'record_number': 75, 'order_number': 3, 'label': 'JCHAIN (kidney-R75-BM3)', 'type_of': ['HGNC:5713']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM4', 'ccf_pref_label': 'IGKC', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:5716', 'record_number': 75, 'order_number': 4, 'label': 'IGKC (kidney-R75-BM4)', 'type_of': ['HGNC:5716']}], 'references': ['https://doi.org/10.1101/2021.07.28.454201', 'https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1126/science.aat5031'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76', 'record_number': 76, 'label': 'Record 76', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 76, 'order_number': 1, 'label': 'kidney (kidney-R76-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS2', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 76, 'order_number': 2, 'label': 'Interstitium (kidney-R76-AS2)', 'type_of': ['UBERON:0005215']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-CT1', 'ccf_pref_label': 'Neutrophil', 'source_concept': 'CL:0000775', 'record_number': 76, 'order_number': 1, 'label': 'Neutrophil (kidney-R76-CT1)', 'type_of': ['CL:0000775']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM1', 'ccf_pref_label': 'S100A9', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10499', 'record_number': 76, 'order_number': 1, 'label': 'S100A9 (kidney-R76-BM1)', 'type_of': ['HGNC:10499']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM2', 'ccf_pref_label': 'S100A8', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:10498', 'record_number': 76, 'order_number': 2, 'label': 'S100A8 (kidney-R76-BM2)', 'type_of': ['HGNC:10498']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM3', 'ccf_pref_label': 'FCGR3B', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:3620', 'record_number': 76, 'order_number': 3, 'label': 'FCGR3B (kidney-R76-BM3)', 'type_of': ['HGNC:3620']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM4', 'ccf_pref_label': 'CSF3R', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:2439', 'record_number': 76, 'order_number': 4, 'label': 'CSF3R (kidney-R76-BM4)', 'type_of': ['HGNC:2439']}], 'references': ['https://doi.org/10.1101/2021.07.28.454201', 'https://doi.org/10.1016/j.exphem.2016.10.008', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1172/jci.insight.133267', 'https://doi.org/10.1126/science.aat5031'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77', 'record_number': 77, 'label': 'Record 77', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 77, 'order_number': 1, 'label': 'kidney (kidney-R77-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS2', 'ccf_pref_label': 'Interstitium', 'source_concept': 'UBERON:0005215', 'record_number': 77, 'order_number': 2, 'label': 'Interstitium (kidney-R77-AS2)', 'type_of': ['UBERON:0005215']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-CT1', 'ccf_pref_label': 'Mast cell', 'source_concept': 'CL:0000097', 'record_number': 77, 'order_number': 1, 'label': 'Mast cell (kidney-R77-CT1)', 'type_of': ['CL:0000097']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM1', 'ccf_pref_label': 'KIT', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:6342', 'record_number': 77, 'order_number': 1, 'label': 'KIT (kidney-R77-BM1)', 'type_of': ['HGNC:6342']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM2', 'ccf_pref_label': 'CPA3', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:2298', 'record_number': 77, 'order_number': 2, 'label': 'CPA3 (kidney-R77-BM2)', 'type_of': ['HGNC:2298']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM3', 'ccf_pref_label': 'MS4A2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:7316', 'record_number': 77, 'order_number': 3, 'label': 'MS4A2 (kidney-R77-BM3)', 'type_of': ['HGNC:7316']}], 'references': ['https://doi.org/10.1101/2021.07.28.454201', 'https://doi.org/10.1038/s41467-019-10861-2', 'https://doi.org/10.1038/s41586-020-2941-1', 'https://doi.org/10.1172/jci.insight.133267'], 'type_of': ['AsctbRecord']}
# {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78', 'record_number': 78, 'label': 'Record 78', 'anatomical_structure_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS1', 'ccf_pref_label': 'kidney', 'source_concept': 'UBERON:0002113', 'record_number': 78, 'order_number': 1, 'label': 'kidney (kidney-R78-AS1)', 'type_of': ['UBERON:0002113']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS2', 'ccf_pref_label': 'Papilla', 'source_concept': 'UBERON:0001228', 'record_number': 78, 'order_number': 2, 'label': 'Papilla (kidney-R78-AS2)', 'type_of': ['UBERON:0001228']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS3', 'ccf_pref_label': 'Papillary Tip', 'source_concept': 'UBERON:0009095', 'record_number': 78, 'order_number': 3, 'label': 'Papillary Tip (kidney-R78-AS3)', 'type_of': ['UBERON:0009095']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS4', 'ccf_pref_label': 'Papillary Tip Epithelium', 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium', 'record_number': 78, 'order_number': 4, 'label': 'Papillary Tip Epithelium (kidney-R78-AS4)', 'type_of': ['https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium']}], 'cell_type_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-CT1', 'ccf_pref_label': 'Papillary Tip Epithelial Cell', 'source_concept': 'CL:1000597', 'record_number': 78, 'order_number': 1, 'label': 'Papillary Tip Epithelial Cell (kidney-R78-CT1)', 'type_of': ['CL:1000597']}], 'gene_marker_list': [{'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM1', 'ccf_pref_label': 'KRT5', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:6442', 'record_number': 78, 'order_number': 1, 'label': 'KRT5 (kidney-R78-BM1)', 'type_of': ['HGNC:6442']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM2', 'ccf_pref_label': 'TP63', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:15979', 'record_number': 78, 'order_number': 2, 'label': 'TP63 (kidney-R78-BM2)', 'type_of': ['HGNC:15979']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM3', 'ccf_pref_label': 'GPX2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4554', 'record_number': 78, 'order_number': 3, 'label': 'GPX2 (kidney-R78-BM3)', 'type_of': ['HGNC:4554']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM4', 'ccf_pref_label': 'TACSTD2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:11530', 'record_number': 78, 'order_number': 4, 'label': 'TACSTD2 (kidney-R78-BM4)', 'type_of': ['HGNC:11530']}, {'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM5', 'ccf_pref_label': 'GPX2', 'ccf_biomarker_type': 'gene', 'source_concept': 'HGNC:4554', 'record_number': 78, 'order_number': 5, 'label': 'GPX2 (kidney-R78-BM5)', 'type_of': ['HGNC:4554']}], 'type_of': ['AsctbRecord']}

# %% [markdown]
# ## Example 2: Run a SPARQL query via `grlc` with `requests`

# %% [markdown]
# `grlc` retrieves SPARQL queries in [https://github.com/hubmapconsortium/ccf-grlc](https://github.com/hubmapconsortium/ccf-grlc), then allows the user to run these queries like RESTful API endpoints. In this example, we retrieve all the AS, CT, and Bs in the ASCT+B table in the lymph node ([https://purl.humanatlas.io/asct-b/lymph-node](https://purl.humanatlas.io/asct-b/lymph-node)). The query is documented [here](https://apps.humanatlas.io/api/grlc/hra.html#get-/asctb-in-table).

# %%
# set desired file format
format = "csv" 

# set url
grlc_url = f"https://grlc.io/api-git/hubmapconsortium/ccf-grlc/subdir/hra/asctb-in-table.{format}?asctb=https%3A%2F%2Fpurl.humanatlas.io%2Fasct-b%2Flymph-node"

# set header
headers = {
  "Accept": "text/csv"
}

# make request
response = requests.get(grlc_url)

# convert text to file-like object
csv_data = StringIO(response.text)  

# concert to DataFrame
df = pd.read_csv(csv_data)
df
# Out:
#                        as_label  \
# 0     Afferent lymphatic vessel
# 1     Afferent lymphatic vessel
# 2     Afferent lymphatic vessel
# 3     Afferent lymphatic vessel
# 4     Afferent lymphatic vessel
# ...                         ...
# 2325                 lymph node
# 2326                 lymph node
# 2327                 lymph node
# 2328                 lymph node
# 2329                 lymph node
#
#                                                ct_label bm_label  \
# 0                  Endothelial Cell of Lymphatic Vessel  TNFRSF9
# 1                                    Smooth Muscle Cell    ACTA2
# 2                  Endothelial Cell of Lymphatic Vessel    Lyve1
# 3                  Endothelial Cell of Lymphatic Vessel   CLEC4M
# 4                  Endothelial Cell of Lymphatic Vessel     CAV1
# ...                                                 ...      ...
# 2325                      Blood Vessel Endothelial Cell    PVRL2
# 2326                      Blood Vessel Endothelial Cell   PROX-1
# 2327                      Blood Vessel Endothelial Cell    CD123
# 2328  Lymphatic Endothelial Cell-Subcapsular Sinus F...     CD45
# 2329  Lymphatic Endothelial Cell-Subcapsular Sinus F...   PROX-1
#
#                                                  as  \
# 0     http://purl.obolibrary.org/obo/UBERON_0010396
# 1     http://purl.obolibrary.org/obo/UBERON_0010396
# 2     http://purl.obolibrary.org/obo/UBERON_0010396
# 3     http://purl.obolibrary.org/obo/UBERON_0010396
# 4     http://purl.obolibrary.org/obo/UBERON_0010396
# ...                                             ...
# 2325  http://purl.obolibrary.org/obo/UBERON_0000029
# 2326  http://purl.obolibrary.org/obo/UBERON_0000029
# 2327  http://purl.obolibrary.org/obo/UBERON_0000029
# 2328  http://purl.obolibrary.org/obo/UBERON_0000029
# 2329  http://purl.obolibrary.org/obo/UBERON_0000029
#
#                                              ct  \
# 0     http://purl.obolibrary.org/obo/CL_0002138
# 1     http://purl.obolibrary.org/obo/CL_0019017
# 2     http://purl.obolibrary.org/obo/CL_0002138
# 3     http://purl.obolibrary.org/obo/CL_0002138
# 4     http://purl.obolibrary.org/obo/CL_0002138
# ...                                         ...
# 2325  http://purl.obolibrary.org/obo/CL_0000071
# 2326  http://purl.obolibrary.org/obo/CL_0000071
# 2327  http://purl.obolibrary.org/obo/CL_0000071
# 2328  http://purl.obolibrary.org/obo/CL_0009108
# 2329  http://purl.obolibrary.org/obo/CL_0009108
#
#                                      bm   bmType
# 0     http://identifiers.org/hgnc/11924  protein
# 1       http://identifiers.org/hgnc/130     gene
# 2     http://identifiers.org/hgnc/14687  protein
# 3     http://identifiers.org/hgnc/13523     gene
# 4      http://identifiers.org/hgnc/1527     gene
# ...                                 ...      ...
# 2325   http://identifiers.org/hgnc/9707     gene
# 2326   http://identifiers.org/hgnc/9459  protein
# 2327   http://identifiers.org/hgnc/6012  protein
# 2328   http://identifiers.org/hgnc/9666  protein
# 2329   http://identifiers.org/hgnc/9459  protein
#
# [2330 rows x 7 columns]

# %% [markdown]
# ## Example 3: Run your own SPARQL query with `requests`

# %% [markdown]
# (do not use hra-api client), ask for text/csv, parse with csv module

# %%
# In this example, we write our own SPARQL query inline. Alternatively, you could load a query saved in an RQ file.
query = "SELECT * WHERE { ?sub ?pred ?obj . } LIMIT 10" #this is a simple query for all subject, predicate, object triples in the queried graph

# define endpoint
url = "https://lod.humanatlas.io/sparql"

# define parameters
params = {
    "query": query,
    "format": "json"  # Request JSON format
}

# Send the GET request
response = requests.get(url, params=params)

# Check for a successful response
if response.status_code == 200:
    # Parse JSON response to a dictionary
    results = response.json()

    # Extract data into a DataFrame
    data_sparql = []
    for result in results["results"]["bindings"]:
        data_sparql.append({k: v["value"] for k, v in result.items()})

    df = pd.DataFrame(data_sparql)
    print(df)
else:
    print("Error:", response.status_code)
# Out:
#                                                  sub  \
# 0  http://protege.stanford.edu/plugins/owl/proteg...
# 1         http://purl.obolibrary.org/obo/BFO_0000002
# 2         http://purl.obolibrary.org/obo/BFO_0000002
# 3         http://purl.obolibrary.org/obo/BFO_0000002
# 4         http://purl.obolibrary.org/obo/BFO_0000002
# 5         http://purl.obolibrary.org/obo/BFO_0000002
# 6         http://purl.obolibrary.org/obo/BFO_0000002
# 7         http://purl.obolibrary.org/obo/BFO_0000002
# 8         http://purl.obolibrary.org/obo/BFO_0000002
# 9         http://purl.obolibrary.org/obo/BFO_0000002
#
#                                               pred  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1       http://purl.obolibrary.org/obo/IAO_0000115
# 2       http://purl.obolibrary.org/obo/IAO_0000116
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4       http://www.w3.org/2000/01/rdf-schema#label
# 5  http://www.w3.org/2000/01/rdf-schema#subClassOf
# 6  http://www.w3.org/2000/01/rdf-schema#subClassOf
# 7       http://www.w3.org/2002/07/owl#disjointWith
# 8       http://www.w3.org/2002/07/owl#disjointWith
# 9       http://www.w3.org/2002/07/owl#disjointWith
#
#                                                  obj
# 0   http://www.w3.org/2002/07/owl#AnnotationProperty
# 1  An entity that exists in full at any time in w...
# 2  BFO 2 Reference: Continuant entities are entit...
# 3                http://www.w3.org/2002/07/owl#Class
# 4                                         continuant
# 5         http://purl.obolibrary.org/obo/BFO_0000001
# 6                                             t15972
# 7         http://purl.obolibrary.org/obo/BFO_0000003
# 8                                             t16159
# 9                                            t307419

# %% [markdown]
# ## Demonstrate how to use the HRA KG either declaratively (via SPARQL) or imperatively (via JSON)

# %% [markdown]
# Juxtapose querying JSON with Python vs SPARQL (faster, cleaner, no for or foreach loops)
#
# - For Python, use kidney.json
#
# - For SPARQL, use code example from "Cells to expect in my anatomical region of interest":
# ```
# #+ summary: All cells that make up the kidney cortex
#
#
# PREFIX ccf: <http://purl.org/ccf/>
# PREFIX kidney_cortex: <http://purl.obolibrary.org/obo/UBERON_0001225>
#
#
# SELECT DISTINCT ?cell_label ?cell_ontology_id
# FROM <https://purl.humanatlas.io/asct-b/kidney>
# WHERE {
#   kidney_cortex: ^ccf:ccf_part_of* ?kidney_cortex_parts .
#   ?cell_ontology_id ccf:ccf_located_in ?kidney_cortex_parts .
#   ?cell_ontology_id ccf:ccf_pref_label ?cell_label .
# }
#
# ```

# %% [markdown]
# In this section, we juxtapose two ways of using data from the HRA KG to retrieve all the cells that make up the kidney cortex:
# 1. imperatively via opening a data product (JSON) in Python
# 2. declaratively via a SPARQL query
#
# While both options have advantages, we will show that the SPARQL query needs fewer lines of code and adds the ability to easily query more than one graph.

# %% [markdown]
# ### Declaratively (via SPARQL)

# %%
query = """
PREFIX ccf: <http://purl.org/ccf/>
PREFIX kidney_cortex: <http://purl.obolibrary.org/obo/UBERON_0001225>


SELECT DISTINCT ?cell_label ?cell_ontology_id
FROM <https://purl.humanatlas.io/asct-b/kidney>
WHERE {
  kidney_cortex: ^ccf:ccf_part_of* ?kidney_cortex_parts .
  # ?cell_ontology_id ccf:ccf_located_in ?kidney_cortex_parts .
  # ?cell_ontology_id ccf:ccf_pref_label ?cell_label .
}
"""

# define endpoint
url = "https://lod.humanatlas.io/sparql"

# define parameters
params = {
    "query": query,
    "format": "json"  # Request JSON format
}

# Send the GET request
response = requests.get(url, params=params)

# Check for a successful response
if response.status_code == 200:
    # Parse JSON response to a dictionary
    results = response.json()

    # Extract data into a DataFrame
    kidney_sparql = []
    for result in results["results"]["bindings"]:
        kidney_sparql.append({k: v["value"] for k, v in result.items()})

    df = pd.DataFrame(kidney_sparql)
    
else:
    print("Error:", response.status_code)
df
# Out:
#                                           cell_label  \
# 0                                           Podocyte
# 1            Cortical Collecting Duct Principal Cell
# 2                           Parietal Epithelial Cell
# 3  Cortical Collecting Duct Intercalated Cell Type A
#
#                             cell_ontology_id
# 0  http://purl.obolibrary.org/obo/CL_0000653
# 1  http://purl.obolibrary.org/obo/CL_1000714
# 2  http://purl.obolibrary.org/obo/CL_1000452
# 3  http://purl.obolibrary.org/obo/CL_1000715

# %% [markdown]
# ### Imperatively (via JSON)

# %%
# To achieve this in Python, we first need to get the JSON representation of the ASCT+B table for the kidney, then we need to iterate through all rows with the UBERON ID for the kidney cortex, and finally, we need to collect all cell types in a DataFrame.
# get ASCT+B table (note that this is the same procedure as Example 1)
pprint(kidney_json)
# Out:
# {'@type': 'Container',
#  'data': {'anatomical_structures': [{'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'UBERON anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001062',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'FMA anatomical '
#                                                        'structure',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:62955',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'General anatomical '
#                                                        'term',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'FMA:29733',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_pref_label': 'body proper',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0013702'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'left kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004538'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'right kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004539'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0013702'],
#                                      'ccf_pref_label': 'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002113'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'kidney capsule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002015'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001225'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'outer cortex of kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002189'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002189',
#                                                      'UBERON:0005271',
#                                                      'UBERON:0001284',
#                                                      'UBERON:0001229'],
#                                      'ccf_pref_label': 'Glomerular Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004188'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'visceral epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005751'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'juxtamedullary cortex',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005271'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'medullary ray',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009883'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0009883',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct '
#                                                        '(Cortex)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004203'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal medulla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000362'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'outer stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004202',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thick '
#                                                        'Limb/Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001291'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'kidney outer medulla '
#                                                        'inner stripe',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004201'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004201',
#                                                      'UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001289'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600036'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'inner medulla of '
#                                                        'kidney',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0004200',
#                                                      'UBERON:0004726'],
#                                      'ccf_pref_label': 'Descending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009202'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001294',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'renal papilla',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001228'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001228'],
#                                      'ccf_pref_label': 'papillary tip',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009095'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001225'],
#                                      'ccf_pref_label': 'renal column (column '
#                                                        'of Bertin)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001284'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000362'],
#                                      'ccf_pref_label': 'renal pyramid',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004200'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'nephron',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001285'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Renal Corpuscle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001229'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004188'],
#                                      'ccf_pref_label': 'parietal epithelial '
#                                                        'layer',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005750'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229'],
#                                      'ccf_pref_label': 'renal glomerulus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0000074'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0000074'],
#                                      'ccf_pref_label': 'Glomerulus Vasculature',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004190'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004190'],
#                                      'ccf_pref_label': 'glomerular capillary '
#                                                        'endothelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004294'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001229',
#                                                      'UBERON:0002113'],
#                                      'ccf_pref_label': 'Interstitium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005215'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005215'],
#                                      'ccf_pref_label': 'Proximal Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002319'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002319'],
#                                      'ccf_pref_label': 'glomerular mesangium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002320'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001285'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001231'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'proximal tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004134'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004196'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal convoluted '
#                                                        'tubule segment 2',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004197'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004134'],
#                                      'ccf_pref_label': 'proximal straight '
#                                                        'tubule segment 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001290'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005096'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 1',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005099'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001289'],
#                                      'ccf_pref_label': 'descending thin limb '
#                                                        'of loop of Henle 3',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:8600037'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Loop of Henle (Thin '
#                                                        'Limb)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004193'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001291'],
#                                      'ccf_pref_label': 'Macula Densa',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002335'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Distal Convolution',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001292'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001231'],
#                                      'ccf_pref_label': 'Connecting Tubule',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005097'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'renal collecting '
#                                                        'system',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004100'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004100',
#                                                      'UBERON:0001232'],
#                                      'ccf_pref_label': 'Tubules',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001232'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Outer '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004204'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0001232'],
#                                      'ccf_pref_label': 'Collecting Duct (Inner '
#                                                        'Medulla)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004205'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0002113'],
#                                      'ccf_pref_label': 'Vessels',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0006544'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Blood Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003517'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517',
#                                                      'UBERON:0009202',
#                                                      'UBERON:0009091'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0001986'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0034884'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Afferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004639'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0034884'],
#                                      'ccf_pref_label': 'Efferent Arteriole',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004640'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0003527'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003527'],
#                                      'ccf_pref_label': 'Peritubular Capillary',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0005272'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0005272'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0012441'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0004726'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0004726'],
#                                      'ccf_pref_label': 'Ascending Vasa Recta',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0009091'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0006544'],
#                                      'ccf_pref_label': 'Kidney Lymphatic '
#                                                        'Vessel',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel',
#                                      'parent_class': 'ccf:AnatomicalStructure'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['https://purl.org/ccf/ASCTB-TEMP_kidney-lymphatic-vessel'],
#                                      'ccf_pref_label': 'Endothelium (non '
#                                                        'glomerular)',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002042'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': False,
#                                      'ccf_part_of': ['UBERON:0003517'],
#                                      'ccf_pref_label': 'Juxtaglomerular '
#                                                        'Apparatus',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'UBERON:0002303'},
#                                     {'ccf_asctb_type': 'AS',
#                                      'ccf_is_provisional': True,
#                                      'ccf_part_of': ['UBERON:0009095'],
#                                      'ccf_pref_label': 'Papillary Tip '
#                                                        'Epithelium',
#                                      'conforms_to': 'AnatomicalStructure',
#                                      'id': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                      'parent_class': 'ccf:AnatomicalStructure'}],
#           'asctb_record': [{'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                                            'label': 'kidney '
#                                                                     '(kidney-R1-AS1)',
#                                                            'order_number': 1,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['UBERON:0002113']},
#                                                           {'ccf_pref_label': 'kidney '
#                                                                              'capsule',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                                            'label': 'kidney '
#                                                                     'capsule '
#                                                                     '(kidney-R1-AS2)',
#                                                            'order_number': 2,
#                                                            'record_number': 1,
#                                                            'source_concept': 'UBERON:0002015',
#                                                            'type_of': ['UBERON:0002015']}],
#                             'cell_type_list': [{'ccf_pref_label': 'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                                                 'label': 'stromal cell '
#                                                          '(kidney-R1-CT1)',
#                                                 'order_number': 1,
#                                                 'record_number': 1,
#                                                 'source_concept': 'CL:0000499',
#                                                 'type_of': ['CL:0000499']},
#                                                {'ccf_pref_label': 'capsule '
#                                                                   'mesenchymal '
#                                                                   'stromal '
#                                                                   'cell',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                                                 'label': 'capsule mesenchymal '
#                                                          'stromal cell '
#                                                          '(kidney-R1-CT2)',
#                                                 'order_number': 2,
#                                                 'record_number': 1,
#                                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                                                 'type_of': ['https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'Foxd1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                                                   'label': 'Foxd1 '
#                                                            '(kidney-R1-BM1)',
#                                                   'order_number': 1,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:3802',
#                                                   'type_of': ['HGNC:3802']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'VSX2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                                                   'label': 'VSX2 '
#                                                            '(kidney-R1-BM2)',
#                                                   'order_number': 2,
#                                                   'record_number': 1,
#                                                   'source_concept': 'HGNC:1975',
#                                                   'type_of': ['HGNC:1975']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#                             'label': 'Record 1',
#                             'record_number': 1,
#                             'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                                            'label': 'kidney '
#                                                                     '(kidney-R2-AS1)',
#                                                            'order_number': 1,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['UBERON:0002113']},
#                                                           {'ccf_pref_label': 'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                                            'label': 'cortex of '
#                                                                     'kidney '
#                                                                     '(kidney-R2-AS2)',
#                                                            'order_number': 2,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0001225',
#                                                            'type_of': ['UBERON:0001225']},
#                                                           {'ccf_pref_label': 'outer '
#                                                                              'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                                            'label': 'outer '
#                                                                     'cortex of '
#                                                                     'kidney '
#                                                                     '(kidney-R2-AS3)',
#                                                            'order_number': 3,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0002189',
#                                                            'type_of': ['UBERON:0002189']},
#                                                           {'ccf_pref_label': 'Glomerular '
#                                                                              'Epithelium',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                                            'label': 'Glomerular '
#                                                                     'Epithelium '
#                                                                     '(kidney-R2-AS4)',
#                                                            'order_number': 4,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0004188',
#                                                            'type_of': ['UBERON:0004188']},
#                                                           {'ccf_pref_label': 'visceral '
#                                                                              'epithelial '
#                                                                              'layer',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                                            'label': 'visceral '
#                                                                     'epithelial '
#                                                                     'layer '
#                                                                     '(kidney-R2-AS5)',
#                                                            'order_number': 5,
#                                                            'record_number': 2,
#                                                            'source_concept': 'UBERON:0005751',
#                                                            'type_of': ['UBERON:0005751']}],
#                             'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                                                 'label': 'Podocyte '
#                                                          '(kidney-R2-CT1)',
#                                                 'order_number': 1,
#                                                 'record_number': 2,
#                                                 'source_concept': 'CL:0000653',
#                                                 'type_of': ['CL:0000653']}],
#                             'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS2',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                                                   'label': 'NPHS2 '
#                                                            '(kidney-R2-BM1)',
#                                                   'order_number': 1,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:13394',
#                                                   'type_of': ['HGNC:13394']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PODXL',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                                                   'label': 'PODXL '
#                                                            '(kidney-R2-BM2)',
#                                                   'order_number': 2,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9171',
#                                                   'type_of': ['HGNC:9171']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'NPHS1',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                                                   'label': 'NPHS1 '
#                                                            '(kidney-R2-BM3)',
#                                                   'order_number': 3,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:7908',
#                                                   'type_of': ['HGNC:7908']},
#                                                  {'ccf_biomarker_type': 'gene',
#                                                   'ccf_pref_label': 'PTPRQ',
#                                                   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                                                   'label': 'PTPRQ '
#                                                            '(kidney-R2-BM4)',
#                                                   'order_number': 4,
#                                                   'record_number': 2,
#                                                   'source_concept': 'HGNC:9679',
#                                                   'type_of': ['HGNC:9679']}],
#                             'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#                             'label': 'Record 2',
#                             'record_number': 2,
#                             'type_of': ['AsctbRecord']},
#                            {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1',
#                                                            'label': 'kidney '
#                                                                     '(kidney-R3-AS1)',
#                                                            'order_number': 1,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0002113',
#                                                            'type_of': ['UBERON:0002113']},
#                                                           {'ccf_pref_label': 'cortex '
#                                                                              'of '
#                                                                              'kidney',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2',
#                                                            'label': 'cortex of '
#                                                                     'kidney '
#                                                                     '(kidney-R3-AS2)',
#                                                            'order_number': 2,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0001225',
#                                                            'type_of': ['UBERON:0001225']},
#                                                           {'ccf_pref_label': 'juxtamedullary '
#                                                                              'cortex',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3',
#                                                            'label': 'juxtamedullary '
#                                                                     'cortex '
#                                                                     '(kidney-R3-AS3)',
#                                                            'order_number': 3,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0005271',
#                                                            'type_of': ['UBERON:0005271']},
#                                                           {'ccf_pref_label': 'Glomerular '
#                                                                              'Epithelium',
#                                                            'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4',
#                                                            'label': 'Glomerular '
#                                                                     'Epithelium '
#                                                                     '(kidney-R3-AS4)',
#                                                            'order_number': 4,
#                                                            'record_number': 3,
#                                                            'source_concept': 'UBERON:0004188',
#                                                            'type_of': ['UBERON:0004188']},
# ...
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000814'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (general)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:613',
#                                                                          'HGNC:1636',
#                                                                          'HGNC:1638',
#                                                                          'HGNC:3609',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0001056'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (classical)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6152',
#                                                                          'HGNC:3765',
#                                                                          'HGNC:26705'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1084/jem.20030323',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000990'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Dendritic Cell (plasmatoid)',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6012',
#                                                                          'HGNC:3765'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2']}],
#                           'id': 'CL:0001058'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:1241',
#                                                                          'HGNC:4947',
#                                                                          'HGNC:6152'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000576'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'mononuclear phagocyte',
#                           'conforms_to': 'CellType',
#                           'id': 'CL:0000113'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000113'],
#                           'ccf_is_provisional': True,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Monocyte Derived Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:7376',
#                                                                          'HGNC:6152',
#                                                                          'HGNC:4942',
#                                                                          'HGNC:4948',
#                                                                          'HGNC:2435',
#                                                                          'HGNC:1628',
#                                                                          'HGNC:12339']}],
#                           'id': 'https://purl.org/ccf/ASCTB-TEMP_monocyte-derived-cell',
#                           'parent_class': 'ccf:CellType'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:16892',
#                                                                          'HGNC:1673',
#                                                                          'HGNC:1675',
#                                                                          'HGNC:11935',
#                                                                          'HGNC:1677'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000084'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Cytotoxic T Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:4708',
#                                                                          'HGNC:10630',
#                                                                          'HGNC:10632'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000910'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'regulatory T cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6106']}],
#                           'id': 'CL:0000815'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'B cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:5713',
#                                                                          'HGNC:1698',
#                                                                          'HGNC:7315',
#                                                                          'HGNC:4947'],
#                                                              'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000236'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Plasma cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:30125',
#                                                                          'HGNC:18508',
#                                                                          'HGNC:5713',
#                                                                          'HGNC:5716'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000786'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Neutrophil',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:10499',
#                                                                          'HGNC:10498',
#                                                                          'HGNC:3620',
#                                                                          'HGNC:2439'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1016/j.exphem.2016.10.008',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267',
#                                                                             'https://doi.org/10.1126/science.aat5031']}],
#                           'id': 'CL:0000775'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0005215'],
#                           'ccf_pref_label': 'Mast cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6342',
#                                                                          'HGNC:2298',
#                                                                          'HGNC:7316'],
#                                                              'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                                                                             'https://doi.org/10.1038/s41467-019-10861-2',
#                                                                             'https://doi.org/10.1038/s41586-020-2941-1',
#                                                                             'https://doi.org/10.1172/jci.insight.133267']}],
#                           'id': 'CL:0000097'},
#                          {'ccf_asctb_type': 'CT',
#                           'ccf_ct_isa': ['CL:0000000'],
#                           'ccf_is_provisional': False,
#                           'ccf_located_in': ['UBERON:0002113',
#                                              'UBERON:0001228',
#                                              'UBERON:0009095',
#                                              'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium'],
#                           'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                           'conforms_to': 'CellType',
#                           'has_characterizing_marker_set': [{'members': ['HGNC:6442',
#                                                                          'HGNC:15979',
#                                                                          'HGNC:4554',
#                                                                          'HGNC:11530']}],
#                           'id': 'CL:1000597'}]},
#  'iri': 'https://purl.humanatlas.io/asct-b/kidney',
#  'metadata': {'created_by': ['https://github.com/hubmapconsortium/hra-do-processor'],
#               'creation_date': '2024-09-24',
#               'derived_from': 'https://lod.humanatlas.io/asct-b/kidney/v1.5#raw-data',
#               'description': 'The graph representation of the Anatomical '
#                              'Structures, Cell Types, plus Biomarkers (ASCT+B) '
#                              'table for Kidney dataset.',
#               'license': 'https://creativecommons.org/licenses/by/4.0/',
#               'publisher': 'HuBMAP',
#               'see_also': 'https://lod.humanatlas.io/asct-b/kidney/v1.5/',
#               'title': 'kidney (v1.5) graph data',
#               'version': 'v1.5'}}

# %%
# iterate over rows in ASCT+B table 
for row in kidney_json['data']['asctb_record']:
  pprint(row)
# Out:
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS1',
#                                 'label': 'kidney (kidney-R1-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'kidney capsule',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-AS2',
#                                 'label': 'kidney capsule (kidney-R1-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 1,
#                                 'source_concept': 'UBERON:0002015',
#                                 'type_of': ['UBERON:0002015']}],
#  'cell_type_list': [{'ccf_pref_label': 'stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT1',
#                      'label': 'stromal cell (kidney-R1-CT1)',
#                      'order_number': 1,
#                      'record_number': 1,
#                      'source_concept': 'CL:0000499',
#                      'type_of': ['CL:0000499']},
#                     {'ccf_pref_label': 'capsule mesenchymal stromal cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-CT2',
#                      'label': 'capsule mesenchymal stromal cell '
#                               '(kidney-R1-CT2)',
#                      'order_number': 2,
#                      'record_number': 1,
#                      'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell',
#                      'type_of': ['https://purl.org/ccf/ASCTB-TEMP_capsule-mesenchymal-stromal-cell']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'Foxd1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM1',
#                        'label': 'Foxd1 (kidney-R1-BM1)',
#                        'order_number': 1,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:3802',
#                        'type_of': ['HGNC:3802']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'VSX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1-BM2',
#                        'label': 'VSX2 (kidney-R1-BM2)',
#                        'order_number': 2,
#                        'record_number': 1,
#                        'source_concept': 'HGNC:1975',
#                        'type_of': ['HGNC:1975']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R1',
#  'label': 'Record 1',
#  'record_number': 1,
#  'references': ['https://doi.org/10.1371/journal.pone.0187118'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS1',
#                                 'label': 'kidney (kidney-R2-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS2',
#                                 'label': 'cortex of kidney (kidney-R2-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['UBERON:0001225']},
#                                {'ccf_pref_label': 'outer cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS3',
#                                 'label': 'outer cortex of kidney '
#                                          '(kidney-R2-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0002189',
#                                 'type_of': ['UBERON:0002189']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS4',
#                                 'label': 'Glomerular Epithelium '
#                                          '(kidney-R2-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['UBERON:0004188']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-AS5',
#                                 'label': 'visceral epithelial layer '
#                                          '(kidney-R2-AS5)',
#                                 'order_number': 5,
#                                 'record_number': 2,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['UBERON:0005751']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#                      'label': 'Podocyte (kidney-R2-CT1)',
#                      'order_number': 1,
#                      'record_number': 2,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CL:0000653']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM1',
#                        'label': 'NPHS2 (kidney-R2-BM1)',
#                        'order_number': 1,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['HGNC:13394']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM2',
#                        'label': 'PODXL (kidney-R2-BM2)',
#                        'order_number': 2,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['HGNC:9171']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM3',
#                        'label': 'NPHS1 (kidney-R2-BM3)',
#                        'order_number': 3,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['HGNC:7908']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-BM4',
#                        'label': 'PTPRQ (kidney-R2-BM4)',
#                        'order_number': 4,
#                        'record_number': 2,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['HGNC:9679']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2',
#  'label': 'Record 2',
#  'record_number': 2,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS1',
#                                 'label': 'kidney (kidney-R3-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS2',
#                                 'label': 'cortex of kidney (kidney-R3-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['UBERON:0001225']},
#                                {'ccf_pref_label': 'juxtamedullary cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS3',
#                                 'label': 'juxtamedullary cortex '
#                                          '(kidney-R3-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005271',
#                                 'type_of': ['UBERON:0005271']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS4',
#                                 'label': 'Glomerular Epithelium '
#                                          '(kidney-R3-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['UBERON:0004188']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-AS5',
#                                 'label': 'visceral epithelial layer '
#                                          '(kidney-R3-AS5)',
#                                 'order_number': 5,
#                                 'record_number': 3,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['UBERON:0005751']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-CT1',
#                      'label': 'Podocyte (kidney-R3-CT1)',
#                      'order_number': 1,
#                      'record_number': 3,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CL:0000653']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM1',
#                        'label': 'NPHS2 (kidney-R3-BM1)',
#                        'order_number': 1,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['HGNC:13394']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM2',
#                        'label': 'PODXL (kidney-R3-BM2)',
#                        'order_number': 2,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['HGNC:9171']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM3',
#                        'label': 'NPHS1 (kidney-R3-BM3)',
#                        'order_number': 3,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['HGNC:7908']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM4',
#                        'label': 'PTPRQ (kidney-R3-BM4)',
#                        'order_number': 4,
#                        'record_number': 3,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['HGNC:9679']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3',
#  'label': 'Record 3',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R3-BM5',
#                           'label': 'PODXL (kidney-R3-BM5)',
#                           'order_number': 5,
#                           'record_number': 3,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['HGNC:9171']}],
#  'record_number': 3,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS1',
#                                 'label': 'kidney (kidney-R4-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'cortex of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS2',
#                                 'label': 'cortex of kidney (kidney-R4-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['UBERON:0001225']},
#                                {'ccf_pref_label': 'medullary ray',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS3',
#                                 'label': 'medullary ray (kidney-R4-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0009883',
#                                 'type_of': ['UBERON:0009883']},
#                                {'ccf_pref_label': 'Collecting Duct (Cortex)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-AS4',
#                                 'label': 'Collecting Duct (Cortex) '
#                                          '(kidney-R4-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 4,
#                                 'source_concept': 'UBERON:0004203',
#                                 'type_of': ['UBERON:0004203']}],
#  'cell_type_list': [{'ccf_pref_label': 'Cortical Collecting Duct Principal '
#                                        'Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-CT1',
#                      'label': 'Cortical Collecting Duct Principal Cell '
#                               '(kidney-R4-CT1)',
#                      'order_number': 1,
#                      'record_number': 4,
#                      'source_concept': 'CL:1000714',
#                      'type_of': ['CL:1000714']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM1',
#                        'label': 'AQP2 (kidney-R4-BM1)',
#                        'order_number': 1,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['HGNC:634']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM2',
#                        'label': 'AQP3 (kidney-R4-BM2)',
#                        'order_number': 2,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:636',
#                        'type_of': ['HGNC:636']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FXYD4',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM3',
#                        'label': 'FXYD4 (kidney-R4-BM3)',
#                        'order_number': 3,
#                        'record_number': 4,
#                        'source_concept': 'HGNC:4028',
#                        'type_of': ['HGNC:4028']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4',
#  'label': 'Record 4',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R4-BM4',
#                           'label': 'AQP2 (kidney-R4-BM4)',
#                           'order_number': 4,
#                           'record_number': 4,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['HGNC:634']}],
#  'record_number': 4,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS1',
#                                 'label': 'kidney (kidney-R5-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS2',
#                                 'label': 'renal medulla (kidney-R5-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['UBERON:0000362']},
#                                {'ccf_pref_label': 'kidney outer medulla outer '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS3',
#                                 'label': 'kidney outer medulla outer stripe '
#                                          '(kidney-R5-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0004202',
#                                 'type_of': ['UBERON:0004202']},
#                                {'ccf_pref_label': 'Loop of Henle (Thick '
#                                                   'Limb/Medulla)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-AS4',
#                                 'label': 'Loop of Henle (Thick Limb/Medulla) '
#                                          '(kidney-R5-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 5,
#                                 'source_concept': 'UBERON:0001291',
#                                 'type_of': ['UBERON:0001291']}],
#  'cell_type_list': [{'ccf_pref_label': 'Medullary Thick Ascending Limb Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-CT1',
#                      'label': 'Medullary Thick Ascending Limb Cell '
#                               '(kidney-R5-CT1)',
#                      'order_number': 1,
#                      'record_number': 5,
#                      'source_concept': 'CL:1001108',
#                      'type_of': ['CL:1001108']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC12A1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM1',
#                        'label': 'SLC12A1 (kidney-R5-BM1)',
#                        'order_number': 1,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:10910',
#                        'type_of': ['HGNC:10910']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'UMOD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM2',
#                        'label': 'UMOD (kidney-R5-BM2)',
#                        'order_number': 2,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:12559',
#                        'type_of': ['HGNC:12559']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CASR',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5-BM3',
#                        'label': 'CASR (kidney-R5-BM3)',
#                        'order_number': 3,
#                        'record_number': 5,
#                        'source_concept': 'HGNC:1514',
#                        'type_of': ['HGNC:1514']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R5',
#  'label': 'Record 5',
#  'record_number': 5,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS1',
#                                 'label': 'kidney (kidney-R6-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS2',
#                                 'label': 'renal medulla (kidney-R6-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['UBERON:0000362']},
#                                {'ccf_pref_label': 'kidney outer medulla inner '
#                                                   'stripe',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS3',
#                                 'label': 'kidney outer medulla inner stripe '
#                                          '(kidney-R6-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0004201',
#                                 'type_of': ['UBERON:0004201']},
#                                {'ccf_pref_label': 'Loop of Henle (Thin Limb)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS4',
#                                 'label': 'Loop of Henle (Thin Limb) '
#                                          '(kidney-R6-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:0001289',
#                                 'type_of': ['UBERON:0001289']},
#                                {'ccf_pref_label': 'descending thin limb of '
#                                                   'loop of Henle 2',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-AS5',
#                                 'label': 'descending thin limb of loop of '
#                                          'Henle 2 (kidney-R6-AS5)',
#                                 'order_number': 5,
#                                 'record_number': 6,
#                                 'source_concept': 'UBERON:8600036',
#                                 'type_of': ['UBERON:8600036']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Thin Limb Cell Type 2',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-CT1',
#                      'label': 'Descending Thin Limb Cell Type 2 '
#                               '(kidney-R6-CT1)',
#                      'order_number': 1,
#                      'record_number': 6,
#                      'source_concept': 'CL:4030013',
#                      'type_of': ['CL:4030013']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CRYAB',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM1',
#                        'label': 'CRYAB (kidney-R6-BM1)',
#                        'order_number': 1,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:2389',
#                        'type_of': ['HGNC:2389']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC39A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM2',
#                        'label': 'SLC39A8 (kidney-R6-BM2)',
#                        'order_number': 2,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:20862',
#                        'type_of': ['HGNC:20862']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM3',
#                        'label': 'TACSTD2 (kidney-R6-BM3)',
#                        'order_number': 3,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['HGNC:11530']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM4',
#                        'label': 'AQP1 (kidney-R6-BM4)',
#                        'order_number': 4,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:633',
#                        'type_of': ['HGNC:633']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC9A3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM5',
#                        'label': 'SLC9A3 (kidney-R6-BM5)',
#                        'order_number': 5,
#                        'record_number': 6,
#                        'source_concept': 'HGNC:11073',
#                        'type_of': ['HGNC:11073']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6',
#  'label': 'Record 6',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP1',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R6-BM6',
#                           'label': 'AQP1 (kidney-R6-BM6)',
#                           'order_number': 6,
#                           'record_number': 6,
#                           'source_concept': 'HGNC:633',
#                           'type_of': ['HGNC:633']}],
#  'record_number': 6,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS1',
#                                 'label': 'kidney (kidney-R7-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS2',
#                                 'label': 'renal medulla (kidney-R7-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['UBERON:0000362']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS3',
#                                 'label': 'inner medulla of kidney '
#                                          '(kidney-R7-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['UBERON:0001294']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-AS4',
#                                 'label': 'Descending Vasa Recta '
#                                          '(kidney-R7-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 7,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['UBERON:0009202']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-CT1',
#                      'label': 'Descending Vasa Recta Endothelial Cell '
#                               '(kidney-R7-CT1)',
#                      'order_number': 1,
#                      'record_number': 7,
#                      'source_concept': 'CL:1001285',
#                      'type_of': ['CL:1001285']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SERPINE2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM1',
#                        'label': 'SERPINE2 (kidney-R7-BM1)',
#                        'order_number': 1,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:8951',
#                        'type_of': ['HGNC:8951']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TM4SF1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM2',
#                        'label': 'TM4SF1 (kidney-R7-BM2)',
#                        'order_number': 2,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:11853',
#                        'type_of': ['HGNC:11853']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PALMD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM3',
#                        'label': 'PALMD (kidney-R7-BM3)',
#                        'order_number': 3,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:15846',
#                        'type_of': ['HGNC:15846']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'ADAMTS6',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM4',
#                        'label': 'ADAMTS6 (kidney-R7-BM4)',
#                        'order_number': 4,
#                        'record_number': 7,
#                        'source_concept': 'HGNC:222',
#                        'type_of': ['HGNC:222']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7',
#  'label': 'Record 7',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'UMOD',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R7-BM5',
#                           'label': 'UMOD (kidney-R7-BM5)',
#                           'order_number': 5,
#                           'record_number': 7,
#                           'source_concept': 'HGNC:12559',
#                           'type_of': ['HGNC:12559']}],
#  'record_number': 7,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS1',
#                                 'label': 'kidney (kidney-R8-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS2',
#                                 'label': 'renal medulla (kidney-R8-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['UBERON:0000362']},
#                                {'ccf_pref_label': 'inner medulla of kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS3',
#                                 'label': 'inner medulla of kidney '
#                                          '(kidney-R8-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001294',
#                                 'type_of': ['UBERON:0001294']},
#                                {'ccf_pref_label': 'renal papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS4',
#                                 'label': 'renal papilla (kidney-R8-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['UBERON:0001228']},
#                                {'ccf_pref_label': 'papillary tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-AS5',
#                                 'label': 'papillary tip (kidney-R8-AS5)',
#                                 'order_number': 5,
#                                 'record_number': 8,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['UBERON:0009095']}],
#  'cell_type_list': [{'ccf_pref_label': 'Inner Medullary Collecting Duct Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-CT1',
#                      'label': 'Inner Medullary Collecting Duct Cell '
#                               '(kidney-R8-CT1)',
#                      'order_number': 1,
#                      'record_number': 8,
#                      'source_concept': 'CL:1000718',
#                      'type_of': ['CL:1000718']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'AQP2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM1',
#                        'label': 'AQP2 (kidney-R8-BM1)',
#                        'order_number': 1,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:634',
#                        'type_of': ['HGNC:634']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SLC14A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM2',
#                        'label': 'SLC14A2 (kidney-R8-BM2)',
#                        'order_number': 2,
#                        'record_number': 8,
#                        'source_concept': 'HGNC:10919',
#                        'type_of': ['HGNC:10919']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8',
#  'label': 'Record 8',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'AQP2',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R8-BM3',
#                           'label': 'AQP2 (kidney-R8-BM3)',
#                           'order_number': 3,
#                           'record_number': 8,
#                           'source_concept': 'HGNC:634',
#                           'type_of': ['HGNC:634']}],
#  'record_number': 8,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS1',
#                                 'label': 'kidney (kidney-R9-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'renal cortex',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS2',
#                                 'label': 'renal cortex (kidney-R9-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001225',
#                                 'type_of': ['UBERON:0001225']},
#                                {'ccf_pref_label': 'renal column (column of '
#                                                   'Bertin)',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS3',
#                                 'label': 'renal column (column of Bertin) '
#                                          '(kidney-R9-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0001284',
#                                 'type_of': ['UBERON:0001284']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS4',
#                                 'label': 'Glomerular Epithelium '
#                                          '(kidney-R9-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['UBERON:0004188']},
#                                {'ccf_pref_label': 'visceral epithelial layer',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-AS5',
#                                 'label': 'visceral epithelial layer '
#                                          '(kidney-R9-AS5)',
#                                 'order_number': 5,
#                                 'record_number': 9,
#                                 'source_concept': 'UBERON:0005751',
#                                 'type_of': ['UBERON:0005751']}],
#  'cell_type_list': [{'ccf_pref_label': 'Podocyte',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-CT1',
#                      'label': 'Podocyte (kidney-R9-CT1)',
#                      'order_number': 1,
#                      'record_number': 9,
#                      'source_concept': 'CL:0000653',
#                      'type_of': ['CL:0000653']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM1',
#                        'label': 'NPHS2 (kidney-R9-BM1)',
#                        'order_number': 1,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:13394',
#                        'type_of': ['HGNC:13394']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PODXL',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM2',
#                        'label': 'PODXL (kidney-R9-BM2)',
#                        'order_number': 2,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9171',
#                        'type_of': ['HGNC:9171']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'NPHS1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM3',
#                        'label': 'NPHS1 (kidney-R9-BM3)',
#                        'order_number': 3,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:7908',
#                        'type_of': ['HGNC:7908']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PTPRQ',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM4',
#                        'label': 'PTPRQ (kidney-R9-BM4)',
#                        'order_number': 4,
#                        'record_number': 9,
#                        'source_concept': 'HGNC:9679',
#                        'type_of': ['HGNC:9679']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9',
#  'label': 'Record 9',
#  'protein_marker_list': [{'ccf_biomarker_type': 'protein',
#                           'ccf_pref_label': 'PODXL',
#                           'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R9-BM5',
#                           'label': 'PODXL (kidney-R9-BM5)',
#                           'order_number': 5,
#                           'record_number': 9,
#                           'source_concept': 'HGNC:9171',
#                           'type_of': ['HGNC:9171']}],
#  'record_number': 9,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS1',
#                                 'label': 'kidney (kidney-R10-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'renal medulla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS2',
#                                 'label': 'renal medulla (kidney-R10-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0000362',
#                                 'type_of': ['UBERON:0000362']},
#                                {'ccf_pref_label': 'renal pyramid',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS3',
#                                 'label': 'renal pyramid (kidney-R10-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0004200',
#                                 'type_of': ['UBERON:0004200']},
#                                {'ccf_pref_label': 'Descending Vasa Recta',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-AS4',
#                                 'label': 'Descending Vasa Recta '
#                                          '(kidney-R10-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 10,
#                                 'source_concept': 'UBERON:0009202',
#                                 'type_of': ['UBERON:0009202']}],
#  'cell_type_list': [{'ccf_pref_label': 'Descending Vasa Recta Endothelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-CT1',
#                      'label': 'Descending Vasa Recta Endothelial Cell '
#                               '(kidney-R10-CT1)',
#                      'order_number': 1,
#                      'record_number': 10,
#                      'source_concept': 'CL:1001285',
#                      'type_of': ['CL:1001285']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'SERPINE2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM1',
#                        'label': 'SERPINE2 (kidney-R10-BM1)',
#                        'order_number': 1,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:8951',
#                        'type_of': ['HGNC:8951']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TM4SF1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM2',
#                        'label': 'TM4SF1 (kidney-R10-BM2)',
#                        'order_number': 2,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:11853',
#                        'type_of': ['HGNC:11853']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'PALMD',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM3',
#                        'label': 'PALMD (kidney-R10-BM3)',
#                        'order_number': 3,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:15846',
#                        'type_of': ['HGNC:15846']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'ADAMTS6',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10-BM4',
#                        'label': 'ADAMTS6 (kidney-R10-BM4)',
#                        'order_number': 4,
#                        'record_number': 10,
#                        'source_concept': 'HGNC:222',
#                        'type_of': ['HGNC:222']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R10',
#  'label': 'Record 10',
#  'record_number': 10,
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS1',
#                                 'label': 'kidney (kidney-R11-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 11,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'nephron',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS2',
#                                 'label': 'nephron (kidney-R11-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 11,
#                                 'source_concept': 'UBERON:0001285',
#                                 'type_of': ['UBERON:0001285']},
#                                {'ccf_pref_label': 'Renal Corpuscle',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS3',
#                                 'label': 'Renal Corpuscle (kidney-R11-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 11,
#                                 'source_concept': 'UBERON:0001229',
#                                 'type_of': ['UBERON:0001229']},
#                                {'ccf_pref_label': 'Glomerular Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R11-AS4',
#                                 'label': 'Glomerular Epithelium '
#                                          '(kidney-R11-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 11,
#                                 'source_concept': 'UBERON:0004188',
#                                 'type_of': ['UBERON:0004188']},
# ...
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-BM3',
#                        'label': 'MS4A1 (kidney-R74-BM3)',
#                        'order_number': 3,
#                        'record_number': 74,
#                        'source_concept': 'HGNC:7315',
#                        'type_of': ['HGNC:7315']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'HLA-DRA',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74-BM4',
#                        'label': 'HLA-DRA (kidney-R74-BM4)',
#                        'order_number': 4,
#                        'record_number': 74,
#                        'source_concept': 'HGNC:4947',
#                        'type_of': ['HGNC:4947']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R74',
#  'label': 'Record 74',
#  'record_number': 74,
#  'references': ['https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-AS1',
#                                 'label': 'kidney (kidney-R75-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 75,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-AS2',
#                                 'label': 'Interstitium (kidney-R75-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 75,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['UBERON:0005215']}],
#  'cell_type_list': [{'ccf_pref_label': 'Plasma cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-CT1',
#                      'label': 'Plasma cell (kidney-R75-CT1)',
#                      'order_number': 1,
#                      'record_number': 75,
#                      'source_concept': 'CL:0000786',
#                      'type_of': ['CL:0000786']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'MZB1',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM1',
#                        'label': 'MZB1 (kidney-R75-BM1)',
#                        'order_number': 1,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:30125',
#                        'type_of': ['HGNC:30125']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FCRL5',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM2',
#                        'label': 'FCRL5 (kidney-R75-BM2)',
#                        'order_number': 2,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:18508',
#                        'type_of': ['HGNC:18508']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'JCHAIN',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM3',
#                        'label': 'JCHAIN (kidney-R75-BM3)',
#                        'order_number': 3,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:5713',
#                        'type_of': ['HGNC:5713']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'IGKC',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75-BM4',
#                        'label': 'IGKC (kidney-R75-BM4)',
#                        'order_number': 4,
#                        'record_number': 75,
#                        'source_concept': 'HGNC:5716',
#                        'type_of': ['HGNC:5716']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R75',
#  'label': 'Record 75',
#  'record_number': 75,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS1',
#                                 'label': 'kidney (kidney-R76-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 76,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-AS2',
#                                 'label': 'Interstitium (kidney-R76-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 76,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['UBERON:0005215']}],
#  'cell_type_list': [{'ccf_pref_label': 'Neutrophil',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-CT1',
#                      'label': 'Neutrophil (kidney-R76-CT1)',
#                      'order_number': 1,
#                      'record_number': 76,
#                      'source_concept': 'CL:0000775',
#                      'type_of': ['CL:0000775']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'S100A9',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM1',
#                        'label': 'S100A9 (kidney-R76-BM1)',
#                        'order_number': 1,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:10499',
#                        'type_of': ['HGNC:10499']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'S100A8',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM2',
#                        'label': 'S100A8 (kidney-R76-BM2)',
#                        'order_number': 2,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:10498',
#                        'type_of': ['HGNC:10498']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'FCGR3B',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM3',
#                        'label': 'FCGR3B (kidney-R76-BM3)',
#                        'order_number': 3,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:3620',
#                        'type_of': ['HGNC:3620']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CSF3R',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76-BM4',
#                        'label': 'CSF3R (kidney-R76-BM4)',
#                        'order_number': 4,
#                        'record_number': 76,
#                        'source_concept': 'HGNC:2439',
#                        'type_of': ['HGNC:2439']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R76',
#  'label': 'Record 76',
#  'record_number': 76,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1016/j.exphem.2016.10.008',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267',
#                 'https://doi.org/10.1126/science.aat5031'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS1',
#                                 'label': 'kidney (kidney-R77-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 77,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'Interstitium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-AS2',
#                                 'label': 'Interstitium (kidney-R77-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 77,
#                                 'source_concept': 'UBERON:0005215',
#                                 'type_of': ['UBERON:0005215']}],
#  'cell_type_list': [{'ccf_pref_label': 'Mast cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-CT1',
#                      'label': 'Mast cell (kidney-R77-CT1)',
#                      'order_number': 1,
#                      'record_number': 77,
#                      'source_concept': 'CL:0000097',
#                      'type_of': ['CL:0000097']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'KIT',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM1',
#                        'label': 'KIT (kidney-R77-BM1)',
#                        'order_number': 1,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:6342',
#                        'type_of': ['HGNC:6342']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'CPA3',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM2',
#                        'label': 'CPA3 (kidney-R77-BM2)',
#                        'order_number': 2,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:2298',
#                        'type_of': ['HGNC:2298']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'MS4A2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77-BM3',
#                        'label': 'MS4A2 (kidney-R77-BM3)',
#                        'order_number': 3,
#                        'record_number': 77,
#                        'source_concept': 'HGNC:7316',
#                        'type_of': ['HGNC:7316']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R77',
#  'label': 'Record 77',
#  'record_number': 77,
#  'references': ['https://doi.org/10.1101/2021.07.28.454201',
#                 'https://doi.org/10.1038/s41467-019-10861-2',
#                 'https://doi.org/10.1038/s41586-020-2941-1',
#                 'https://doi.org/10.1172/jci.insight.133267'],
#  'type_of': ['AsctbRecord']}
# {'anatomical_structure_list': [{'ccf_pref_label': 'kidney',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS1',
#                                 'label': 'kidney (kidney-R78-AS1)',
#                                 'order_number': 1,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0002113',
#                                 'type_of': ['UBERON:0002113']},
#                                {'ccf_pref_label': 'Papilla',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS2',
#                                 'label': 'Papilla (kidney-R78-AS2)',
#                                 'order_number': 2,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0001228',
#                                 'type_of': ['UBERON:0001228']},
#                                {'ccf_pref_label': 'Papillary Tip',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS3',
#                                 'label': 'Papillary Tip (kidney-R78-AS3)',
#                                 'order_number': 3,
#                                 'record_number': 78,
#                                 'source_concept': 'UBERON:0009095',
#                                 'type_of': ['UBERON:0009095']},
#                                {'ccf_pref_label': 'Papillary Tip Epithelium',
#                                 'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-AS4',
#                                 'label': 'Papillary Tip Epithelium '
#                                          '(kidney-R78-AS4)',
#                                 'order_number': 4,
#                                 'record_number': 78,
#                                 'source_concept': 'https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium',
#                                 'type_of': ['https://purl.org/ccf/ASCTB-TEMP_papillary-tip-epithelium']}],
#  'cell_type_list': [{'ccf_pref_label': 'Papillary Tip Epithelial Cell',
#                      'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-CT1',
#                      'label': 'Papillary Tip Epithelial Cell (kidney-R78-CT1)',
#                      'order_number': 1,
#                      'record_number': 78,
#                      'source_concept': 'CL:1000597',
#                      'type_of': ['CL:1000597']}],
#  'gene_marker_list': [{'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'KRT5',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM1',
#                        'label': 'KRT5 (kidney-R78-BM1)',
#                        'order_number': 1,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:6442',
#                        'type_of': ['HGNC:6442']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TP63',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM2',
#                        'label': 'TP63 (kidney-R78-BM2)',
#                        'order_number': 2,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:15979',
#                        'type_of': ['HGNC:15979']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'GPX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM3',
#                        'label': 'GPX2 (kidney-R78-BM3)',
#                        'order_number': 3,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:4554',
#                        'type_of': ['HGNC:4554']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'TACSTD2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM4',
#                        'label': 'TACSTD2 (kidney-R78-BM4)',
#                        'order_number': 4,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:11530',
#                        'type_of': ['HGNC:11530']},
#                       {'ccf_biomarker_type': 'gene',
#                        'ccf_pref_label': 'GPX2',
#                        'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78-BM5',
#                        'label': 'GPX2 (kidney-R78-BM5)',
#                        'order_number': 5,
#                        'record_number': 78,
#                        'source_concept': 'HGNC:4554',
#                        'type_of': ['HGNC:4554']}],
#  'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R78',
#  'label': 'Record 78',
#  'record_number': 78,
#  'type_of': ['AsctbRecord']}

# %%
# get all rows with kidney cortex
cortex_id = "UBERON:0001225"

# %%
# find all AS IDs with a connection to the cortex
def find_connected_ids(kidney_data, cortex_id, collected_ids=None):
  """_summary_

  Args:
      kidney_data (json): table as JSON
      cortex_id (str): AS ID
      collected_ids (set(), optional): A set of IDs. Defaults to None.

  Returns:
       collected_ids (set()): A set of IDs. Defaults to None.
  """
  if collected_ids is None:
      collected_ids = set()

  new_ids = set()

  # Loop through each anatomical structure to find connections to cortex_id
  for structure in kidney_data['data']['anatomical_structures']:
      try:
          # If the cortex_id is in the 'ccf_part_of' list, add the structure's ID
          if cortex_id in structure['ccf_part_of'] and structure['id'] not in collected_ids:
              new_ids.add(structure['id'])
      except KeyError:
          # Skip if 'ccf_part_of' key doesn't exist
          pass

  # If no new IDs are found, return the collected set
  if not new_ids:
      return collected_ids

  # Add newly found IDs to collected_ids
  collected_ids.update(new_ids)

  # Recursively find connections for each new ID found
  for new_id in new_ids:
      find_connected_ids(kidney_data, new_id, collected_ids)

  return collected_ids


# Example usage
ids_with_connection_to_cortex = find_connected_ids(kidney_json, cortex_id)
pprint(ids_with_connection_to_cortex)
# Out:
# {'UBERON:0001284',
#  'UBERON:0002189',
#  'UBERON:0004188',
#  'UBERON:0004203',
#  'UBERON:0005271',
#  'UBERON:0005750',
#  'UBERON:0005751',
#  'UBERON:0009883'}

# %%
# check connections to cortex
def check_relationships(id: str):
  """Checks if the provided IRI is connected to the cortex
  Args:
      id (str): an IRI (UBERON or FMA)
  Returns:
      check (bool): checks whether there is a connection
  """

  check = False
  for entry in kidney_json['data']['anatomical_structures']:
    if entry['id'] == id:
      try:
        if cortex_id in entry['ccf_part_of']:
          check = True
      except:
        pass

  return check

# %%
# initialize dict for result
result = {
  "cell_label": [],
  "cell_ontology_id": []
}

# initialize list for all asctb_records with cortex
relevant_records = []

for record in kidney_json['data']['asctb_record']:
  for row in record['anatomical_structure_list']:
    if (cortex_id in row['source_concept'] or cortex_id in row['type_of'] or check_relationships(row['source_concept']) or row['source_concept'] in ids_with_connection_to_cortex):
      relevant_records.append(record['cell_type_list'])
    
# use list comprehension to simply the list of cell types
list_flattened = [record for sublist in relevant_records for record in sublist]
pprint(list_flattened[:3])
# Out:
# [{'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (kidney-R2-CT1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CL:0000653']},
#  {'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (kidney-R2-CT1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CL:0000653']},
#  {'ccf_pref_label': 'Podocyte',
#   'id': 'https://purl.humanatlas.io/asct-b/kidney/v1.5#R2-CT1',
#   'label': 'Podocyte (kidney-R2-CT1)',
#   'order_number': 1,
#   'record_number': 2,
#   'source_concept': 'CL:0000653',
#   'type_of': ['CL:0000653']}]

# %%
# prefix for OBO PURL
prefix = "http://purl.obolibrary.org/obo/"

# capture result in dict
for cell_type in list_flattened:
  result['cell_label'].append(cell_type['ccf_pref_label'])
  result['cell_ontology_id'].append(prefix+cell_type['source_concept'])
  
# convert to dataframe
df = pd.DataFrame(result).drop_duplicates(subset="cell_ontology_id")
df
# Out:
#                                            cell_label  \
# 0                                            Podocyte
# 8             Cortical Collecting Duct Principal Cell
# 15                           Parietal Epithelial Cell
# 20  Cortical Collecting Duct Intercalated Cell Type A
#
#                              cell_ontology_id
# 0   http://purl.obolibrary.org/obo/CL:0000653
# 8   http://purl.obolibrary.org/obo/CL:1000714
# 15  http://purl.obolibrary.org/obo/CL:1000452
# 20  http://purl.obolibrary.org/obo/CL:1000715
